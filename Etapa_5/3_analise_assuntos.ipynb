# %% [markdown]
# # Análise das questões a partir das provas

# %%
Dados_Questoes = "questions_D_M.csv"

# %% [markdown]
# # Explicação do Código de Reorganização de Provas
#
# ## O que o código faz?
#
# Este código Python foi criado para **reorganizar arquivos de provas** que estão espalhados em uma estrutura de pastas complexa e bagunçada. Ele pega todos os arquivos `.data` (que contêm as provas) e os organiza de forma mais simples e lógica.
#
# ## Estrutura Desejada
#
# O código transforma estruturas complexas em uma organização simples:
#
# ```
# Provas_Arrumado/
# ├── Curso1/
# │   ├── Avaliacao1/
# │   │   ├── prova1.data
# │   │   └── prova2.data
# │   └── Avaliacao2/
# │       └── prova3.data
# └── Curso2/
#     └── Prova_Final/
#         └── prova4.data
# ```
#
# ## Principais Funções
#
# ### 1. `simplificar_hierarquia_provas()`
# **O que faz:** É a função principal que faz toda a reorganização
# - Percorre todas as pastas da estrutura original
# - Encontra arquivos `.data`
# - Identifica qual curso e avaliação cada arquivo pertence
# - Move os arquivos para a nova estrutura organizada
# - Gera um relatório de tudo que foi feito
#
# ### 2. `identificar_curso_avaliacao()`
# **O que faz:** Analisa o caminho de uma pasta e tenta descobrir:
# - Qual é o **curso** (ex: "Introdução à Ciência dos Computadores")
# - Qual é a **avaliação** (ex: "Prova Final", "Avaliação 1")
#
# **Como funciona:**
# - Procura por palavras-chave conhecidas como "programacao", "avaliacao", "prova"
# - Usa padrões para identificar automaticamente curso e avaliação
#
# ### 3. `verificar_estrutura_atual()`
# **O que faz:** Analisa como estão organizadas as pastas atualmente
# - Conta quantos arquivos existem
# - Mostra os níveis de profundidade das pastas
# - Ajuda a entender a bagunça antes da reorganização
#
# ### 4. `executar_reorganizacao_completa()`
# **O que faz:** Executa todo o processo paso a paso:
# 1. Verifica como está a estrutura atual
# 2. Executa a reorganização
# 3. Verifica como ficou o resultado
# 4. Mostra sugestões do que fazer depois
#
# ## Como usar?
#
# 1. **Configure o caminho:** Mude a variável `pasta_provas` para apontar para sua pasta de provas
# 2. **Execute o script:** O código vai criar uma nova pasta chamada `Provas_Arrumado`
# 3. **Verifique o resultado:** Confira se a reorganização ficou como esperado
# 4. **Substitua a original:** Se estiver tudo certo, pode usar a nova pasta
#
# ## Relatório Gerado
#
# O código gera um relatório mostrando:
# - ✅ Quantos cursos foram processados
# - ✅ Quantas avaliações foram reorganizadas
# - ✅ Quantos arquivos foram movidos
# - ⚠️ Erros que aconteceram (se houver)
#
# ## Vantagens
#
# - **Automatiza** um trabalho que seria muito demorado fazer manualmente
# - **Preserva** os arquivos originais (apenas copia)
# - **Padroniza** os nomes das pastas
# - **Gera relatórios** para você saber exatamente o que foi feito
# - **É seguro** - cria uma nova estrutura sem mexer na original
#
# ## Exemplo Prático
#
# **Antes:**
# ```
# /Provas/Curso_ICC_2023/Semestre1/Avaliacoes/Parcial/Turma_A/arquivo1.data
# ```
#
# **Depois:**
# ```
# /Provas_Arrumado/Curso ICC 2023/Parcial/arquivo1.data
# ```
#
# Muito mais simples e organizado! 🎯

# %%
import os
import shutil
from pathlib import Path

Provas="./Provas"
Provas_Arrumadas="./Provas_Arrumadas"

def copiar_pasta_provas(pasta_origem, pasta_destino=Provas):
    """
    Copia a pasta de provas completa mantendo a estrutura original
    """
    
    print("🚀 Copiando pasta de provas completa...")
    print(f"   📁 Origem: {pasta_origem}")
    print(f"   📁 Destino: {pasta_destino}")
    
    # Verificar se a origem existe
    if not os.path.exists(pasta_origem):
        print(f"❌ Pasta de origem não encontrada: {pasta_origem}")
        return False
    
    try:
        # Remover pasta destino se existir
        if os.path.exists(pasta_destino):
            print(f"🗑️  Removendo pasta existente: {pasta_destino}")
            shutil.rmtree(pasta_destino)
        
        # Copiar toda a pasta
        print(f"📋 Copiando estrutura completa...")
        shutil.copytree(pasta_origem, pasta_destino)
        
        # Contar arquivos copiados
        total_arquivos = 0
        arquivos_data = 0
        
        for root, dirs, files in os.walk(pasta_destino):
            total_arquivos += len(files)
            arquivos_data += len([f for f in files if f.endswith('.data')])
        
        print(f"✅ Cópia concluída!")
        print(f"📊 Total de arquivos: {total_arquivos}")
        print(f"📊 Arquivos .data: {arquivos_data}")
        print(f"📁 Pasta criada em: {os.path.abspath(pasta_destino)}")
        
        # Executar limpeza de pastas duplicadas
        print(f"\n🧹 Removendo níveis duplicados de pastas...")
        limpar_pastas_duplicadas(pasta_destino)
        
        return True
        
    except Exception as e:
        print(f"❌ Erro ao copiar: {e}")
        return False

def limpar_pastas_duplicadas(pasta_base):
    """
    Remove níveis duplicados de pastas com o mesmo nome
    Ex: pasta/subpasta/subpasta/arquivo.data -> pasta/subpasta/arquivo.data
    """
    
    print(f"🔍 Analisando estrutura em: {pasta_base}")
    
    pastas_processadas = 0
    arquivos_movidos = 0
    
    # Percorrer toda a estrutura
    for root, dirs, files in os.walk(pasta_base, topdown=False):
        # Para cada subpasta no diretório atual
        for pasta_nome in dirs:
            pasta_caminho = os.path.join(root, pasta_nome)
            
            # Verificar se existe uma subpasta com o mesmo nome
            subpasta_igual = os.path.join(pasta_caminho, pasta_nome)
            
            if os.path.exists(subpasta_igual) and os.path.isdir(subpasta_igual):
                print(f"   🎯 Encontrado nível duplicado: {pasta_nome}")
                print(f"      📁 Pasta pai: {pasta_caminho}")
                print(f"      📁 Pasta filha: {subpasta_igual}")
                
                try:
                    # Mover todo conteúdo da subpasta para a pasta pai
                    for item in os.listdir(subpasta_igual):
                        item_origem = os.path.join(subpasta_igual, item)
                        item_destino = os.path.join(pasta_caminho, item)
                        
                        # Se já existe no destino, criar nome único
                        if os.path.exists(item_destino):
                            contador = 1
                            nome_base, extensao = os.path.splitext(item)
                            while os.path.exists(item_destino):
                                novo_nome = f"{nome_base}_{contador}{extensao}"
                                item_destino = os.path.join(pasta_caminho, novo_nome)
                                contador += 1
                        
                        # Mover o item
                        shutil.move(item_origem, item_destino)
                        arquivos_movidos += 1
                        print(f"         ✅ Movido: {item}")
                    
                    # Remover a pasta duplicada vazia
                    os.rmdir(subpasta_igual)
                    pastas_processadas += 1
                    print(f"      🗑️  Pasta duplicada removida")
                    
                except Exception as e:
                    print(f"      ❌ Erro ao processar {pasta_nome}: {e}")
    
    print(f"\n📊 LIMPEZA CONCLUÍDA:")
    print(f"   ✅ Pastas duplicadas removidas: {pastas_processadas}")
    print(f"   ✅ Arquivos reorganizados: {arquivos_movidos}")
    
    return pastas_processadas > 0

def executar_apenas_limpeza(pasta_base="./Dados_Provas_Arrumado/Provas"):
    """
    Executa apenas a limpeza de pastas duplicadas (sem copiar)
    """
    print("🧹 LIMPEZA DE PASTAS DUPLICADAS")
    print("-" * 40)
    
    if not os.path.exists(pasta_base):
        print(f"❌ Pasta não encontrada: {pasta_base}")
        return False
    
    print(f"📁 Processando: {os.path.abspath(pasta_base)}")
    sucesso = limpar_pastas_duplicadas(pasta_base)
    
    if sucesso:
        print("\n✨ LIMPEZA CONCLUÍDA!")
    else:
        print("\n⚠️  Nenhuma pasta duplicada encontrada")
    
    return sucesso

# Execução direta
if __name__ == "__main__":
    # Caminho das provas
    pasta_origem = "../Etapa_3/Processamento/Provas"
    
    print("🔧 CÓPIA DE PASTA DE PROVAS")
    print("-" * 40)
    
    # Verificar se origem existe
    if not os.path.exists(pasta_origem):
        print(f"❌ Pasta não encontrada: {pasta_origem}")
        # Tentar outros caminhos
        outros_caminhos = [
            "../Etapa_2/Provas",
            "../Etapa_1/Provas", 
            "../dados/Provas",
            "./Provas"
        ]
        
        for caminho in outros_caminhos:
            if os.path.exists(caminho):
                pasta_origem = caminho
                print(f"✅ Encontrada em: {caminho}")
                break
        else:
            print("❌ Nenhuma pasta de provas encontrada!")
            exit(1)
    
    # Executar cópia
    sucesso = copiar_pasta_provas(pasta_origem)
    
    if sucesso:
        print("\n✨ CONCLUÍDO!")
        print("📁 Verifique: ls -la ./Dados_Provas_Arrumado/Provas")
    else:
        print("\n❌ FALHOU!")

# Para executar apenas a limpeza, descomente a linha abaixo:
# executar_apenas_limpeza()
# Out:
# 🔧 CÓPIA DE PASTA DE PROVAS
# ----------------------------------------
# 🚀 Copiando pasta de provas completa...
#    📁 Origem: ../Etapa_3/Processamento/Provas
#    📁 Destino: ./Provas
# 🗑️  Removendo pasta existente: ./Provas
# 📋 Copiando estrutura completa...
# ✅ Cópia concluída!
# 📊 Total de arquivos: 730
# 📊 Arquivos .data: 730
# 📁 Pasta criada em: /root/QuestionInsight/Etapa_5/Provas
#
# 🧹 Removendo níveis duplicados de pastas...
# 🔍 Analisando estrutura em: ./Provas
#
# 📊 LIMPEZA CONCLUÍDA:
#    ✅ Pastas duplicadas removidas: 0
#    ✅ Arquivos reorganizados: 0
#
# ✨ CONCLUÍDO!
# 📁 Verifique: ls -la ./Dados_Provas_Arrumado/Provas

# %% [markdown]
# # Reunir pastas iguais

# %%
import os
import shutil
import re
from pathlib import Path

def extrair_numeros(nome_pasta):
    """Extrai números válidos de um nome de pasta (evita anos e números muito grandes)"""
    # Busca por padrões comuns de numeração em pastas acadêmicas
    patterns = [
        r'\btp\s*(\d+)',           # tp 1, tp2, tp 01
        r'\bavaliacao\s*(\d+)',    # avaliacao 01, avaliacao 2
        r'\blab\s*(\d+)',          # lab 1, lab 2
        r'\bprova\s*(\d+)',        # prova 1, prova 2
        r'\btrabalho\s*.*?(\d+)',  # trabalho pratico 1
        r'^(\d+)\s*-',             # 01 -, 02 -
        r'\b(\d+)\s*-',            # tp 1 -, avaliacao 2 -
    ]
    
    nome_lower = nome_pasta.lower()
    
    # Tenta cada padrão
    for pattern in patterns:
        matches = re.findall(pattern, nome_lower)
        if matches:
            numeros = [int(m) for m in matches if int(m) <= 20]  # Limita a números razoáveis (≤20)
            if numeros:
                return max(numeros)
    
    # Como fallback, busca números isolados de 1-2 dígitos no início ou meio do nome
    # mas ignora anos (4 dígitos) e números muito grandes
    numeros = re.findall(r'\b(\d{1,2})\b', nome_lower)
    if numeros:
        numeros_validos = [int(n) for n in numeros if 1 <= int(n) <= 20]
        if numeros_validos:
            return max(numeros_validos)
    
    return None

def copiar_estrutura_base(origem, destino):
    """Copia a estrutura base mantendo apenas os dois primeiros níveis"""
    if os.path.exists(destino):
        shutil.rmtree(destino)
    
    # Cria a pasta raiz de destino
    os.makedirs(destino, exist_ok=True)
    
    # Percorre o primeiro nível (ex: "introducao a ciencia dos computadores")
    for item_nivel1 in os.listdir(origem):
        caminho_nivel1_origem = os.path.join(origem, item_nivel1)
        caminho_nivel1_destino = os.path.join(destino, item_nivel1)
        
        if os.path.isdir(caminho_nivel1_origem):
            os.makedirs(caminho_nivel1_destino, exist_ok=True)
            
            # Percorre o segundo nível (ex: "exam", "lab", etc.)
            for item_nivel2 in os.listdir(caminho_nivel1_origem):
                caminho_nivel2_origem = os.path.join(caminho_nivel1_origem, item_nivel2)
                caminho_nivel2_destino = os.path.join(caminho_nivel1_destino, item_nivel2)
                
                if os.path.isdir(caminho_nivel2_origem):
                    os.makedirs(caminho_nivel2_destino, exist_ok=True)

def organizar_subpastas_por_numero(origem, destino):
    """Organiza as subpastas de terceiro nível por números"""
    
    # Primeiro, copia a estrutura base
    copiar_estrutura_base(origem, destino)
    
    # Depois organiza as subpastas de terceiro nível
    for item_nivel1 in os.listdir(origem):
        caminho_nivel1_origem = os.path.join(origem, item_nivel1)
        caminho_nivel1_destino = os.path.join(destino, item_nivel1)
        
        if os.path.isdir(caminho_nivel1_origem):
            for item_nivel2 in os.listdir(caminho_nivel1_origem):
                caminho_nivel2_origem = os.path.join(caminho_nivel1_origem, item_nivel2)
                caminho_nivel2_destino = os.path.join(caminho_nivel1_destino, item_nivel2)
                
                if os.path.isdir(caminho_nivel2_origem):
                    # Processa as subpastas de terceiro nível
                    processar_nivel3(caminho_nivel2_origem, caminho_nivel2_destino)

def processar_nivel3(origem_nivel2, destino_nivel2):
    """Processa e organiza as pastas de terceiro nível"""
    
    # Dicionário para agrupar pastas por número
    pastas_por_numero = {}
    pastas_excecao = []
    
    # Classifica todas as pastas do terceiro nível
    for item_nivel3 in os.listdir(origem_nivel2):
        caminho_nivel3_origem = os.path.join(origem_nivel2, item_nivel3)
        
        if os.path.isdir(caminho_nivel3_origem):
            numero = extrair_numeros(item_nivel3)
            
            if numero is not None:
                if numero not in pastas_por_numero:
                    pastas_por_numero[numero] = []
                pastas_por_numero[numero].append((item_nivel3, caminho_nivel3_origem))
            else:
                pastas_excecao.append((item_nivel3, caminho_nivel3_origem))
        else:
            # Se for arquivo, copia diretamente
            shutil.copy2(caminho_nivel3_origem, destino_nivel2)
    
    # Cria as pastas organizadas por número
    for numero in sorted(pastas_por_numero.keys()):
        pasta_numero = os.path.join(destino_nivel2, f"Prova_{numero:02d}")
        os.makedirs(pasta_numero, exist_ok=True)
        
        for nome_pasta, caminho_origem in pastas_por_numero[numero]:
            caminho_destino = os.path.join(pasta_numero, nome_pasta)
            shutil.copytree(caminho_origem, caminho_destino)
            print(f"Movido: {nome_pasta} -> Prova_{numero:02d}")
    
    # Cria pasta de exceção se houver pastas sem número
    if pastas_excecao:
        pasta_excecao = os.path.join(destino_nivel2, "excecao")
        os.makedirs(pasta_excecao, exist_ok=True)
        
        for nome_pasta, caminho_origem in pastas_excecao:
            caminho_destino = os.path.join(pasta_excecao, nome_pasta)
            shutil.copytree(caminho_origem, caminho_destino)
            print(f"Movido para exceção: {nome_pasta}")

def main():
    """Função principal"""
    origem = "./Provas"
    destino = "./Provas_Arrumadas"
    
    if not os.path.exists(origem):
        print(f"Erro: A pasta '{origem}' não existe!")
        return
    
    try:
        print("Iniciando organização das pastas...")
        organizar_subpastas_por_numero(origem, destino)
        print(f"\nOrganização concluída! Verifique a pasta '{destino}'")
        
        # Mostra um resumo da organização
        mostrar_resumo(destino)
        
    except Exception as e:
        print(f"Erro durante a organização: {str(e)}")

def mostrar_resumo(destino):
    """Mostra um resumo da organização"""
    print("\n" + "="*50)
    print("RESUMO DA ORGANIZAÇÃO")
    print("="*50)
    
    for item_nivel1 in os.listdir(destino):
        caminho_nivel1 = os.path.join(destino, item_nivel1)
        if os.path.isdir(caminho_nivel1):
            print(f"\n📁 {item_nivel1}/")
            
            for item_nivel2 in os.listdir(caminho_nivel1):
                caminho_nivel2 = os.path.join(caminho_nivel1, item_nivel2)
                if os.path.isdir(caminho_nivel2):
                    print(f"  📁 {item_nivel2}/")
                    
                    grupos = [item for item in os.listdir(caminho_nivel2) 
                             if os.path.isdir(os.path.join(caminho_nivel2, item))]
                    
                    for grupo in sorted(grupos):
                        caminho_grupo = os.path.join(caminho_nivel2, grupo)
                        num_pastas = len([item for item in os.listdir(caminho_grupo) 
                                        if os.path.isdir(os.path.join(caminho_grupo, item))])
                        print(f"    📂 {grupo}/ ({num_pastas} pastas)")

if __name__ == "__main__":
    main()
# Out:
# Iniciando organização das pastas...
# Movido: trabalho pratico 1 -> Prova_01
# Movido: tp1 - variaveis e estrutura sequencial -> Prova_01
# Movido: tp01 - variaveis e estrutura sequencial -> Prova_01
# Movido: trabalho pratico 01 -> Prova_01
# Movido: lab 1 - variaveis e estrutura sequencial -> Prova_01
# Movido: tp 01 -> Prova_01
# Movido: tp1 -> Prova_01
# Movido: tp 1 -> Prova_01
# Movido: avaliacao 01 - variaveis e estrutura sequencial de programacao -> Prova_01
# Movido: tp 2 -> Prova_02
# Movido: tp 2 - condicionais compostos (ifelse) -> Prova_02
# Movido: trabalho pratico 02 - estrutura condicional simples e composta -> Prova_02
# Movido: avaliacao parcial 02 [grupo 2] – estrutura condicional composta (sem aninhamento) -> Prova_02
# Movido: tp02 - condicionais simples (ifelse) -> Prova_02
# Movido: trabalho pratico 02 - estrutura condicional simples e composta (ok) -> Prova_02
# Movido: tp2 -> Prova_02
# Movido: trabalho pratico 02 - estrutura condicional simples e composta (sem aninhamento) -> Prova_02
# Movido: tp 02 - condicionais simples (ifelse) -> Prova_02
# Movido: tp 02 – estrutura condicional composta -> Prova_02
# Movido: tp2 - estrutura condicional simples e composta -> Prova_02
# Movido: lab 2 – estrutura condicional -> Prova_02
# Movido: tp 2 - condicional simples e composta (ifelse) -> Prova_02
# Movido: tp 02 -> Prova_02
# Movido: tp 2 - condicionais simples (ifelse) -> Prova_02
# Movido: avaliacao parcial 02 – estrutura condicional composta (sem aninhamento) -> Prova_02
# Movido: tp3 - estrutura condicional encadeada -> Prova_03
# Movido: tp03 – condicionais encadeadas (ifelif) -> Prova_03
# Movido: avaliacao parcial 03 – estruturas condicionais encadeadas -> Prova_03
# Movido: tp 3 - condicionais encadeadas (ifelifelse) -> Prova_03
# Movido: tp 3 -> Prova_03
# Movido: tp 03 – condicionais encadeadas (ifelif) -> Prova_03
# Movido: tp 3 – condicionais encadeadas (ifelif) -> Prova_03
# Movido: trabalho pratico 03 - estrutura condicional encadeada -> Prova_03
# Movido: trabalho pratico 3 -> Prova_03
# Movido: avaliacao parcial 03– estrutura condicional encadeada (turmas de segunda) -> Prova_03
# Movido: tp3 -> Prova_03
# Movido: tp 04 -> Prova_04
# Movido: tp3 e tp4 - condicional e repeticao (while) (p) 2 -> Prova_04
# Movido: trabalho pratico 04 -> Prova_04
# Movido: tp3 e tp4 - condicional e repeticao (while) (p) -> Prova_04
# Movido: tp 4 -> Prova_04
# Movido: tp 04 - estrutura de repeticao (while) -> Prova_04
# Movido: tp4 -> Prova_04
# Movido: avaliacao parcial 04 – estrutura de repeticao por condicao (while) - versao olimpica d -> Prova_04
# Movido: tp3 e tp4 - condicional e repeticao (while) (g) -> Prova_04
# Movido: trabalho pratico 4 -> Prova_04
# Movido: avaliacao parcial 04 – estrutura de repeticao por condicao (while) -> Prova_04
# Movido: tp5 -> Prova_05
# Movido: tp 5 -> Prova_05
# Movido: avaliacao parcial 05 – vetores e strings -> Prova_05
# Movido: trabalho pratico 5 -> Prova_05
# Movido: trabalho pratico 05 -> Prova_05
# Movido: tp 05 -> Prova_05
# Movido: tp 06 - estrutura de repeticao por contagem (for) -> Prova_06
# Movido: trabalho pratico 06 – repeticao por contagem -> Prova_06
# Movido: tp 6 -> Prova_06
# Movido: tp6 -> Prova_06
# Movido: trabalho pratico 6 -> Prova_06
# Movido: tp 06 -> Prova_06
# Movido: trabalho pratico 06 - estrutura de repeticao por contagem (for) -> Prova_06
# Movido: avaliacao parcial 06 – repeticao por contagem -> Prova_06
# Movido para exceção: prova final 201902
# Movido para exceção: trabalho pratico substitutivo
# Movido para exceção: prova final
# Movido para exceção: tp substitutivo - eme01
# Movido para exceção: prova final 202202
# Movido para exceção: xxx
# Movido para exceção: prova final - mateus
# Movido para exceção: tp substitutivo
# Movido para exceção: tp substitutivo - epg01
# Movido: trabalho pratico 1 -> Prova_01
# Movido: tp01 - variaveis e estrutura sequencial -> Prova_01
# Movido: trabalho pratico 01 -> Prova_01
# Movido: tp 01 -> Prova_01
# Movido: tp. 01 - variaveis e estrutura sequencial -> Prova_01
# Movido: tp1 -> Prova_01
# Movido: tp 1 - variaveis e estrutura sequencial -> Prova_01
# Movido: avaliacao 01 - variaveis e estrutura sequencial -> Prova_01
# Movido: tp 1 -> Prova_01
# Movido: tp 2 -> Prova_02
# Movido: tp 2 - condicionais compostos (ifelse) -> Prova_02
# Movido: trabalho pratico 02 - estrutura condicional simples e composta -> Prova_02
# Movido: tp. 02 - condicionais compostos (ifelse) -> Prova_02
# Movido: tp2 -> Prova_02
# Movido: trabalho pratico 02 - estrutura condicional simples e composta (sem aninhamento) -> Prova_02
# Movido: tp2 - estrutura condicional simples e composta -> Prova_02
# Movido: tp 2 - condicional simples e composta (ifelse) -> Prova_02
# Movido: tp 02 -> Prova_02
# Movido: tp 2 - condicionais simples (ifelse) -> Prova_02
# Movido: avaliacao parcial 02 – estrutura condicional composta (sem aninhamento) -> Prova_02
# Movido: tp3 - estrutura condicional encadeada -> Prova_03
# Movido: avaliacao parcial 03– estrutura condicional encadeada -> Prova_03
# Movido: avaliacao parcial 03 – estruturas condicionais encadeadas -> Prova_03
# Movido: tp 3 - condicionais encadeadas (ifelifelse) -> Prova_03
# Movido: tp 3 -> Prova_03
# Movido: tp 03 – condicionais encadeadas (ifelif) -> Prova_03
# Movido: tp 3 – condicionais encadeadas (ifelif) -> Prova_03
# Movido: trabalho pratico 03 - estrutura condicional encadeada -> Prova_03
# Movido: trabalho pratico 3 -> Prova_03
# Movido: tp3 -> Prova_03
# Movido: tp 04 -> Prova_04
# Movido: trabalho pratico 04 -> Prova_04
# Movido: tp3 e tp4 - condicional e repeticao (while) (p) -> Prova_04
# Movido: tp 4 -> Prova_04
# Movido: tp4 -> Prova_04
# Movido: trabalho pratico 4 -> Prova_04
# Movido: avaliacao parcial 04 – estrutura de repeticao por condicao (while) -> Prova_04
# Movido: tp5 -> Prova_05
# Movido: tp 5 -> Prova_05
# Movido: avaliacao parcial 05 – vetores e strings -> Prova_05
# Movido: trabalho pratico 5 -> Prova_05
# Movido: trabalho pratico 05 -> Prova_05
# Movido: tp 05 -> Prova_05
# Movido: trabalho pratico 06 – repeticao por contagem -> Prova_06
# Movido: tp 6 -> Prova_06
# Movido: tp6 -> Prova_06
# Movido: trabalho pratico 6 -> Prova_06
# Movido: trabalho pratico 06 - estrutura de repeticao por contagem (for) -> Prova_06
# Movido: avaliacao parcial 06 – repeticao por contagem -> Prova_06
# Movido para exceção: trabalho pratico substitutivo
# Movido para exceção: tp
# Movido para exceção: prova final - segunda chamada
# Movido para exceção: prova final
# Movido para exceção: tp substitutivo
#
# Organização concluída! Verifique a pasta './Provas_Arrumadas'
#
# ==================================================
# RESUMO DA ORGANIZAÇÃO
# ==================================================
#
# 📁 introducao a programacao de computadores/
#   📁 exam/
#     📂 Prova_01/ (9 pastas)
#     📂 Prova_02/ (16 pastas)
#     📂 Prova_03/ (11 pastas)
#     📂 Prova_04/ (11 pastas)
#     📂 Prova_05/ (6 pastas)
#     📂 Prova_06/ (8 pastas)
#     📂 excecao/ (9 pastas)
#
# 📁 introducao a ciencia dos computadores/
#   📁 exam/
#     📂 Prova_01/ (9 pastas)
#     📂 Prova_02/ (11 pastas)
#     📂 Prova_03/ (10 pastas)
#     📂 Prova_04/ (7 pastas)
#     📂 Prova_05/ (6 pastas)
#     📂 Prova_06/ (6 pastas)
#     📂 excecao/ (5 pastas)

# %% [markdown]
# # Análise dos dados

# %%
Dados_Provas = "./Provas_Arrumadas"
Dados_Questoes = "questions_D_M.csv"

# %%
import os
import pandas as pd
import glob
from pathlib import Path
import re
import json

# Configuração dos caminhos
Dados_Provas = "../Etapa_3/Processamento/Provas"
Dados_Questoes = "misconceptions_summary_por_questao.csv"

def extrair_info_arquivo_data(caminho_arquivo):
    """
    Extrai informações do arquivo .data
    """
    info = {}
    
    try:
        with open(caminho_arquivo, 'r', encoding='utf-8') as f:
            conteudo = f.read()
        
        # Extrair informações básicas
        patterns = {
            'assessment_title': r'assessment title:\s*(.+)',
            'class_name': r'class name:\s*(.+)',
            'class_number': r'class number:\s*(\d+)',
            'start': r'start:\s*(.+)',
            'end': r'end:\s*(.+)',
            'language': r'language:\s*(.+)',
            'type': r'type:\s*(.+)',
            'weight': r'weight:\s*(\d+)',
            'total_exercises': r'total_exercises:\s*(\d+)'
        }
        
        for key, pattern in patterns.items():
            match = re.search(pattern, conteudo, re.IGNORECASE)
            if match:
                info[key] = match.group(1).strip()
        
        # Extrair exercícios
        exercises_pattern = r'exercise (\d+):\s*(.+)'
        exercises = re.findall(exercises_pattern, conteudo, re.IGNORECASE)
        
        info['exercises'] = {}
        for ex_num, ex_content in exercises:
            questoes = [q.strip() for q in ex_content.split(' or ')]
            info['exercises'][f'exercise_{ex_num}'] = questoes
            
        return info
        
    except Exception as e:
        print(f"Erro ao processar {caminho_arquivo}: {e}")
        return None

def mapear_estrutura_provas():
    """
    Mapeia toda a estrutura de provas, módulos e questões
    """
    mapeamento = {}
    arquivos_processados = []
    arquivos_ignorados = []
    
    print("🔍 Debug: Explorando estrutura de diretórios...")
    
    # Percorrer toda a estrutura de diretórios
    for root, dirs, files in os.walk(Dados_Provas):
        # MODIFICAÇÃO: Verificar se o caminho atual contém pasta "excecao"
        partes_caminho_root = Path(root).parts
        
        # Verificar se "excecao" está no caminho (case insensitive)
        if any(parte.lower() == 'excecao' for parte in partes_caminho_root):
            # Ignorar esta pasta e todos os seus arquivos
            for file in files:
                if file.endswith('.data'):
                    arquivos_ignorados.append(os.path.join(root, file))
            print(f"   🚫 Ignorando pasta de exceção: {root}")
            continue
        
        # MODIFICAÇÃO: Remover pastas "excecao" da lista de diretórios a serem explorados
        dirs[:] = [d for d in dirs if d.lower() != 'excecao']
        
        for file in files:
            if file.endswith('.data'):
                caminho_completo = os.path.join(root, file)
                arquivos_processados.append(caminho_completo)
                
                # Extrair informações do caminho de forma mais robusta
                partes_caminho = Path(caminho_completo).parts
                print(f"   📁 Processando: {' → '.join(partes_caminho[-4:])}")
                
                # Estratégia melhorada para identificar módulo e prova
                modulo = None
                prova = None
                
                # Buscar por padrões conhecidos de módulos
                for i, parte in enumerate(partes_caminho):
                    parte_lower = parte.lower()
                    
                    # Identificar módulos
                    if any(keyword in parte_lower for keyword in ['introducao', 'programacao', 'algoritmos', 'estrutura']):
                        modulo = parte
                        
                        # Buscar a prova nas partes seguintes
                        for j in range(i + 1, len(partes_caminho) - 1):  # -1 para excluir o arquivo
                            if partes_caminho[j] not in ['exam', 'test', 'avaliacao']:
                                if any(keyword in partes_caminho[j].lower() for keyword in ['avaliacao', 'prova', 'tp', 'parcial', 'final']):
                                    prova = partes_caminho[j]
                                    break
                        
                        # Se não encontrou prova, usar a pasta pai do arquivo
                        if not prova and len(partes_caminho) > 1:
                            prova = partes_caminho[-2]
                        
                        break
                
                # Fallback: usar as últimas duas pastas como módulo e prova
                if not modulo and len(partes_caminho) >= 3:
                    modulo = partes_caminho[-3]
                    prova = partes_caminho[-2]
                
                print(f"      🏷️  Módulo: {modulo} | Prova: {prova}")
                
                if modulo and prova:
                    info_arquivo = extrair_info_arquivo_data(caminho_completo)
                    
                    if info_arquivo:
                        if modulo not in mapeamento:
                            mapeamento[modulo] = {}
                        
                        if prova not in mapeamento[modulo]:
                            mapeamento[modulo][prova] = {}
                        
                        arquivo_id = file.replace('.data', '')
                        mapeamento[modulo][prova][arquivo_id] = {
                            'caminho': caminho_completo,
                            'info': info_arquivo
                        }
                    else:
                        print(f"      ⚠️  Erro ao extrair info do arquivo: {file}")
                else:
                    print(f"      ❌ Não foi possível identificar módulo/prova para: {caminho_completo}")
    
    print(f"\n📊 Total de arquivos .data encontrados: {len(arquivos_processados)}")
    print(f"🚫 Total de arquivos .data ignorados (pasta 'excecao'): {len(arquivos_ignorados)}")
    print(f"📊 Módulos mapeados: {len(mapeamento)}")
    
    # Debug: mostrar estrutura mapeada
    for mod, provas in mapeamento.items():
        print(f"   🔹 {mod}: {len(provas)} prova(s)")
        for prova, arquivos in provas.items():
            print(f"      📋 {prova}: {len(arquivos)} arquivo(s)")
    
    # MODIFICAÇÃO: Mostrar alguns exemplos de arquivos ignorados se houver
    if arquivos_ignorados:
        print(f"\n🚫 Exemplos de arquivos ignorados (pasta 'excecao'):")
        for arquivo in arquivos_ignorados[:5]:  # Mostrar apenas os primeiros 5
            print(f"   - {arquivo}")
        if len(arquivos_ignorados) > 5:
            print(f"   ... e mais {len(arquivos_ignorados) - 5} arquivo(s)")
    
    return mapeamento

def carregar_dados_questoes():
    """
    Carrega dados das questões do arquivo CSV
    """
    try:
        df_questoes = pd.read_csv(Dados_Questoes)
        print(f"   📋 Colunas encontradas: {list(df_questoes.columns)}")
        return df_questoes
    except Exception as e:
        print(f"Erro ao carregar dados de questões: {e}")
        return None

def criar_mapeamento_questao_prova(mapeamento_provas):
    """
    Cria um mapeamento entre questões e provas
    """
    questao_para_prova = {}
    estatisticas = {
        'total_questoes_mapeadas': 0,
        'arquivos_sem_exercises': 0,
        'questoes_duplicadas': 0
    }
    
    print("🔗 Debug: Criando mapeamento questão-prova...")
    
    for modulo, provas in mapeamento_provas.items():
        print(f"   🔹 Processando módulo: {modulo}")
        
        for prova, arquivos in provas.items():
            print(f"      📋 Processando prova: {prova}")
            
            for arquivo_id, dados in arquivos.items():
                exercises = dados['info'].get('exercises', {})
                
                if not exercises:
                    estatisticas['arquivos_sem_exercises'] += 1
                    print(f"         ⚠️  Arquivo sem exercícios: {arquivo_id}")
                    continue
                
                print(f"         📄 Arquivo: {arquivo_id} - {len(exercises)} exercício(s)")
                
                for exercise_key, questoes in exercises.items():
                    print(f"            🔸 {exercise_key}: {len(questoes)} questão(ões)")
                    
                    for question in questoes:
                        question_clean = str(question).strip()
                        
                        # Verificar duplicatas
                        if question_clean in questao_para_prova:
                            estatisticas['questoes_duplicadas'] += 1
                            print(f"               ⚠️  Questão duplicada: {question_clean}")
                        
                        questao_para_prova[question_clean] = {
                            'modulo': modulo,
                            'prova': prova,
                            'arquivo': arquivo_id,
                            'exercise': exercise_key,
                            'assessment_title': dados['info'].get('assessment_title', 'N/A'),
                            'class_name': dados['info'].get('class_name', 'N/A')
                        }
                        
                        estatisticas['total_questoes_mapeadas'] += 1
    
    print(f"\n📊 Estatísticas do mapeamento:")
    print(f"   ✅ Total questões mapeadas: {estatisticas['total_questoes_mapeadas']}")
    print(f"   ⚠️  Arquivos sem exercícios: {estatisticas['arquivos_sem_exercises']}")
    print(f"   🔄 Questões duplicadas: {estatisticas['questoes_duplicadas']}")
    
    return questao_para_prova

def analisar_desempenho_geral(df_questoes, questao_para_prova):
    """
    Análise de desempenho geral por módulos e provas
    """
    resultados = {}
    
    print("📈 Debug: Analisando desempenho...")
    print(f"   📊 Questões no CSV: {len(df_questoes)}")
    print(f"   🔗 Questões mapeadas: {len(questao_para_prova)}")
    
    # CORREÇÃO: Usar 'question' ao invés de 'question'
    coluna_id = 'question' if 'question' in df_questoes.columns else 'question'
    print(f"   🔑 Usando coluna: {coluna_id}")
    
    # Adicionar informações de mapeamento ao DataFrame
    df_questoes['question_str'] = df_questoes[coluna_id].astype(str)
    
    # Contar quantas questões foram mapeadas com sucesso
    questoes_encontradas = 0
    questoes_nao_encontradas = []
    
    def map_field(question, field, default='Não Mapeado'):
        nonlocal questoes_encontradas
        questao_str = str(question)
        if questao_str in questao_para_prova:
            if field == 'encontrada':
                questoes_encontradas += 1
            return questao_para_prova[questao_str].get(field, default)
        else:
            if field == 'modulo':
                questoes_nao_encontradas.append(questao_str)
            return default
    
    df_questoes['modulo'] = df_questoes['question_str'].apply(lambda x: map_field(x, 'modulo'))
    df_questoes['prova'] = df_questoes['question_str'].apply(lambda x: map_field(x, 'prova'))
    df_questoes['assessment_title'] = df_questoes['question_str'].apply(lambda x: map_field(x, 'assessment_title'))
    df_questoes['arquivo'] = df_questoes['question_str'].apply(lambda x: map_field(x, 'arquivo'))
    df_questoes['exercise'] = df_questoes['question_str'].apply(lambda x: map_field(x, 'exercise'))
    
    print(f"   ✅ Questões do CSV encontradas no mapeamento: {questoes_encontradas}")
    print(f"   ❌ Questões não encontradas: {len(questoes_nao_encontradas)}")
    
    if len(questoes_nao_encontradas) <= 10:
        print(f"      Exemplos de questões não mapeadas: {questoes_nao_encontradas[:10]}")
    
    # Análise por módulo
    resultados['por_modulo'] = {}
    modulos_validos = df_questoes[df_questoes['modulo'] != 'Não Mapeado']
    
    print(f"   📚 Módulos encontrados nos dados: {modulos_validos['modulo'].unique().tolist()}")
    
    for modulo in modulos_validos['modulo'].unique():
        df_modulo = df_questoes[df_questoes['modulo'] == modulo]
        
        # Função auxiliar para calcular métricas
        def calc_metric(column, operation='mean'):
            if column in df_modulo.columns and not df_modulo[column].isna().all():
                if operation == 'mean':
                    return df_modulo[column].mean()
                elif operation == 'sum':
                    return df_modulo[column].sum()
            return None
        
        # Calcular taxa de sucesso apenas onde há dados válidos
        taxa_sucesso = None
        if 'num_correct' in df_modulo.columns and 'num_tests' in df_modulo.columns:
            df_valido = df_modulo[(df_modulo['num_tests'] > 0) & 
                                  (df_modulo['num_correct'].notna()) & 
                                  (df_modulo['num_tests'].notna())]
            if len(df_valido) > 0:
                taxa_sucesso = (df_valido['num_correct'] / df_valido['num_tests']).mean()
        
        resultados['por_modulo'][modulo] = {
            'total_questoes': len(df_modulo),
            'questoes_mapeadas': len(df_modulo[df_modulo['modulo'] != 'Não Mapeado']),
            'dificuldade_media': calc_metric('dificuldade'),
            'discriminacao_media': calc_metric('discriminacao'),
            'tempo_medio_implementacao': calc_metric('tempo_implementacao'),
            'taxa_sucesso_media': taxa_sucesso,
            'erros_sintaxe_media': calc_metric('num_syntax_errors'),
            'erros_logica_media': calc_metric('num_logic_errors'),
            'total_submissoes': calc_metric('num_submissoes', 'sum'),
            'total_testes': calc_metric('num_tests', 'sum'),
            'provas_associadas': df_modulo['prova'].unique().tolist()
        }
    
    # Análise por prova
    resultados['por_prova'] = {}
    provas_validas = df_questoes[df_questoes['prova'] != 'Não Mapeado']
    
    print(f"   📋 Provas encontradas nos dados: {len(provas_validas['prova'].unique())}")
    
    for prova in provas_validas['prova'].unique():
        df_prova = df_questoes[df_questoes['prova'] == prova]
        
        # Função auxiliar para calcular métricas
        def calc_metric(column, operation='mean'):
            if column in df_prova.columns and not df_prova[column].isna().all():
                if operation == 'mean':
                    return df_prova[column].mean()
                elif operation == 'sum':
                    return df_prova[column].sum()
            return None
        
        # Calcular taxa de sucesso
        taxa_sucesso = None
        if 'num_correct' in df_prova.columns and 'num_tests' in df_prova.columns:
            df_valido = df_prova[(df_prova['num_tests'] > 0) & 
                                (df_prova['num_correct'].notna()) & 
                                (df_prova['num_tests'].notna())]
            if len(df_valido) > 0:
                taxa_sucesso = (df_valido['num_correct'] / df_valido['num_tests']).mean()
        
        resultados['por_prova'][prova] = {
            'modulo': df_prova['modulo'].iloc[0] if len(df_prova) > 0 else 'N/A',
            'assessment_title': df_prova['assessment_title'].iloc[0] if len(df_prova) > 0 else 'N/A',
            'total_questoes': len(df_prova),
            'dificuldade_media': calc_metric('dificuldade'),
            'discriminacao_media': calc_metric('discriminacao'),
            'tempo_medio_implementacao': calc_metric('tempo_implementacao'),
            'taxa_sucesso_media': taxa_sucesso,
            'arquivos_associados': df_prova['arquivo'].unique().tolist()
        }
    
    return resultados, df_questoes

def gerar_relatorio(resultados, df_questoes_enriquecido):
    """
    Gera relatório detalhado da análise
    """
    print("="*80)
    print("RELATÓRIO DE ANÁLISE DE DESEMPENHO - MÓDULOS E PROVAS")
    print("="*80)
    
    # Estatísticas gerais
    total_questoes = len(df_questoes_enriquecido)
    questoes_mapeadas = len(df_questoes_enriquecido[df_questoes_enriquecido['modulo'] != 'Não Mapeado'])
    
    print(f"\n📊 ESTATÍSTICAS GERAIS")
    print(f"   • Total de questões no dataset: {total_questoes}")
    print(f"   • Questões mapeadas com sucesso: {questoes_mapeadas} ({questoes_mapeadas/total_questoes:.1%})")
    print(f"   • Questões não mapeadas: {total_questoes - questoes_mapeadas}")
    
    # Análise por Módulo
    print("\n📚 ANÁLISE POR MÓDULO")
    print("-"*50)
    
    for modulo, dados in resultados['por_modulo'].items():
        if modulo != 'Não Mapeado':
            print(f"\n🔹 {modulo.upper()}")
            print(f"   📊 Total de questões: {dados['total_questoes']}")
            
            if dados.get('provas_associadas'):
                print(f"   📋 Provas associadas: {', '.join(dados['provas_associadas'])}")
            
            if dados['dificuldade_media'] is not None:
                print(f"   🎯 Dificuldade média: {dados['dificuldade_media']:.3f}")
            
            if dados['discriminacao_media'] is not None:
                print(f"   📈 Discriminação média: {dados['discriminacao_media']:.3f}")
            
            if dados['tempo_medio_implementacao'] is not None:
                print(f"   ⏱️  Tempo médio de implementação: {dados['tempo_medio_implementacao']:.2f}")
            
            if dados['taxa_sucesso_media'] is not None:
                print(f"   ✅ Taxa de sucesso média: {dados['taxa_sucesso_media']:.2%}")
            
            if dados['erros_sintaxe_media'] is not None:
                print(f"   🔧 Erros de sintaxe (média): {dados['erros_sintaxe_media']:.2f}")
            
            if dados['erros_logica_media'] is not None:
                print(f"   🧠 Erros de lógica (média): {dados['erros_logica_media']:.2f}")
            
            if dados.get('total_submissoes') is not None:
                print(f"   📤 Total de submissões: {dados['total_submissoes']:.0f}")
            
            if dados.get('total_testes') is not None:
                print(f"   🧪 Total de testes executados: {dados['total_testes']:.0f}")
    
    # Análise por Prova
    print("\n\n📋 ANÁLISE POR PROVA")
    print("-"*50)
    
    # Agrupar provas por módulo para melhor organização
    provas_por_modulo = {}
    for prova, dados in resultados['por_prova'].items():
        modulo = dados['modulo']
        if modulo not in provas_por_modulo:
            provas_por_modulo[modulo] = {}
        provas_por_modulo[modulo][prova] = dados
    
    for modulo, provas in provas_por_modulo.items():
        if modulo != 'Não Mapeado':
            print(f"\n📚 {modulo.upper()}")
            
            for prova, dados in provas.items():
                print(f"\n   🔸 {dados['assessment_title']}")
                print(f"      📁 Código da prova: {prova}")
                print(f"      📊 Total de questões: {dados['total_questoes']}")
                
                if dados.get('arquivos_associados'):
                    print(f"      📄 Arquivos: {', '.join(dados['arquivos_associados'])}")
                
                if dados['dificuldade_media'] is not None:
                    print(f"      🎯 Dificuldade média: {dados['dificuldade_media']:.3f}")
                
                if dados['discriminacao_media'] is not None:
                    print(f"      📈 Discriminação média: {dados['discriminacao_media']:.3f}")
                
                if dados['tempo_medio_implementacao'] is not None:
                    print(f"      ⏱️  Tempo médio: {dados['tempo_medio_implementacao']:.2f}")
                
                if dados['taxa_sucesso_media'] is not None:
                    print(f"      ✅ Taxa de sucesso: {dados['taxa_sucesso_media']:.2%}")
    
    # Resumo de questões não mapeadas
    questoes_nao_mapeadas = df_questoes_enriquecido[df_questoes_enriquecido['modulo'] == 'Não Mapeado']
    if len(questoes_nao_mapeadas) > 0:
        print(f"\n\n⚠️  QUESTÕES NÃO MAPEADAS: {len(questoes_nao_mapeadas)}")
        print("-"*50)
        
        # CORREÇÃO: Usar coluna correta
        coluna_id = 'question' if 'question' in questoes_nao_mapeadas.columns else 'question'
        print(f"Exemplos: {questoes_nao_mapeadas[coluna_id].head(10).tolist()}")
        
        # Sugestões para melhorar o mapeamento
        print(f"\n💡 SUGESTÕES PARA MELHORAR O MAPEAMENTO:")
        print(f"   • Verificar se todos os arquivos .data têm a seção 'EXERCISES'")
        print(f"   • Confirmar formato das questões nos arquivos .data")
        print(f"   • Verificar correspondência entre IDs das questões")

def executar_analise_completa():
    """
    Executa a análise completa
    """
    print("🚀 Iniciando análise completa...")
    
    # 1. Mapear estrutura de provas
    print("📁 Mapeando estrutura de provas...")
    mapeamento_provas = mapear_estrutura_provas()
    
    total_modulos = len(mapeamento_provas)
    total_provas = sum(len(provas) for provas in mapeamento_provas.values())
    total_arquivos = sum(len(arquivos) for provas in mapeamento_provas.values() 
                        for arquivos in provas.values())
    
    print(f"\n📊 RESUMO DA ESTRUTURA MAPEADA:")
    print(f"   🔹 Módulos encontrados: {total_modulos}")
    print(f"   📋 Provas encontradas: {total_provas}")
    print(f"   📄 Arquivos .data processados: {total_arquivos}")
    
    # 2. Carregar dados das questões
    print("\n📊 Carregando dados das questões...")
    df_questoes = carregar_dados_questoes()
    
    if df_questoes is None:
        print("❌ Erro: Não foi possível carregar os dados das questões")
        return
    
    print(f"   Carregadas {len(df_questoes)} questões do arquivo CSV")
    print(f"   📋 Colunas disponíveis: {list(df_questoes.columns)[:10]}{'...' if len(df_questoes.columns) > 10 else ''}")
    
    # 3. Criar mapeamento questão-prova
    print("\n🔗 Criando mapeamento questão-prova...")
    questao_para_prova = criar_mapeamento_questao_prova(mapeamento_provas)
    
    # 4. Analisar desempenho
    print("\n📈 Analisando desempenho...")
    resultados, df_enriquecido = analisar_desempenho_geral(df_questoes, questao_para_prova)
    
    # 5. Gerar relatório
    print("\n📋 Gerando relatório...")
    gerar_relatorio(resultados, df_enriquecido)
    
    # 6. Salvar resultados
    print("\n💾 Salvando resultados...")

    # Criar pasta de saída
    pasta_saida = "relacao_assunto_questoes"
    os.makedirs(pasta_saida, exist_ok=True)
    
    try:
        # Salvar DataFrame enriquecido
        df_enriquecido.to_csv(os.path.join(pasta_saida, 'dados_questoes_enriquecidos.csv'), index=False)
        print(f"   ✅ Dados enriquecidos salvos em: {os.path.join(pasta_saida, 'dados_questoes_enriquecidos.csv')}")
        
        # Salvar mapeamento
        with open(os.path.join(pasta_saida, 'mapeamento_questao_prova.json'), 'w', encoding='utf-8') as f:
            json.dump(questao_para_prova, f, indent=2, ensure_ascii=False)
        print(f"   ✅ Mapeamento salvo em: {os.path.join(pasta_saida, 'mapeamento_questao_prova.json')}")
        
        # Salvar estrutura completa
        estrutura_completa = {
            'mapeamento_provas': mapeamento_provas,
            'estatisticas': {
                'total_modulos': total_modulos,
                'total_provas': total_provas,
                'total_arquivos': total_arquivos,
                'questoes_csv': len(df_questoes),
                'questoes_mapeadas': len([q for q in df_enriquecido['modulo'] if q != 'Não Mapeado'])
            }
        }
        
        with open(os.path.join(pasta_saida, 'estrutura_completa.json'), 'w', encoding='utf-8') as f:
            json.dump(estrutura_completa, f, indent=2, ensure_ascii=False, default=str)
        print(f"   ✅ Estrutura completa salva em: {os.path.join(pasta_saida, 'estrutura_completa.json')}")
        
    except Exception as e:
        print(f"   ⚠️  Erro ao salvar arquivos: {e}")
    
    print("\n✨ Análise completa finalizada!")
    print(f"\n📋 RESUMO FINAL:")
    print(f"   🎯 Taxa de mapeamento: {len([q for q in df_enriquecido['modulo'] if q != 'Não Mapeado'])/len(df_questoes):.1%}")
    print(f"   📚 Módulos com dados: {len([m for m in resultados['por_modulo'] if m != 'Não Mapeado'])}")
    print(f"   📋 Provas com dados: {len([p for p in resultados['por_prova']])}")
    
    return {
        'mapeamento_provas': mapeamento_provas,
        'questao_para_prova': questao_para_prova,
        'resultados': resultados,
        'df_enriquecido': df_enriquecido
    }

# Executar análise
if __name__ == "__main__":
    dados_completos = executar_analise_completa()
# Out:
# 🚀 Iniciando análise completa...
# 📁 Mapeando estrutura de provas...
# 🔍 Debug: Explorando estrutura de diretórios...
#    📁 Processando: introducao a programacao de computadores → exam → prova final 201902 → 3863.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final 201902
#    📁 Processando: introducao a programacao de computadores → exam → prova final 201902 → 3861.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final 201902
#    📁 Processando: introducao a programacao de computadores → exam → prova final 201902 → 3867.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final 201902
#    📁 Processando: introducao a programacao de computadores → exam → prova final 201902 → 3864.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final 201902
#    📁 Processando: introducao a programacao de computadores → exam → prova final 201902 → 3871.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final 201902
#    📁 Processando: introducao a programacao de computadores → exam → prova final 201902 → 3870.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final 201902
#    📁 Processando: introducao a programacao de computadores → exam → tp 04 → 3601.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 04
#    📁 Processando: introducao a programacao de computadores → exam → tp 04 → 5113.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 04
#    📁 Processando: introducao a programacao de computadores → exam → tp 04 → 5070.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 04
#    📁 Processando: introducao a programacao de computadores → exam → tp 04 → 3629.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 04
#    📁 Processando: introducao a programacao de computadores → exam → tp 04 → 3604.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 04
#    📁 Processando: introducao a programacao de computadores → exam → tp 04 → 4673.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 04
#    📁 Processando: introducao a programacao de computadores → exam → tp 04 → 4112.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 04
#    📁 Processando: introducao a programacao de computadores → exam → tp 04 → 4126.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 04
#    📁 Processando: introducao a programacao de computadores → exam → tp 04 → 4677.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 04
#    📁 Processando: introducao a programacao de computadores → exam → tp 04 → 5069.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 04
#    📁 Processando: introducao a programacao de computadores → exam → tp 04 → 5068.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 04
#    📁 Processando: introducao a programacao de computadores → exam → tp 04 → 4682.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 04
#    📁 Processando: introducao a programacao de computadores → exam → tp 04 → 3602.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 04
#    📁 Processando: introducao a programacao de computadores → exam → tp 04 → 3605.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 04
#    📁 Processando: introducao a programacao de computadores → exam → tp 04 → 3627.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 04
#    📁 Processando: introducao a programacao de computadores → exam → tp 04 → 5071.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 04
#    📁 Processando: introducao a programacao de computadores → exam → tp 04 → 1189.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 04
#    📁 Processando: introducao a programacao de computadores → exam → tp 04 → 4154.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 04
#    📁 Processando: introducao a programacao de computadores → exam → tp 04 → 4137.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 04
#    📁 Processando: introducao a programacao de computadores → exam → tp 04 → 4671.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 04
#    📁 Processando: introducao a programacao de computadores → exam → tp 04 → 4135.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 04
#    📁 Processando: introducao a programacao de computadores → exam → tp 04 → 3625.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 04
#    📁 Processando: introducao a programacao de computadores → exam → tp 04 → 4672.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 04
#    📁 Processando: introducao a programacao de computadores → exam → tp 04 → 4704.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 04
#    📁 Processando: introducao a programacao de computadores → exam → tp 06 - estrutura de repeticao por contagem (for) → 1255.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 06 - estrutura de repeticao por contagem (for)
#    📁 Processando: introducao a programacao de computadores → exam → tp 06 - estrutura de repeticao por contagem (for) → 1262.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 06 - estrutura de repeticao por contagem (for)
#    📁 Processando: introducao a programacao de computadores → exam → tp3 - estrutura condicional encadeada → 1709.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp3 - estrutura condicional encadeada
#    📁 Processando: introducao a programacao de computadores → exam → tp3 - estrutura condicional encadeada → 1718.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp3 - estrutura condicional encadeada
#    📁 Processando: introducao a programacao de computadores → exam → tp3 - estrutura condicional encadeada → 1708.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp3 - estrutura condicional encadeada
#    📁 Processando: introducao a programacao de computadores → exam → tp3 - estrutura condicional encadeada → 1715.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp3 - estrutura condicional encadeada
#    📁 Processando: introducao a programacao de computadores → exam → tp3 - estrutura condicional encadeada → 1721.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp3 - estrutura condicional encadeada
#    📁 Processando: introducao a programacao de computadores → exam → trabalho pratico 06 – repeticao por contagem → 980.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: trabalho pratico 06 – repeticao por contagem
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 4822.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 3784.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 5935.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 3783.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 5904.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 5532.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 5945.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 1263.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 4240.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 5941.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 4793.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 4239.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 5158.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 5527.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 4832.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 4802.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 3780.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 3779.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 4242.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 5528.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 5162.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 5531.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 5164.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 1269.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 3778.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 4258.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 3782.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 1540.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 3777.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 5923.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 5170.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 4797.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 5537.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 4208.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 5921.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 5177.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → tp 6 → 1527.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 6
#    📁 Processando: introducao a programacao de computadores → exam → trabalho pratico 1 → 270.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: trabalho pratico 1
#    📁 Processando: introducao a programacao de computadores → exam → tp1 - variaveis e estrutura sequencial → 1053.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp1 - variaveis e estrutura sequencial
#    📁 Processando: introducao a programacao de computadores → exam → tp3 e tp4 - condicional e repeticao (while) (p) 2 → 3164.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp3 e tp4 - condicional e repeticao (while) (p) 2
#    📁 Processando: introducao a programacao de computadores → exam → tp 2 → 5718.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 2
#    📁 Processando: introducao a programacao de computadores → exam → tp 2 → 5299.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 2
#    📁 Processando: introducao a programacao de computadores → exam → tp 2 → 5297.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 2
#    📁 Processando: introducao a programacao de computadores → exam → tp 2 → 5706.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 2
#    📁 Processando: introducao a programacao de computadores → exam → tp 2 → 5704.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 2
#    📁 Processando: introducao a programacao de computadores → exam → tp 2 → 5311.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 2
#    📁 Processando: introducao a programacao de computadores → exam → tp 2 → 5719.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 2
#    📁 Processando: introducao a programacao de computadores → exam → tp 2 → 5309.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 2
#    📁 Processando: introducao a programacao de computadores → exam → tp 2 → 5307.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 2
#    📁 Processando: introducao a programacao de computadores → exam → tp 2 → 5698.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 2
#    📁 Processando: introducao a programacao de computadores → exam → tp 2 → 5697.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 2
#    📁 Processando: introducao a programacao de computadores → exam → trabalho pratico 04 → 626.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: trabalho pratico 04
#    📁 Processando: introducao a programacao de computadores → exam → trabalho pratico 04 → 314.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: trabalho pratico 04
#    📁 Processando: introducao a programacao de computadores → exam → trabalho pratico 04 → 627.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: trabalho pratico 04
#    📁 Processando: introducao a programacao de computadores → exam → trabalho pratico 04 → 328.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: trabalho pratico 04
#    📁 Processando: introducao a programacao de computadores → exam → tp5 → 3192.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp5
#    📁 Processando: introducao a programacao de computadores → exam → tp5 → 3717.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp5
#    📁 Processando: introducao a programacao de computadores → exam → tp5 → 1785.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp5
#    📁 Processando: introducao a programacao de computadores → exam → tp5 → 3732.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp5
#    📁 Processando: introducao a programacao de computadores → exam → tp5 → 1795.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp5
#    📁 Processando: introducao a programacao de computadores → exam → tp5 → 3716.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp5
#    📁 Processando: introducao a programacao de computadores → exam → tp5 → 3202.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp5
#    📁 Processando: introducao a programacao de computadores → exam → tp5 → 1796.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp5
#    📁 Processando: introducao a programacao de computadores → exam → tp5 → 3197.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp5
#    📁 Processando: introducao a programacao de computadores → exam → tp5 → 3715.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp5
#    📁 Processando: introducao a programacao de computadores → exam → tp5 → 3201.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp5
#    📁 Processando: introducao a programacao de computadores → exam → tp5 → 3719.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp5
#    📁 Processando: introducao a programacao de computadores → exam → tp5 → 3205.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp5
#    📁 Processando: introducao a programacao de computadores → exam → tp5 → 3200.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp5
#    📁 Processando: introducao a programacao de computadores → exam → tp5 → 1793.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp5
#    📁 Processando: introducao a programacao de computadores → exam → tp5 → 3248.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp5
#    📁 Processando: introducao a programacao de computadores → exam → tp5 → 1791.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp5
#    📁 Processando: introducao a programacao de computadores → exam → tp5 → 3736.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp5
#    📁 Processando: introducao a programacao de computadores → exam → tp5 → 3734.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp5
#    📁 Processando: introducao a programacao de computadores → exam → tp5 → 3199.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp5
#    📁 Processando: introducao a programacao de computadores → exam → tp01 - variaveis e estrutura sequencial → 1058.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp01 - variaveis e estrutura sequencial
#    📁 Processando: introducao a programacao de computadores → exam → tp01 - variaveis e estrutura sequencial → 1062.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp01 - variaveis e estrutura sequencial
#    📁 Processando: introducao a programacao de computadores → exam → tp01 - variaveis e estrutura sequencial → 1060.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp01 - variaveis e estrutura sequencial
#    📁 Processando: introducao a programacao de computadores → exam → tp01 - variaveis e estrutura sequencial → 1052.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp01 - variaveis e estrutura sequencial
#    📁 Processando: introducao a programacao de computadores → exam → tp 2 - condicionais compostos (ifelse) → 1097.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 2 - condicionais compostos (ifelse)
#    📁 Processando: introducao a programacao de computadores → exam → trabalho pratico 02 - estrutura condicional simples e composta → 541.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: trabalho pratico 02 - estrutura condicional simples e composta
#    📁 Processando: introducao a programacao de computadores → exam → trabalho pratico 02 - estrutura condicional simples e composta → 525.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: trabalho pratico 02 - estrutura condicional simples e composta
#    📁 Processando: introducao a programacao de computadores → exam → trabalho pratico 02 - estrutura condicional simples e composta → 526.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: trabalho pratico 02 - estrutura condicional simples e composta
#    📁 Processando: introducao a programacao de computadores → exam → trabalho pratico 02 - estrutura condicional simples e composta → 539.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: trabalho pratico 02 - estrutura condicional simples e composta
#    📁 Processando: introducao a programacao de computadores → exam → trabalho pratico 02 - estrutura condicional simples e composta → 518.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: trabalho pratico 02 - estrutura condicional simples e composta
#    📁 Processando: introducao a programacao de computadores → exam → tp 5 → 5472.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 5
#    📁 Processando: introducao a programacao de computadores → exam → tp 5 → 1224.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 5
#    📁 Processando: introducao a programacao de computadores → exam → tp 5 → 1233.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 5
#    📁 Processando: introducao a programacao de computadores → exam → tp 5 → 1505.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 5
#    📁 Processando: introducao a programacao de computadores → exam → tp 5 → 5874.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 5
#    📁 Processando: introducao a programacao de computadores → exam → tp 5 → 5867.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 5
#    📁 Processando: introducao a programacao de computadores → exam → tp 5 → 1235.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 5
#    📁 Processando: introducao a programacao de computadores → exam → tp 5 → 5127.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 5
#    📁 Processando: introducao a programacao de computadores → exam → tp 5 → 5473.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 5
#    📁 Processando: introducao a programacao de computadores → exam → tp 5 → 5875.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 5
#    📁 Processando: introducao a programacao de computadores → exam → tp 5 → 5129.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 5
#    📁 Processando: introducao a programacao de computadores → exam → tp 5 → 5153.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 5
#    📁 Processando: introducao a programacao de computadores → exam → tp 5 → 5493.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 5
#    📁 Processando: introducao a programacao de computadores → exam → tp 5 → 5868.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 5
#    📁 Processando: introducao a programacao de computadores → exam → tp 5 → 1220.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 5
#    📁 Processando: introducao a programacao de computadores → exam → tp 5 → 1512.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 5
#    📁 Processando: introducao a programacao de computadores → exam → tp 5 → 5471.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 5
#    📁 Processando: introducao a programacao de computadores → exam → tp 5 → 1232.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 5
#    📁 Processando: introducao a programacao de computadores → exam → tp 5 → 5126.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 5
#    📁 Processando: introducao a programacao de computadores → exam → tp 5 → 5470.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 5
#    📁 Processando: introducao a programacao de computadores → exam → tp 5 → 5130.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 5
#    📁 Processando: introducao a programacao de computadores → exam → tp 5 → 5865.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 5
#    📁 Processando: introducao a programacao de computadores → exam → tp 5 → 5877.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 5
#    📁 Processando: introducao a programacao de computadores → exam → tp6 → 3307.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp6
#    📁 Processando: introducao a programacao de computadores → exam → tp6 → 3245.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp6
#    📁 Processando: introducao a programacao de computadores → exam → tp6 → 1828.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp6
#    📁 Processando: introducao a programacao de computadores → exam → tp6 → 1830.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp6
#    📁 Processando: introducao a programacao de computadores → exam → tp6 → 3260.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp6
#    📁 Processando: introducao a programacao de computadores → exam → tp6 → 3246.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp6
#    📁 Processando: introducao a programacao de computadores → exam → tp6 → 1822.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp6
#    📁 Processando: introducao a programacao de computadores → exam → tp6 → 3247.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp6
#    📁 Processando: introducao a programacao de computadores → exam → tp6 → 1832.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp6
#    📁 Processando: introducao a programacao de computadores → exam → tp6 → 1831.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp6
#    📁 Processando: introducao a programacao de computadores → exam → tp6 → 3235.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp6
#    📁 Processando: introducao a programacao de computadores → exam → tp6 → 3249.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp6
#    📁 Processando: introducao a programacao de computadores → exam → tp6 → 3305.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp6
#    📁 Processando: introducao a programacao de computadores → exam → trabalho pratico substitutivo → 778.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: trabalho pratico substitutivo
#    📁 Processando: introducao a programacao de computadores → exam → trabalho pratico substitutivo → 769.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: trabalho pratico substitutivo
#    📁 Processando: introducao a programacao de computadores → exam → trabalho pratico 6 → 711.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: trabalho pratico 6
#    📁 Processando: introducao a programacao de computadores → exam → trabalho pratico 6 → 714.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: trabalho pratico 6
#    📁 Processando: introducao a programacao de computadores → exam → trabalho pratico 6 → 722.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: trabalho pratico 6
#    📁 Processando: introducao a programacao de computadores → exam → trabalho pratico 6 → 715.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: trabalho pratico 6
#    📁 Processando: introducao a programacao de computadores → exam → trabalho pratico 6 → 712.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: trabalho pratico 6
#    📁 Processando: introducao a programacao de computadores → exam → trabalho pratico 01 → 830.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: trabalho pratico 01
#    📁 Processando: introducao a programacao de computadores → exam → trabalho pratico 01 → 487.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: trabalho pratico 01
#    📁 Processando: introducao a programacao de computadores → exam → trabalho pratico 01 → 488.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: trabalho pratico 01
#    📁 Processando: introducao a programacao de computadores → exam → trabalho pratico 01 → 475.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: trabalho pratico 01
#    📁 Processando: introducao a programacao de computadores → exam → trabalho pratico 01 → 836.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: trabalho pratico 01
#    📁 Processando: introducao a programacao de computadores → exam → trabalho pratico 01 → 468.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: trabalho pratico 01
#    📁 Processando: introducao a programacao de computadores → exam → trabalho pratico 01 → 269.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: trabalho pratico 01
#    📁 Processando: introducao a programacao de computadores → exam → trabalho pratico 01 → 473.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: trabalho pratico 01
#    📁 Processando: introducao a programacao de computadores → exam → lab 1 - variaveis e estrutura sequencial → 3094.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: lab 1 - variaveis e estrutura sequencial
#    📁 Processando: introducao a programacao de computadores → exam → avaliacao parcial 02 [grupo 2] – estrutura condicional composta (sem aninhamento) → 128.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: avaliacao parcial 02 [grupo 2] – estrutura condicional composta (sem aninhamento)
#    📁 Processando: introducao a programacao de computadores → exam → tp03 – condicionais encadeadas (ifelif) → 1148.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp03 – condicionais encadeadas (ifelif)
#    📁 Processando: introducao a programacao de computadores → exam → tp3 e tp4 - condicional e repeticao (while) (p) → 3162.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp3 e tp4 - condicional e repeticao (while) (p)
#    📁 Processando: introducao a programacao de computadores → exam → tp3 e tp4 - condicional e repeticao (while) (p) → 3163.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp3 e tp4 - condicional e repeticao (while) (p)
#    📁 Processando: introducao a programacao de computadores → exam → tp3 e tp4 - condicional e repeticao (while) (p) → 3161.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp3 e tp4 - condicional e repeticao (while) (p)
#    📁 Processando: introducao a programacao de computadores → exam → tp3 e tp4 - condicional e repeticao (while) (p) → 3158.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp3 e tp4 - condicional e repeticao (while) (p)
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 5184.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 387.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 5953.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 5952.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 1317.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 4345.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 1003.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 5188.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 5557.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 4796.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 5947.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 3298.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 5192.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 1559.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 1892.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 4815.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 5948.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 5946.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 3292.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 5183.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 1308.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 4838.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 1313.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 1314.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 382.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 5554.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 4841.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 3310.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 1885.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 3296.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 5547.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 3300.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 1888.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 4821.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 5190.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 3301.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 4837.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 4318.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 4279.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 1880.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 4310.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 1891.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 5550.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 3309.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 1311.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → prova final → 5944.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: prova final
#    📁 Processando: introducao a programacao de computadores → exam → tp 4 → 5825.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 4
#    📁 Processando: introducao a programacao de computadores → exam → tp 4 → 5412.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 4
#    📁 Processando: introducao a programacao de computadores → exam → tp 4 → 1468.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 4
#    📁 Processando: introducao a programacao de computadores → exam → tp 4 → 1190.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 4
#    📁 Processando: introducao a programacao de computadores → exam → tp 4 → 1184.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 4
#    📁 Processando: introducao a programacao de computadores → exam → tp 4 → 5414.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 4
#    📁 Processando: introducao a programacao de computadores → exam → tp 4 → 5425.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 4
#    📁 Processando: introducao a programacao de computadores → exam → tp 4 → 1482.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 4
#    📁 Processando: introducao a programacao de computadores → exam → tp 4 → 5413.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 4
#    📁 Processando: introducao a programacao de computadores → exam → tp 4 → 5817.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 4
#    📁 Processando: introducao a programacao de computadores → exam → tp 4 → 5818.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 4
#    📁 Processando: introducao a programacao de computadores → exam → tp 4 → 1187.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 4
#    📁 Processando: introducao a programacao de computadores → exam → tp 4 → 5810.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 4
#    📁 Processando: introducao a programacao de computadores → exam → tp 4 → 5816.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 4
#    📁 Processando: introducao a programacao de computadores → exam → tp 4 → 5424.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 4
#    📁 Processando: introducao a programacao de computadores → exam → tp 4 → 5820.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 4
#    📁 Processando: introducao a programacao de computadores → exam → tp 01 → 1979.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 01
#    📁 Processando: introducao a programacao de computadores → exam → tp 01 → 4440.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 01
#    📁 Processando: introducao a programacao de computadores → exam → tp 01 → 4452.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 01
#    📁 Processando: introducao a programacao de computadores → exam → tp 01 → 3437.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 01
#    📁 Processando: introducao a programacao de computadores → exam → tp 01 → 3984.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 01
#    📁 Processando: introducao a programacao de computadores → exam → tp 01 → 1977.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 01
#    📁 Processando: introducao a programacao de computadores → exam → tp 01 → 1972.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 01
#    📁 Processando: introducao a programacao de computadores → exam → tp 01 → 3983.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 01
#    📁 Processando: introducao a programacao de computadores → exam → tp 01 → 3962.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 01
#    📁 Processando: introducao a programacao de computadores → exam → tp 01 → 3444.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 01
#    📁 Processando: introducao a programacao de computadores → exam → tp 01 → 4493.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 01
#    📁 Processando: introducao a programacao de computadores → exam → tp 01 → 3465.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 01
#    📁 Processando: introducao a programacao de computadores → exam → tp 01 → 4451.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 01
#    📁 Processando: introducao a programacao de computadores → exam → tp 01 → 4453.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 01
#    📁 Processando: introducao a programacao de computadores → exam → tp 01 → 3445.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 01
#    📁 Processando: introducao a programacao de computadores → exam → tp 01 → 4484.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 01
#    📁 Processando: introducao a programacao de computadores → exam → tp 01 → 3960.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 01
#    📁 Processando: introducao a programacao de computadores → exam → tp 01 → 3436.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 01
#    📁 Processando: introducao a programacao de computadores → exam → tp 01 → 2003.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 01
#    📁 Processando: introducao a programacao de computadores → exam → tp 01 → 3433.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 01
#    📁 Processando: introducao a programacao de computadores → exam → tp 01 → 3961.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 01
#    📁 Processando: introducao a programacao de computadores → exam → tp 01 → 3438.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 01
#    📁 Processando: introducao a programacao de computadores → exam → avaliacao parcial 03 – estruturas condicionais encadeadas → 130.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: avaliacao parcial 03 – estruturas condicionais encadeadas
#    📁 Processando: introducao a programacao de computadores → exam → avaliacao parcial 03 – estruturas condicionais encadeadas → 126.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: avaliacao parcial 03 – estruturas condicionais encadeadas
#    📁 Processando: introducao a programacao de computadores → exam → avaliacao parcial 03 – estruturas condicionais encadeadas → 127.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: avaliacao parcial 03 – estruturas condicionais encadeadas
#    📁 Processando: introducao a programacao de computadores → exam → avaliacao parcial 03 – estruturas condicionais encadeadas → 140.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: avaliacao parcial 03 – estruturas condicionais encadeadas
#    📁 Processando: introducao a programacao de computadores → exam → tp 3 - condicionais encadeadas (ifelifelse) → 1434.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 3 - condicionais encadeadas (ifelifelse)
#    📁 Processando: introducao a programacao de computadores → exam → tp 3 - condicionais encadeadas (ifelifelse) → 1436.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 3 - condicionais encadeadas (ifelifelse)
#    📁 Processando: introducao a programacao de computadores → exam → tp02 - condicionais simples (ifelse) → 1098.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp02 - condicionais simples (ifelse)
#    📁 Processando: introducao a programacao de computadores → exam → tp 04 - estrutura de repeticao (while) → 1182.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 04 - estrutura de repeticao (while)
#    📁 Processando: introducao a programacao de computadores → exam → tp 3 → 5763.data
#       🏷️  Módulo: introducao a programacao de computadores | Prova: tp 3
#    📁 Processando: introducao a programacao de computadores → exam → tp 3 → 5346.data
# ...
#                ⚠️  Questão duplicada: 1167
#                ⚠️  Questão duplicada: 1168
#                ⚠️  Questão duplicada: 1169
#                ⚠️  Questão duplicada: 1170
#                ⚠️  Questão duplicada: 1171
#                ⚠️  Questão duplicada: 1172
#                ⚠️  Questão duplicada: 1173
#                ⚠️  Questão duplicada: 1174
#                ⚠️  Questão duplicada: 1175
#          📄 Arquivo: 147 - 2 exercício(s)
#             🔸 exercise_01: 12 questão(ões)
#                ⚠️  Questão duplicada: 1152
#                ⚠️  Questão duplicada: 1153
#                ⚠️  Questão duplicada: 1154
#                ⚠️  Questão duplicada: 1155
#                ⚠️  Questão duplicada: 1156
#                ⚠️  Questão duplicada: 1157
#                ⚠️  Questão duplicada: 1158
#                ⚠️  Questão duplicada: 1159
#                ⚠️  Questão duplicada: 1160
#                ⚠️  Questão duplicada: 1161
#                ⚠️  Questão duplicada: 1162
#                ⚠️  Questão duplicada: 1163
#             🔸 exercise_02: 12 questão(ões)
#                ⚠️  Questão duplicada: 1164
#                ⚠️  Questão duplicada: 1165
#                ⚠️  Questão duplicada: 1166
#                ⚠️  Questão duplicada: 1167
#                ⚠️  Questão duplicada: 1168
#                ⚠️  Questão duplicada: 1169
#                ⚠️  Questão duplicada: 1170
#                ⚠️  Questão duplicada: 1171
#                ⚠️  Questão duplicada: 1172
#                ⚠️  Questão duplicada: 1173
#                ⚠️  Questão duplicada: 1174
#                ⚠️  Questão duplicada: 1175
#          📄 Arquivo: 148 - 2 exercício(s)
#             🔸 exercise_01: 12 questão(ões)
#                ⚠️  Questão duplicada: 1152
#                ⚠️  Questão duplicada: 1153
#                ⚠️  Questão duplicada: 1154
#                ⚠️  Questão duplicada: 1155
#                ⚠️  Questão duplicada: 1156
#                ⚠️  Questão duplicada: 1157
#                ⚠️  Questão duplicada: 1158
#                ⚠️  Questão duplicada: 1159
#                ⚠️  Questão duplicada: 1160
#                ⚠️  Questão duplicada: 1161
#                ⚠️  Questão duplicada: 1162
#                ⚠️  Questão duplicada: 1163
#             🔸 exercise_02: 12 questão(ões)
#                ⚠️  Questão duplicada: 1164
#                ⚠️  Questão duplicada: 1165
#                ⚠️  Questão duplicada: 1166
#                ⚠️  Questão duplicada: 1167
#                ⚠️  Questão duplicada: 1168
#                ⚠️  Questão duplicada: 1169
#                ⚠️  Questão duplicada: 1170
#                ⚠️  Questão duplicada: 1171
#                ⚠️  Questão duplicada: 1172
#                ⚠️  Questão duplicada: 1173
#                ⚠️  Questão duplicada: 1174
#                ⚠️  Questão duplicada: 1175
#       📋 Processando prova: avaliacao parcial 02 – estrutura condicional composta (sem aninhamento)
#          📄 Arquivo: 93 - 2 exercício(s)
#             🔸 exercise_01: 11 questão(ões)
#                ⚠️  Questão duplicada: 1080
#                ⚠️  Questão duplicada: 1081
#                ⚠️  Questão duplicada: 1082
#                ⚠️  Questão duplicada: 1083
#                ⚠️  Questão duplicada: 1084
#                ⚠️  Questão duplicada: 1085
#                ⚠️  Questão duplicada: 1086
#                ⚠️  Questão duplicada: 1087
#                ⚠️  Questão duplicada: 1088
#                ⚠️  Questão duplicada: 1089
#                ⚠️  Questão duplicada: 1090
#             🔸 exercise_02: 8 questão(ões)
#                ⚠️  Questão duplicada: 1091
#                ⚠️  Questão duplicada: 1092
#                ⚠️  Questão duplicada: 1093
#                ⚠️  Questão duplicada: 1094
#                ⚠️  Questão duplicada: 1095
#                ⚠️  Questão duplicada: 1096
#                ⚠️  Questão duplicada: 1097
#                ⚠️  Questão duplicada: 1098
#          📄 Arquivo: 92 - 2 exercício(s)
#             🔸 exercise_01: 11 questão(ões)
#                ⚠️  Questão duplicada: 1080
#                ⚠️  Questão duplicada: 1081
#                ⚠️  Questão duplicada: 1082
#                ⚠️  Questão duplicada: 1083
#                ⚠️  Questão duplicada: 1084
#                ⚠️  Questão duplicada: 1085
#                ⚠️  Questão duplicada: 1086
#                ⚠️  Questão duplicada: 1087
#                ⚠️  Questão duplicada: 1088
#                ⚠️  Questão duplicada: 1089
#                ⚠️  Questão duplicada: 1090
#             🔸 exercise_02: 8 questão(ões)
#                ⚠️  Questão duplicada: 1091
#                ⚠️  Questão duplicada: 1092
#                ⚠️  Questão duplicada: 1093
#                ⚠️  Questão duplicada: 1094
#                ⚠️  Questão duplicada: 1095
#                ⚠️  Questão duplicada: 1096
#                ⚠️  Questão duplicada: 1097
#                ⚠️  Questão duplicada: 1098
#          📄 Arquivo: 95 - 2 exercício(s)
#             🔸 exercise_01: 11 questão(ões)
#                ⚠️  Questão duplicada: 1080
#                ⚠️  Questão duplicada: 1081
#                ⚠️  Questão duplicada: 1082
#                ⚠️  Questão duplicada: 1083
#                ⚠️  Questão duplicada: 1084
#                ⚠️  Questão duplicada: 1085
#                ⚠️  Questão duplicada: 1086
#                ⚠️  Questão duplicada: 1087
#                ⚠️  Questão duplicada: 1088
#                ⚠️  Questão duplicada: 1089
#                ⚠️  Questão duplicada: 1090
#             🔸 exercise_02: 8 questão(ões)
#                ⚠️  Questão duplicada: 1091
#                ⚠️  Questão duplicada: 1092
#                ⚠️  Questão duplicada: 1093
#                ⚠️  Questão duplicada: 1094
#                ⚠️  Questão duplicada: 1095
#                ⚠️  Questão duplicada: 1096
#                ⚠️  Questão duplicada: 1097
#                ⚠️  Questão duplicada: 1098
#          📄 Arquivo: 94 - 2 exercício(s)
#             🔸 exercise_01: 11 questão(ões)
#                ⚠️  Questão duplicada: 1080
#                ⚠️  Questão duplicada: 1081
#                ⚠️  Questão duplicada: 1082
#                ⚠️  Questão duplicada: 1083
#                ⚠️  Questão duplicada: 1084
#                ⚠️  Questão duplicada: 1085
#                ⚠️  Questão duplicada: 1086
#                ⚠️  Questão duplicada: 1087
#                ⚠️  Questão duplicada: 1088
#                ⚠️  Questão duplicada: 1089
#                ⚠️  Questão duplicada: 1090
#             🔸 exercise_02: 8 questão(ões)
#                ⚠️  Questão duplicada: 1091
#                ⚠️  Questão duplicada: 1092
#                ⚠️  Questão duplicada: 1093
#                ⚠️  Questão duplicada: 1094
#                ⚠️  Questão duplicada: 1095
#                ⚠️  Questão duplicada: 1096
#                ⚠️  Questão duplicada: 1097
#                ⚠️  Questão duplicada: 1098
#
# 📊 Estatísticas do mapeamento:
#    ✅ Total questões mapeadas: 21105
#    ⚠️  Arquivos sem exercícios: 0
#    🔄 Questões duplicadas: 19772
#
# 📈 Analisando desempenho...
# 📈 Debug: Analisando desempenho...
#    📊 Questões no CSV: 829
#    🔗 Questões mapeadas: 1333
#    🔑 Usando coluna: question
#    ✅ Questões do CSV encontradas no mapeamento: 0
#    ❌ Questões não encontradas: 0
#       Exemplos de questões não mapeadas: []
#    📚 Módulos encontrados nos dados: ['introducao a ciencia dos computadores', 'introducao a programacao de computadores']
#    📋 Provas encontradas nos dados: 41
#
# 📋 Gerando relatório...
# ================================================================================
# RELATÓRIO DE ANÁLISE DE DESEMPENHO - MÓDULOS E PROVAS
# ================================================================================
#
# 📊 ESTATÍSTICAS GERAIS
#    • Total de questões no dataset: 829
#    • Questões mapeadas com sucesso: 829 (100.0%)
#    • Questões não mapeadas: 0
#
# 📚 ANÁLISE POR MÓDULO
# --------------------------------------------------
#
# 🔹 INTRODUCAO A CIENCIA DOS COMPUTADORES
#    📊 Total de questões: 825
#    📋 Provas associadas: avaliacao 01 - variaveis e estrutura sequencial, avaliacao parcial 02 – estrutura condicional composta (sem aninhamento), avaliacao parcial 03 – estruturas condicionais encadeadas, tp 3 – condicionais encadeadas (ifelif), tp 2 - condicional simples e composta (ifelse), avaliacao parcial 03– estrutura condicional encadeada, avaliacao parcial 04 – estrutura de repeticao por condicao (while), avaliacao parcial 05 – vetores e strings, avaliacao parcial 06 – repeticao por contagem, tp 1, tp 02, tp substitutivo, trabalho pratico 3, trabalho pratico 03 - estrutura condicional encadeada, trabalho pratico 4, trabalho pratico 05, trabalho pratico 06 - estrutura de repeticao por contagem (for), prova final, trabalho pratico 01, trabalho pratico 02 - estrutura condicional simples e composta, trabalho pratico 5, trabalho pratico 6, tp 1 - variaveis e estrutura sequencial, tp 01, tp 4, tp 6, tp 05, tp1, tp2 - estrutura condicional simples e composta, tp3, tp3 e tp4 - condicional e repeticao (while) (p), tp3 - estrutura condicional encadeada, tp4, tp, tp 04, tp 03 – condicionais encadeadas (ifelif), tp5, tp2, tp 5, tp 2, tp 3
#
# 🔹 INTRODUCAO A PROGRAMACAO DE COMPUTADORES
#    📊 Total de questões: 4
#    📋 Provas associadas: tp 6, tp 5, tp1, tp 02
#
#
# 📋 ANÁLISE POR PROVA
# --------------------------------------------------
#
# 📚 INTRODUCAO A CIENCIA DOS COMPUTADORES
#
#    🔸 Avaliação 01 - Variáveis e Estrutura Sequencial
#       📁 Código da prova: avaliacao 01 - variaveis e estrutura sequencial
#       📊 Total de questões: 22
#       📄 Arquivos: 41
#
#    🔸 Avaliação Parcial 02 – Estrutura Condicional Composta (sem Aninhamento)
#       📁 Código da prova: avaliacao parcial 02 – estrutura condicional composta (sem aninhamento)
#       📊 Total de questões: 19
#       📄 Arquivos: 94
#
#    🔸 Avaliação Parcial 03 – Estruturas Condicionais Encadeadas
#       📁 Código da prova: avaliacao parcial 03 – estruturas condicionais encadeadas
#       📊 Total de questões: 3
#       📄 Arquivos: 129
#
#    🔸 TP 3 – Condicionais Encadeadas (if/elif)
#       📁 Código da prova: tp 3 – condicionais encadeadas (ifelif)
#       📊 Total de questões: 27
#       📄 Arquivos: 1145
#
#    🔸 TP 2 - Condicional Simples e Composta (if/else)
#       📁 Código da prova: tp 2 - condicional simples e composta (ifelse)
#       📊 Total de questões: 14
#       📄 Arquivos: 1405
#
#    🔸 Avaliação Parcial 03– Estrutura Condicional Encadeada
#       📁 Código da prova: avaliacao parcial 03– estrutura condicional encadeada
#       📊 Total de questões: 1
#       📄 Arquivos: 121
#
#    🔸 Avaliação Parcial 04 – Estrutura de Repetição por Condição (while)
#       📁 Código da prova: avaliacao parcial 04 – estrutura de repeticao por condicao (while)
#       📊 Total de questões: 24
#       📄 Arquivos: 148
#
#    🔸 Avaliação Parcial 05 – Vetores e Strings
#       📁 Código da prova: avaliacao parcial 05 – vetores e strings
#       📊 Total de questões: 22
#       📄 Arquivos: 171
#
#    🔸 Avaliação Parcial 06 – Repetição por contagem
#       📁 Código da prova: avaliacao parcial 06 – repeticao por contagem
#       📊 Total de questões: 20
#       📄 Arquivos: 201
#
#    🔸 TP 1: Variáveis e Estrutura Sequencial
#       📁 Código da prova: tp 1
#       📊 Total de questões: 61
#       📄 Arquivos: 1367, 1357, 5256
#
#    🔸 TP 02:  Est. Condicional Simples e Composta (2019)
#       📁 Código da prova: tp 02
#       📊 Total de questões: 53
#       📄 Arquivos: 2018, 3489, 4015, 4536, 3493
#
#    🔸 TP Substitutivo
#       📁 Código da prova: tp substitutivo
#       📊 Total de questões: 65
#       📄 Arquivos: 4799, 5172, 5541
#
#    🔸 Trabalho Prático 3: Estruturas Condicionais Encadeadas
#       📁 Código da prova: trabalho pratico 3
#       📊 Total de questões: 23
#       📄 Arquivos: 560, 569
#
#    🔸 Trabalho Prático 03 - Estrutura Condicional Encadeada
#       📁 Código da prova: trabalho pratico 03 - estrutura condicional encadeada
#       📊 Total de questões: 7
#       📄 Arquivos: 313
#
#    🔸 Trabalho Prático 4: Estrutura de Repetição por Condição (while)
#       📁 Código da prova: trabalho pratico 4
#       📊 Total de questões: 30
#       📄 Arquivos: 922, 921, 620
#
#    🔸 Trabalho Prático 05: Vetores e Strings
#       📁 Código da prova: trabalho pratico 05
#       📊 Total de questões: 25
#       📄 Arquivos: 348
#
#    🔸 Trabalho Prático 06 - Estrutura de Repetição por Contagem (for)
#       📁 Código da prova: trabalho pratico 06 - estrutura de repeticao por contagem (for)
#       📊 Total de questões: 20
#       📄 Arquivos: 368
#
#    🔸 Prova Final
#       📁 Código da prova: prova final
#       📊 Total de questões: 38
#       📄 Arquivos: 1303, 4350, 1557, 4800, 1887
#
#    🔸 Trabalho Prático 01: Variáveis e Estrutura Sequencial de Programação
#       📁 Código da prova: trabalho pratico 01
#       📊 Total de questões: 10
#       📄 Arquivos: 833
#
#    🔸 Trabalho Prático 02 - Estrutura Condicional Simples e Composta
#       📁 Código da prova: trabalho pratico 02 - estrutura condicional simples e composta
#       📊 Total de questões: 10
#       📄 Arquivos: 515
#
#    🔸 Trabalho Prático 5: Vetores e Strings
#       📁 Código da prova: trabalho pratico 5
#       📊 Total de questões: 10
#       📄 Arquivos: 671
#
#    🔸 Trabalho Prático 6: Repetição por Contagem
#       📁 Código da prova: trabalho pratico 6
#       📊 Total de questões: 9
#       📄 Arquivos: 720
#
#    🔸 TP 1 - Variáveis e Estrutura Sequencial
#       📁 Código da prova: tp 1 - variaveis e estrutura sequencial
#       📊 Total de questões: 10
#       📄 Arquivos: 1056
#
#    🔸 TP 01: Variáveis e Estrutura Sequencial
#       📁 Código da prova: tp 01
#       📊 Total de questões: 4
#       📄 Arquivos: 3435, 2000
#
#    🔸 TP 4: Estrutura de Repetição por Condição (while)
#       📁 Código da prova: tp 4
#       📊 Total de questões: 53
#       📄 Arquivos: 1193, 1470, 5812, 5405
#
#    🔸 TP 05: Vetores e Strings
#       📁 Código da prova: tp 05
#       📊 Total de questões: 19
#       📄 Arquivos: 4173, 4748
#
#    🔸 TP1: Variáveis e Estrutura Sequencial
#       📁 Código da prova: tp1
#       📊 Total de questões: 18
#       📄 Arquivos: 1621, 1633, 4915
#
#    🔸 TP2 - Estrutura Condicional Simples e Composta
#       📁 Código da prova: tp2 - estrutura condicional simples e composta
#       📊 Total de questões: 5
#       📄 Arquivos: 1676
#
#    🔸 TP3: Est. Condicional Encadeada
#       📁 Código da prova: tp3
#       📊 Total de questões: 22
#       📄 Arquivos: 5013
#
#    🔸 TP3 e TP4 - Condicional e Repetição (while) (P)
#       📁 Código da prova: tp3 e tp4 - condicional e repeticao (while) (p)
#       📊 Total de questões: 4
#       📄 Arquivos: 3156
#
#    🔸 TP3 - Estrutura Condicional Encadeada
#       📁 Código da prova: tp3 - estrutura condicional encadeada
#       📊 Total de questões: 8
#       📄 Arquivos: 1707
#
#    🔸 TP4: Estrutura de Repetição por Condição (while)
#       📁 Código da prova: tp4
#       📊 Total de questões: 9
#       📄 Arquivos: 1751
#
#    🔸 TP: Revisão
#       📁 Código da prova: tp
#       📊 Total de questões: 1
#       📄 Arquivos: 1882
#
#    🔸 TP 04: Estrutura de Repetição por Condição
#       📁 Código da prova: tp 04
#       📊 Total de questões: 33
#       📄 Arquivos: 4138, 5067
#
#    🔸 TP 03 – Condicionais Encadeadas (if/elif)
#       📁 Código da prova: tp 03 – condicionais encadeadas (ifelif)
#       📊 Total de questões: 22
#       📄 Arquivos: 4085, 3547
#
#    🔸 TP5: Vetores e Strings
#       📁 Código da prova: tp5
#       📊 Total de questões: 3
#       📄 Arquivos: 3718
#
#    🔸 TP2: Est. Condicional Simples e Composta
#       📁 Código da prova: tp2
#       📊 Total de questões: 13
#       📄 Arquivos: 4971
#
#    🔸 TP 2:  Est. Condicional Simples e Composta
#       📁 Código da prova: tp 2
#       📊 Total de questões: 10
#       📄 Arquivos: 5308
#
#    🔸 TP 3: Est. Condicional Encadeada
#       📁 Código da prova: tp 3
#       📊 Total de questões: 27
#       📄 Arquivos: 5331, 5767
#
# 📚 INTRODUCAO A PROGRAMACAO DE COMPUTADORES
#
#    🔸 TP 6: Estrutura de Repetição por Contagem (for)
#       📁 Código da prova: tp 6
#       📊 Total de questões: 34
#       📄 Arquivos: 3777, 1258, 5525, 5165
#
#    🔸 TP 5: Vetores e Strings
#       📁 Código da prova: tp 5
#       📊 Total de questões: 21
#       📄 Arquivos: 1232, 5124, 5468
#
# 💾 Salvando resultados...
#    ✅ Dados enriquecidos salvos em: relacao_assunto_questoes/dados_questoes_enriquecidos.csv
#    ✅ Mapeamento salvo em: relacao_assunto_questoes/mapeamento_questao_prova.json
#    ✅ Estrutura completa salva em: relacao_assunto_questoes/estrutura_completa.json
#
# ✨ Análise completa finalizada!
#
# 📋 RESUMO FINAL:
#    🎯 Taxa de mapeamento: 100.0%
#    📚 Módulos com dados: 2
#    📋 Provas com dados: 41
