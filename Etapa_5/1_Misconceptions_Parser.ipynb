# %%
from VisitorMC3 import *
import ast
import os
import pandas as pd
import csv
from collections import defaultdict

# Caminhos
csv_questoes = "../Etapa_3/questoes_ordenadas.csv"
pasta_usuarios = "../Etapa_3/UsuariosUnicos"
output_summary = "misconceptions_summary_por_questao.csv"
output_detailed = "misconceptions_detailed_por_usuario.csv"

# Constants for MC³ detection
C4_MAX_ALLOWED_RANGEITER = 50
E2_MAX_ALLOWED_LISTS = 5
G4_MIN_VAR_CHRS = 4
G4_MIN_FNC_CHRS = 8
G4_MAX_ALLOWED_NONSIGNIFICANT = 70

# Lista de todos os MC³ possíveis
MC3_TYPES = ['A4', 'A5', 'B4', 'B6', 'B8', 'B9', 'B12', 'C1', 'C2', 'C3', 'C4', 'C8', 'D4', 'E2', 'G4', 'G5', 'H1']

def analisar_codigo(filepath):
    """Analisa um arquivo Python e retorna os MC³ detectados"""
    try:
        with open(filepath, 'r', encoding="utf-8") as file:
            code = file.read()
        parsed = ast.parse(code)
    except Exception as e:
        print(f"Erro ao fazer parsing de {filepath}: {e}")
        return []

    visitor = VisitorMC3()
    
    try:
        # Executar todas as detecções
        resultados = {}
        
        resA4 = visitor.getA4(parsed)
        resA5 = visitor.getA5(parsed)
        resB4 = visitor.getB4(parsed)
        resB6 = visitor.getB6(parsed)
        resB8 = visitor.getB8(parsed)
        resB9 = visitor.getB9(parsed)
        resB12 = visitor.getB12(parsed)
        resC1 = visitor.getC1(parsed)
        resC2 = visitor.getC2(parsed)
        resC3 = visitor.getC3(parsed)
        resC4 = visitor.getC4(parsed, C4_MAX_ALLOWED_RANGEITER)
        resC8 = visitor.getC8(parsed)
        resD4 = visitor.getD4(parsed)
        resE2 = visitor.getE2(parsed, E2_MAX_ALLOWED_LISTS)
        resG4 = visitor.getG4(parsed, G4_MIN_VAR_CHRS, G4_MIN_FNC_CHRS, G4_MAX_ALLOWED_NONSIGNIFICANT)
        resG5 = visitor.getG5(parsed)
        resH1 = visitor.getH1(parsed)

        # Organizar resultados - alguns retornam tuplas, outros boolean
        res_map = {
            'A4': resA4[0] if isinstance(resA4, tuple) else resA4,
            'A5': resA5[0] if isinstance(resA5, tuple) else resA5,
            'B4': resB4,
            'B6': resB6,
            'B8': resB8,
            'B9': resB9,
            'B12': resB12,
            'C1': resC1,
            'C2': resC2,
            'C3': resC3,
            'C4': resC4,
            'C8': resC8,
            'D4': resD4,
            'E2': resE2,
            'G4': resG4,
            'G5': resG5,
            'H1': resH1
        }
        
        # Retornar apenas os MC³ detectados (True)
        detectados = [mc3 for mc3, resultado in res_map.items() if resultado]
        return detectados
        
    except Exception as e:
        print(f"Erro ao processar {filepath}: {e}")
        return []

def main():
    # Ler o CSV de questões
    print("Lendo questoes_ordenadas.csv...")
    df_questoes = pd.read_csv(csv_questoes)
    
    # Estruturas para armazenar os resultados
    summary_data = []  # Para o CSV resumo por questão
    detailed_data = []  # Para o CSV detalhado por usuário
    
    # Processar cada questão
    for _, row in df_questoes.iterrows():
        questao_id = row['id']
        usuarios_str = row['usuarios_respondidos']
        
        print(f"\nProcessando questão {questao_id}...")
        
        # Converter string de usuários para lista
        usuarios = [u.strip() for u in usuarios_str.split(',')]
        
        # Contadores para esta questão
        mc3_counters = defaultdict(int)
        usuarios_analisados = 0
        usuarios_com_misconceptions = 0
        
        # Analisar cada usuário desta questão
        for usuario_id in usuarios:
            # Procurar arquivo do usuário (assumindo que está na pasta do usuário)
            usuario_pasta = os.path.join(pasta_usuarios, str(usuario_id))
            
            if not os.path.exists(usuario_pasta):
                continue
                
            # Procurar arquivo Python na pasta do usuário
            py_files = []
            for item in os.listdir(usuario_pasta):
                item_path = os.path.join(usuario_pasta, item)
                if item.endswith('.py'):
                    py_files.append(item_path)
                elif os.path.isdir(item_path):
                    # Procurar em subpastas também
                    for subitem in os.listdir(item_path):
                        if subitem.endswith('.py'):
                            py_files.append(os.path.join(item_path, subitem))
            
            # Analisar todos os arquivos Python encontrados para este usuário
            usuario_misconceptions = set()
            
            for py_file in py_files:
                misconceptions = analisar_codigo(py_file)
                usuario_misconceptions.update(misconceptions)
            
            if usuario_misconceptions:
                usuarios_analisados += 1
                usuarios_com_misconceptions += 1
                
                # Atualizar contadores
                for mc3 in usuario_misconceptions:
                    mc3_counters[mc3] += 1
                
                # Adicionar ao CSV detalhado
                detailed_data.append({
                    'questao_id': questao_id,
                    'usuario_id': usuario_id,
                    'misconceptions_detectados': ','.join(sorted(usuario_misconceptions)),
                    'total_misconceptions': len(usuario_misconceptions)
                })
            elif py_files:  # Usuario tinha arquivos mas sem misconceptions
                usuarios_analisados += 1
                detailed_data.append({
                    'questao_id': questao_id,
                    'usuario_id': usuario_id,
                    'misconceptions_detectados': '',
                    'total_misconceptions': 0
                })
        
        # Criar linha do resumo para esta questão
        summary_row = {
            'questao_id': questao_id,
            'total_usuarios_responderam': len(usuarios),
            'usuarios_analisados': usuarios_analisados,
            'usuarios_com_misconceptions': usuarios_com_misconceptions,
            'percentual_com_misconceptions': round((usuarios_com_misconceptions/usuarios_analisados*100) if usuarios_analisados > 0 else 0, 2)
        }
        
        # Adicionar contadores de cada MC³
        for mc3_type in MC3_TYPES:
            summary_row[f'count_{mc3_type}'] = mc3_counters[mc3_type]
            summary_row[f'perc_{mc3_type}'] = round((mc3_counters[mc3_type]/usuarios_analisados*100) if usuarios_analisados > 0 else 0, 2)
        
        summary_data.append(summary_row)
        
        print(f"  - Usuários analisados: {usuarios_analisados}/{len(usuarios)}")
        print(f"  - Com misconceptions: {usuarios_com_misconceptions}")
        if mc3_counters:
            print(f"  - MC³ mais frequentes: {dict(sorted(mc3_counters.items(), key=lambda x: x[1], reverse=True)[:3])}")
    
    # Salvar CSV resumo por questão
    print(f"\nSalvando resumo em {output_summary}...")
    df_summary = pd.DataFrame(summary_data)
    df_summary.to_csv(output_summary, index=False, encoding='utf-8')
    
    # Salvar CSV detalhado por usuário
    print(f"Salvando detalhes em {output_detailed}...")
    df_detailed = pd.DataFrame(detailed_data)
    df_detailed.to_csv(output_detailed, index=False, encoding='utf-8')
    
    print("\nResumo geral:")
    print(f"- Total de questões processadas: {len(summary_data)}")
    print(f"- Total de análises de usuários: {len(detailed_data)}")
    print(f"- Arquivos gerados: {output_summary}, {output_detailed}")
    
    # Mostrar estatísticas gerais
    if summary_data:
        total_usuarios_analisados = sum(row['usuarios_analisados'] for row in summary_data)
        total_com_misconceptions = sum(row['usuarios_com_misconceptions'] for row in summary_data)
        
        print(f"- Total usuários analisados: {total_usuarios_analisados}")
        print(f"- Total com misconceptions: {total_com_misconceptions}")
        print(f"- Percentual geral com misconceptions: {round(total_com_misconceptions/total_usuarios_analisados*100, 2)}%")
        
        # MC³ mais frequentes globalmente
        global_mc3_counts = defaultdict(int)
        for row in summary_data:
            for mc3_type in MC3_TYPES:
                global_mc3_counts[mc3_type] += row[f'count_{mc3_type}']
        
        top_mc3 = sorted(global_mc3_counts.items(), key=lambda x: x[1], reverse=True)[:5]
        print(f"- Top 5 MC³ mais frequentes: {dict(top_mc3)}")

if __name__ == "__main__":
    main()
# Out:
# Lendo questoes_ordenadas.csv...
#
# Processando questão 1642...
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9739/codes/5817_6196.py: invalid syntax (<unknown>, line 10)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9739/codes/5730_1949.py: invalid syntax (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9739/codes/5874_3591.py: expected an indented block after 'if' statement on line 7 (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9739/codes/5676_652.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9739/codes/5676_1092.py: invalid syntax (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9739/codes/5764_6783.py: expected an indented block after 'if' statement on line 4 (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9684/codes/5608_825.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9684/codes/5708_5946.py: cannot assign to literal (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9684/codes/5747_6914.py: invalid syntax (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9684/codes/5872_6651.py: '(' was never closed (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9684/codes/5767_6783.py: cannot assign to expression (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9684/codes/5812_6245.py: unindent does not match any outer indentation level (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9684/codes/5950_1495.py: invalid syntax (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9684/codes/5949_5300.py: expected an indented block after 'while' statement on line 4 (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9684/codes/5812_7010.py: expected ':' (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9684/codes/5888_7044.py: invalid syntax (<unknown>, line 9)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9684/codes/5837_6988.py: '(' was never closed (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9684/codes/5950_6247.py: invalid syntax (<unknown>, line 10)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9684/codes/5949_6335.py: expected an indented block after 'if' statement on line 12 (<unknown>, line 14)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9684/codes/5950_6849.py: expected an indented block after 'for' statement on line 4 (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9688/codes/5708_5951.py: '(' was never closed (<unknown>, line 9)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9688/codes/5746_6568.py: expected an indented block after 'if' statement on line 3 (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9688/codes/5790_2518.py: expected an indented block after 'try' statement on line 2 (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9688/codes/5812_6199.py: expected ':' (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9688/codes/5835_6788.py: expected an indented block after function definition on line 1 (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9688/codes/5812_6206.py: unindent does not match any outer indentation level (<unknown>, line 9)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9688/codes/5922_6360.py: inconsistent use of tabs and spaces in indentation (<unknown>, line 10)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9688/codes/5767_6761.py: invalid syntax. Maybe you meant '==' or ':=' instead of '='? (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9688/codes/5949_5300.py: expected ':' (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9688/codes/5708_6000.py: unexpected indent (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9688/codes/5922_1642.py: unexpected indent (<unknown>, line 12)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9688/codes/5767_6778.py: invalid syntax (<unknown>, line 10)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9746/codes/5796_6580.py: unexpected indent (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9816/codes/5923_6391.py: invalid syntax (<unknown>, line 10)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9816/codes/5896_1227.py: invalid syntax (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9816/codes/5782_6044.py: expected an indented block after 'while' statement on line 10 (<unknown>, line 11)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9816/codes/5670_652.py: invalid syntax (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9816/codes/5843_672.py: unexpected indent (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9816/codes/5841_7028.py: unindent does not match any outer indentation level (<unknown>, line 11)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9816/codes/5627_5937.py: unexpected indent (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9816/codes/5841_7031.py: unexpected indent (<unknown>, line 13)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9816/codes/5923_6374.py: '(' was never closed (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9816/codes/5725_6915.py: invalid syntax (<unknown>, line 13)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9816/codes/5670_1879.py: invalid syntax. Perhaps you forgot a comma? (<unknown>, line 12)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9816/codes/5782_6962.py: invalid syntax (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9816/codes/5894_7044.py: invalid syntax (<unknown>, line 15)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9816/codes/5896_1223.py: invalid syntax (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9880/codes/5726_1102.py: unexpected indent (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9880/codes/5727_6100.py: invalid syntax (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9957/codes/5875_6344.py: expected ':' (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9957/codes/5732_6568.py: expected ':' (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9957/codes/5941_6393.py: invalid syntax (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9957/codes/5941_6380.py: expected ':' (<unknown>, line 11)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9957/codes/5913_1223.py: invalid syntax (<unknown>, line 9)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9957/codes/5913_2588.py: '(' was never closed (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9771/codes/5681_1092.py: '(' was never closed (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/2549/codes/5785_6042.py: '(' was never closed (<unknown>, line 11)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/2549/codes/5832_7028.py: invalid syntax (<unknown>, line 13)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/2549/codes/5816_6196.py: expected an indented block after 'while' statement on line 10 (<unknown>, line 12)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9812/codes/5894_7043.py: invalid syntax (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9812/codes/5896_1649.py: unmatched '}' (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9685/codes/5837_7029.py: invalid syntax (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9685/codes/5812_7014.py: expected ':' (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9685/codes/5889_2562.py: unexpected indent (<unknown>, line 31)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9685/codes/5745_1102.py: invalid syntax. Perhaps you forgot a comma? (<unknown>, line 48)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9685/codes/5792_6050.py: expected ':' (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9685/codes/5888_7041.py: invalid syntax (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9685/codes/5922_2847.py: expected an indented block after 'if' statement on line 8 (<unknown>, line 9)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9762/codes/5764_6778.py: invalid syntax (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9762/codes/5935_1642.py: expected ':' (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9762/codes/5674_1397.py: unindent does not match any outer indentation level (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9818/codes/5867_6351.py: invalid syntax (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9818/codes/5727_6913.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9818/codes/5782_6050.py: invalid syntax (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9818/codes/5782_6195.py: invalid syntax (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9818/codes/5782_6612.py: '(' was never closed (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9818/codes/5820_6214.py: expected an indented block after 'if' statement on line 5 (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9818/codes/5820_6247.py: expected ':' (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9818/codes/5727_6568.py: '(' was never closed (<unknown>, line 9)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9818/codes/5924_6051.py: expected ':' (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9818/codes/5727_6940.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9818/codes/5924_6337.py: invalid syntax (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9818/codes/5782_6962.py: invalid syntax (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9818/codes/5780_6228.py: invalid syntax (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9818/codes/5924_6625.py: '(' was never closed (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9682/codes/5790_2525.py: expected an indented block after 'while' statement on line 5 (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9682/codes/5609_1801.py: unterminated string literal (detected at line 4) (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9682/codes/5689_6911.py: invalid decimal literal (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9680/codes/5746_6104.py: invalid character '√' (U+221A) (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9680/codes/5687_2445.py: expected an indented block after 'if' statement on line 4 (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9680/codes/5687_2969.py: expected ':' (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9680/codes/5889_2562.py: invalid syntax (<unknown>, line 9)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9680/codes/5889_6354.py: invalid syntax (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9680/codes/5812_7010.py: invalid syntax (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9680/codes/5835_1186.py: invalid syntax (<unknown>, line 16)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9680/codes/5922_2847.py: invalid syntax (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9799/codes/5632_6895.py: '(' was never closed (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9799/codes/5900_3620.py: invalid syntax (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9799/codes/5630_5937.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9799/codes/5854_6988.py: '(' was never closed (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9799/codes/5902_2844.py: inconsistent use of tabs and spaces in indentation (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9799/codes/5788_2525.py: invalid syntax (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9799/codes/5789_6043.py: invalid syntax (<unknown>, line 10)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9799/codes/5900_7037.py: invalid syntax (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/4226/codes/5924_6051.py: expected an indented block after 'if' statement on line 4 (<unknown>, line 10)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/4226/codes/5924_6338.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/6458/codes/5775_2525.py: invalid syntax (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/6458/codes/5775_2518.py: invalid syntax (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9735/codes/5730_1102.py: invalid syntax (<unknown>, line 13)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9735/codes/5916_3182.py: expected an indented block after 'for' statement on line 9 (<unknown>, line 12)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9735/codes/5730_2167.py: unexpected indent (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9829/codes/5842_2101.py: invalid syntax (<unknown>, line 15)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9829/codes/5781_6580.py: unexpected indent (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9669/codes/5673_1879.py: invalid syntax (<unknown>, line 12)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9669/codes/5830_2108.py: expected an indented block after 'if' statement on line 6 (<unknown>, line 9)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9669/codes/5831_672.py: expected an indented block after 'if' statement on line 6 (<unknown>, line 7)
#   - Usuários analisados: 21/21
#   - Com misconceptions: 21
#   - MC³ mais frequentes: {'A5': 21, 'G4': 21, 'B8': 21}
#
# Processando questão 1644...
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9828/codes/5781_6580.py: unindent does not match any outer indentation level (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9819/codes/5896_1227.py: invalid syntax (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9819/codes/5769_6935.py: '(' was never closed (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9819/codes/5769_6783.py: invalid syntax (<unknown>, line 10)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9819/codes/5668_602.py: illegal target for annotation (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9819/codes/5629_1804.py: '(' was never closed (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9819/codes/5896_1223.py: invalid syntax (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9755/codes/5728_6915.py: expected an indented block after 'else' statement on line 8 (<unknown>, line 10)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9755/codes/5874_6838.py: expected an indented block after 'while' statement on line 11 (<unknown>, line 11)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9755/codes/5817_6197.py: expected ':' (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9755/codes/5728_3041.py: invalid syntax (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9755/codes/5764_6934.py: invalid syntax (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9755/codes/5899_7040.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/7604/codes/5896_6353.py: invalid syntax (<unknown>, line 10)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/7604/codes/5923_1644.py: invalid syntax (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/7604/codes/5669_2973.py: unexpected indent (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/7604/codes/5669_2971.py: expected an indented block after 'if' statement on line 10 (<unknown>, line 11)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/7604/codes/5629_1017.py: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers (<unknown>, line 14)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/7604/codes/5668_1397.py: expected ':' (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9791/codes/5789_6811.py: expected an indented block after 'while' statement on line 4 (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9791/codes/5789_6039.py: unterminated string literal (detected at line 6) (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9791/codes/5789_6228.py: expected an indented block after 'while' statement on line 3 (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9932/codes/5849_672.py: unindent does not match any outer indentation level (<unknown>, line 9)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9672/codes/5654_1365.py: invalid decimal literal (<unknown>, line 9)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/8801/codes/5949_6337.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/8801/codes/5609_1806.py: invalid syntax (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/7702/codes/5797_6050.py: invalid syntax. Maybe you meant '==' or ':=' instead of '='? (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/7702/codes/5915_2563.py: '(' was never closed (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/7702/codes/5913_6353.py: invalid syntax (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/7702/codes/5818_6199.py: expected ':' (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9738/codes/5674_6498.py: expected an indented block after 'if' statement on line 2 (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9691/codes/5872_6347.py: expected ':' (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9691/codes/5889_2588.py: unexpected indent (<unknown>, line 9)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9691/codes/5708_5946.py: invalid syntax (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9691/codes/5949_6630.py: invalid syntax (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9691/codes/5950_1655.py: invalid syntax (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9691/codes/5837_7028.py: unexpected indent (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9691/codes/5888_7043.py: invalid syntax (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9691/codes/5950_6173.py: unexpected indent (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9691/codes/5888_2563.py: expected ':' (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9691/codes/5792_6962.py: expected an indented block after 'if' statement on line 12 (<unknown>, line 12)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9691/codes/5792_6050.py: unindent does not match any outer indentation level (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9691/codes/5949_6294.py: invalid syntax. Perhaps you forgot a comma? (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9691/codes/5791_6043.py: invalid syntax. Perhaps you forgot a comma? (<unknown>, line 14)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9691/codes/5837_6988.py: expected ':' (<unknown>, line 18)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9691/codes/5791_6811.py: unexpected indent (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9954/codes/5764_6758.py: expected an indented block after 'if' statement on line 5 (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9954/codes/5764_6747.py: expected ':' (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9954/codes/5764_6777.py: expected ':' (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9954/codes/5795_6811.py: expected ':' (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9954/codes/5764_6934.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9707/codes/5744_6915.py: invalid syntax. Maybe you meant '==' or ':=' instead of '='? (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9707/codes/5865_3589.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9707/codes/5905_6336.py: invalid syntax (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9707/codes/5904_1644.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9707/codes/5744_6094.py: invalid syntax (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9707/codes/5766_6933.py: invalid syntax (<unknown>, line 9)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9707/codes/5904_6371.py: invalid syntax (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9707/codes/5744_6916.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9817/codes/5725_6915.py: invalid syntax (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9662/codes/5678_652.py: invalid syntax (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9662/codes/5798_6580.py: unexpected indent (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9827/codes/5896_1227.py: invalid syntax (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9827/codes/5726_1102.py: invalid syntax (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9827/codes/5842_2101.py: invalid decimal literal (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9827/codes/5896_1223.py: invalid syntax (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5729_5259.py: expected ':' (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5935_2845.py: unexpected indent (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5874_3589.py: invalid syntax (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5729_6568.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5730_1949.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5935_1644.py: invalid syntax (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5935_6361.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5848_1599.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5916_2576.py: invalid decimal literal (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5848_6323.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5729_6100.py: invalid syntax (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5874_6836.py: invalid syntax (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5764_6936.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5935_6374.py: invalid syntax (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5764_6746.py: unexpected indent (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5795_5287.py: unexpected indent (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5916_2574.py: invalid syntax (<unknown>, line 16)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9692/codes/5889_3189.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9692/codes/5745_1949.py: invalid syntax (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9692/codes/5922_1644.py: invalid syntax (<unknown>, line 6)
#   - Usuários analisados: 18/18
#   - Com misconceptions: 18
#   - MC³ mais frequentes: {'A5': 18, 'G4': 18, 'B8': 18}
#
# Processando questão 1645...
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9681/codes/5835_3232.py: invalid syntax (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9681/codes/5688_1092.py: invalid syntax (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9681/codes/5745_1104.py: expected an indented block after 'if' statement on line 5 (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9681/codes/5745_1102.py: invalid syntax (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9681/codes/5791_6228.py: invalid syntax (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9681/codes/5888_7042.py: expected an indented block after function definition on line 1 (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9681/codes/5922_1645.py: expected ':' (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9830/codes/5923_1645.py: '(' was never closed (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9830/codes/5726_1952.py: unexpected indent (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9830/codes/5953_6247.py: invalid syntax (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9830/codes/5780_6051.py: unexpected indent (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9665/codes/5651_1446.py: cannot assign to expression (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9665/codes/5654_6912.py: invalid syntax (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9665/codes/5868_6655.py: expected an indented block after 'while' statement on line 8 (<unknown>, line 10)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9665/codes/5829_6323.py: invalid syntax (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9665/codes/5829_1599.py: expected ':' (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9754/codes/5658_6699.py: '(' was never closed (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9754/codes/5944_1652.py: expected ':' (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9754/codes/5817_6210.py: expected ':' (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9754/codes/5817_6191.py: invalid syntax. Maybe you meant '==' or ':=' instead of '='? (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9754/codes/5795_6039.py: expected an indented block after 'while' statement on line 3 (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9754/codes/5794_6050.py: invalid syntax (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9754/codes/5795_6228.py: invalid syntax (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9754/codes/5764_6765.py: invalid syntax (<unknown>, line 11)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9754/codes/5899_7040.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9774/codes/5738_1949.py: invalid syntax (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9774/codes/5739_6916.py: invalid syntax. Perhaps you forgot a comma? (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9774/codes/5737_6100.py: expected an indented block after 'if' statement on line 7 (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9774/codes/5681_1092.py: invalid syntax (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9774/codes/5854_6323.py: invalid syntax (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9774/codes/5681_1055.py: invalid syntax. Maybe you meant '==' or ':=' instead of '='? (<unknown>, line 12)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9675/codes/5791_6051.py: expected an indented block after 'while' statement on line 4 (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9675/codes/5745_1102.py: invalid syntax. Perhaps you forgot a comma? (<unknown>, line 11)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9675/codes/5888_7044.py: invalid syntax (<unknown>, line 9)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9675/codes/5791_6043.py: invalid syntax. Perhaps you forgot a comma? (<unknown>, line 14)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9826/codes/5727_5259.py: expected ':' (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9826/codes/5781_2518.py: expected ':' (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9826/codes/5769_6779.py: expected an indented block after 'if' statement on line 5 (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9706/codes/5622_5937.py: invalid syntax (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9706/codes/5766_6781.py: '(' was never closed (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9706/codes/5693_6715.py: expected an indented block after 'if' statement on line 6 (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9912/codes/5677_2970.py: invalid decimal literal (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9912/codes/5677_6498.py: unexpected indent (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9912/codes/5851_2103.py: expected an indented block after 'while' statement on line 6 (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9912/codes/5913_1649.py: '(' was never closed (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9912/codes/5818_6245.py: invalid syntax (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9912/codes/5732_6568.py: invalid syntax (<unknown>, line 14)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9912/codes/5677_6715.py: '(' was never closed (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9912/codes/5677_602.py: expected ':' (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9912/codes/5731_6094.py: invalid syntax (<unknown>, line 13)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9912/codes/5851_2107.py: invalid syntax (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9959/codes/5841_1599.py: expected ':' (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9959/codes/5725_6914.py: invalid syntax. Perhaps you forgot a comma? (<unknown>, line 11)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9959/codes/5843_6788.py: unindent does not match any outer indentation level (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9959/codes/5841_7028.py: expected ':' (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9959/codes/5841_7029.py: invalid syntax (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9673/codes/5672_2970.py: invalid syntax (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9673/codes/5673_1092.py: expected an indented block after 'if' statement on line 3 (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9673/codes/5672_1395.py: expected an indented block after 'if' statement on line 3 (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9673/codes/5736_6568.py: invalid syntax (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9673/codes/5612_1329.py: '(' was never closed (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9673/codes/5735_1949.py: '(' was never closed (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9673/codes/5672_6714.py: '(' was never closed (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9705/codes/5784_2525.py: invalid syntax (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/6456/codes/5923_1645.py: expected ':' (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/6456/codes/5843_6264.py: invalid syntax (<unknown>, line 9)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/6456/codes/5953_1650.py: expected ':' (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/6456/codes/5896_6354.py: expected an indented block after 'for' statement on line 22 (<unknown>, line 23)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/6456/codes/5841_7031.py: '(' was never closed (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/6456/codes/5727_6940.py: unterminated string literal (detected at line 1) (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9876/codes/5923_1645.py: expected an indented block after 'if' statement on line 6 (<unknown>, line 10)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9876/codes/5769_6939.py: invalid syntax (<unknown>, line 13)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9876/codes/5896_2562.py: invalid octal literal (<unknown>, line 33)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9876/codes/5670_1092.py: invalid syntax (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9876/codes/5841_7028.py: invalid syntax (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9876/codes/5781_2518.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9876/codes/5727_6100.py: '(' was never closed (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9876/codes/5782_6048.py: invalid syntax. Maybe you meant '==' or ':=' instead of '='? (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/6376/codes/5766_6933.py: unterminated string literal (detected at line 12) (<unknown>, line 12)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9752/codes/5935_1645.py: '(' was never closed (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9897/codes/5769_6783.py: unindent does not match any outer indentation level (<unknown>, line 16)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9897/codes/5725_6915.py: invalid syntax (<unknown>, line 9)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9897/codes/5727_6100.py: expected an indented block after 'else' statement on line 11 (<unknown>, line 12)
#   - Usuários analisados: 19/19
#   - Com misconceptions: 19
#   - MC³ mais frequentes: {'A5': 19, 'G4': 19, 'B8': 19}
#
# Processando questão 1646...
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9743/codes/5874_3591.py: expected an indented block after 'while' statement on line 8 (<unknown>, line 10)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9743/codes/5848_1599.py: invalid syntax (<unknown>, line 14)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9743/codes/5935_6393.py: invalid syntax (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9743/codes/5874_6831.py: expected an indented block after 'while' statement on line 8 (<unknown>, line 9)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9743/codes/5764_6938.py: expected an indented block after 'else' statement on line 11 (<unknown>, line 12)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9743/codes/5674_6714.py: expected an indented block after 'if' statement on line 5 (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9821/codes/5896_1227.py: invalid syntax (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9821/codes/5670_652.py: invalid syntax (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9821/codes/5601_1560.py: invalid syntax (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9821/codes/5896_2844.py: '(' was never closed (<unknown>, line 11)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9821/codes/5601_1333.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9821/codes/5896_1223.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9708/codes/5742_6100.py: expected ':' (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9708/codes/5744_6074.py: unterminated string literal (detected at line 7) (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9708/codes/5865_3593.py: inconsistent use of tabs and spaces in indentation (<unknown>, line 14)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9708/codes/5784_2518.py: invalid syntax (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9708/codes/5744_6916.py: invalid syntax. Perhaps you forgot a comma? (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/7607/codes/5725_6915.py: expected an indented block after 'if' statement on line 5 (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/7607/codes/5896_2844.py: unexpected indent (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/7607/codes/5923_1646.py: invalid syntax (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9895/codes/5847_2101.py: expected an indented block after 'while' statement on line 4 (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9895/codes/5676_652.py: invalid syntax (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9895/codes/5796_2525.py: '(' was never closed (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9764/codes/5935_1646.py: expected ':' (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9764/codes/5674_2445.py: illegal target for annotation (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9764/codes/5795_6051.py: invalid syntax (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9764/codes/5935_6378.py: expected an indented block after 'for' statement on line 5 (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9764/codes/5796_2518.py: expected an indented block after 'if' statement on line 4 (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9794/codes/5851_2541.py: invalid syntax (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9794/codes/5913_1639.py: invalid syntax (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9801/codes/5659_6474.py: '(' was never closed (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9801/codes/5618_5937.py: '(' was never closed (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9801/codes/5733_1949.py: invalid syntax. Maybe you meant '==' or ':=' instead of '='? (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9801/codes/5618_2938.py: invalid syntax (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9801/codes/5677_3334.py: cannot assign to expression (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9836/codes/5842_2108.py: expected ':' (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9836/codes/5923_6380.py: expected an indented block after 'if' statement on line 6 (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9836/codes/5769_6780.py: cannot assign to expression (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9710/codes/5886_1639.py: invalid decimal literal (<unknown>, line 13)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9710/codes/5619_5937.py: invalid syntax (<unknown>, line 11)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9703/codes/5834_6656.py: unindent does not match any outer indentation level (<unknown>, line 10)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9703/codes/5886_1227.py: invalid syntax (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9703/codes/5865_6646.py: expected an indented block after 'if' statement on line 3 (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9745/codes/5730_1949.py: expected ':' (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9745/codes/5795_6039.py: unexpected indent (<unknown>, line 10)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9745/codes/5795_6228.py: invalid syntax (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9783/codes/5853_1186.py: unterminated string literal (detected at line 1) (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9783/codes/5707_602.py: illegal target for annotation (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9783/codes/5789_5287.py: '(' was never closed (<unknown>, line 15)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9783/codes/5738_1949.py: invalid syntax (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9783/codes/5632_6894.py: illegal target for annotation (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9783/codes/5945_2845.py: invalid syntax (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9783/codes/5707_1397.py: expected ':' (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9783/codes/5945_1646.py: invalid syntax (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9663/codes/5881_2563.py: expected an indented block after 'for' statement on line 6 (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9663/codes/5735_2167.py: expected an indented block after 'if' statement on line 4 (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9663/codes/5735_1949.py: invalid syntax. Maybe you meant '==' or ':=' instead of '='? (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9663/codes/5763_6782.py: invalid syntax (<unknown>, line 22)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9778/codes/5681_1092.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9778/codes/5681_1055.py: expected an indented block after 'if' statement on line 12 (<unknown>, line 15)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9769/codes/5854_1599.py: invalid syntax (<unknown>, line 9)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9769/codes/5901_2574.py: expected ':' (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9769/codes/5901_3176.py: expected ':' (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9834/codes/5668_2445.py: invalid syntax (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9834/codes/5668_1397.py: '(' was never closed (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9686/codes/5608_825.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9686/codes/5812_7013.py: invalid syntax (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9686/codes/5688_1092.py: invalid syntax (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9686/codes/5792_6997.py: unexpected indent (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9841/codes/5687_2445.py: unterminated string literal (detected at line 6) (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9841/codes/5837_6787.py: invalid syntax (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9841/codes/5837_6988.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9850/codes/5733_2167.py: invalid syntax (<unknown>, line 29)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9850/codes/5941_1646.py: '(' was never closed (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9850/codes/5849_5382.py: expected ':' (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9671/codes/5673_1879.py: invalid syntax (<unknown>, line 11)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9671/codes/5673_652.py: invalid syntax (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9671/codes/5671_2973.py: invalid character '⁵' (U+2075) (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9671/codes/5672_6498.py: expected an indented block after 'if' statement on line 2 (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9671/codes/5882_1639.py: unindent does not match any outer indentation level (<unknown>, line 16)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9806/codes/5670_1092.py: invalid syntax (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9806/codes/5727_6104.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9806/codes/5896_1223.py: invalid syntax (<unknown>, line 2)
#   - Usuários analisados: 23/23
#   - Com misconceptions: 23
#   - MC³ mais frequentes: {'A5': 23, 'G4': 23, 'B8': 23}
#
# Processando questão 1647...
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9843/codes/5885_2574.py: invalid syntax (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9843/codes/5619_6895.py: unterminated string literal (detected at line 5) (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9843/codes/5785_6050.py: expected an indented block after 'if' statement on line 8 (<unknown>, line 9)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9843/codes/5865_6829.py: invalid syntax (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/8870/codes/5783_6039.py: unindent does not match any outer indentation level (<unknown>, line 9)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/8870/codes/5785_6042.py: invalid syntax (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/8870/codes/5865_6345.py: invalid syntax (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/8870/codes/5905_6299.py: invalid syntax (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/8870/codes/5743_6526.py: '(' was never closed (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9733/codes/5729_6940.py: invalid syntax (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9733/codes/5674_6498.py: expected an indented block after 'else' statement on line 4 (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9760/codes/5817_7011.py: expected ':' (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9760/codes/5794_6998.py: inconsistent use of tabs and spaces in indentation (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9760/codes/5613_1332.py: invalid syntax (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9760/codes/5613_3711.py: invalid syntax. Perhaps you forgot a comma? (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9760/codes/5848_7028.py: invalid syntax (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9683/codes/5688_1092.py: invalid syntax (<unknown>, line 2)
# ...
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9754/codes/5658_6699.py: '(' was never closed (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9754/codes/5944_1652.py: expected ':' (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9754/codes/5817_6210.py: expected ':' (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9754/codes/5817_6191.py: invalid syntax. Maybe you meant '==' or ':=' instead of '='? (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9754/codes/5795_6039.py: expected an indented block after 'while' statement on line 3 (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9754/codes/5794_6050.py: invalid syntax (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9754/codes/5795_6228.py: invalid syntax (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9754/codes/5764_6765.py: invalid syntax (<unknown>, line 11)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9754/codes/5899_7040.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/7702/codes/5797_6050.py: invalid syntax. Maybe you meant '==' or ':=' instead of '='? (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/7702/codes/5915_2563.py: '(' was never closed (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/7702/codes/5913_6353.py: invalid syntax (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/7702/codes/5818_6199.py: expected ':' (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9955/codes/5737_6100.py: expected an indented block after 'else' statement on line 9 (<unknown>, line 11)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9954/codes/5764_6758.py: expected an indented block after 'if' statement on line 5 (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9954/codes/5764_6747.py: expected ':' (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9954/codes/5764_6777.py: expected ':' (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9954/codes/5795_6811.py: expected ':' (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9954/codes/5764_6934.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5729_5259.py: expected ':' (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5935_2845.py: unexpected indent (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5874_3589.py: invalid syntax (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5729_6568.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5730_1949.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5935_1644.py: invalid syntax (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5935_6361.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5848_1599.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5916_2576.py: invalid decimal literal (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5848_6323.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5729_6100.py: invalid syntax (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5874_6836.py: invalid syntax (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5764_6936.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5935_6374.py: invalid syntax (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5764_6746.py: unexpected indent (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5795_5287.py: unexpected indent (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5916_2574.py: invalid syntax (<unknown>, line 16)
#   - Usuários analisados: 17/17
#   - Com misconceptions: 17
#   - MC³ mais frequentes: {'A5': 17, 'G4': 17, 'B8': 17}
#
# Processando questão 7050...
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9743/codes/5874_3591.py: expected an indented block after 'while' statement on line 8 (<unknown>, line 10)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9743/codes/5848_1599.py: invalid syntax (<unknown>, line 14)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9743/codes/5935_6393.py: invalid syntax (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9743/codes/5874_6831.py: expected an indented block after 'while' statement on line 8 (<unknown>, line 9)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9743/codes/5764_6938.py: expected an indented block after 'else' statement on line 11 (<unknown>, line 12)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9743/codes/5674_6714.py: expected an indented block after 'if' statement on line 5 (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9940/codes/5935_1643.py: unindent does not match any outer indentation level (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9940/codes/5897_2562.py: invalid syntax (<unknown>, line 14)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9940/codes/5935_6373.py: invalid syntax (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9952/codes/5764_6776.py: expected an indented block after 'if' statement on line 4 (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9952/codes/5817_6199.py: expected an indented block after 'while' statement on line 6 (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9758/codes/5730_1949.py: invalid syntax (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9758/codes/5846_6264.py: invalid syntax (<unknown>, line 13)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9758/codes/5817_7011.py: invalid syntax (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9758/codes/5794_6998.py: invalid syntax (<unknown>, line 10)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9758/codes/5897_2844.py: invalid syntax (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9758/codes/5644_3774.py: '(' was never closed (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9758/codes/5674_6498.py: expected an indented block after 'else' statement on line 4 (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9758/codes/5794_6962.py: '(' was never closed (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9758/codes/5935_1640.py: invalid syntax (<unknown>, line 10)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9758/codes/5697_6722.py: expected ':' (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9758/codes/5846_1187.py: invalid syntax (<unknown>, line 9)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9755/codes/5728_6915.py: expected an indented block after 'else' statement on line 8 (<unknown>, line 10)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9755/codes/5874_6838.py: expected an indented block after 'while' statement on line 11 (<unknown>, line 11)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9755/codes/5817_6197.py: expected ':' (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9755/codes/5728_3041.py: invalid syntax (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9755/codes/5764_6934.py: invalid syntax (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9755/codes/5899_7040.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9739/codes/5817_6196.py: invalid syntax (<unknown>, line 10)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9739/codes/5730_1949.py: invalid syntax (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9739/codes/5874_3591.py: expected an indented block after 'if' statement on line 7 (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9739/codes/5676_652.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9739/codes/5676_1092.py: invalid syntax (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9739/codes/5764_6783.py: expected an indented block after 'if' statement on line 4 (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9895/codes/5847_2101.py: expected an indented block after 'while' statement on line 4 (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9895/codes/5676_652.py: invalid syntax (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9895/codes/5796_2525.py: '(' was never closed (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9759/codes/5795_6051.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9733/codes/5729_6940.py: invalid syntax (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9733/codes/5674_6498.py: expected an indented block after 'else' statement on line 4 (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9764/codes/5935_1646.py: expected ':' (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9764/codes/5674_2445.py: illegal target for annotation (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9764/codes/5795_6051.py: invalid syntax (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9764/codes/5935_6378.py: expected an indented block after 'for' statement on line 5 (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9764/codes/5796_2518.py: expected an indented block after 'if' statement on line 4 (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9888/codes/5934_6756.py: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 20)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9888/codes/5739_6094.py: unexpected indent (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9888/codes/5630_6694.py: invalid syntax (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9888/codes/5852_2107.py: unexpected indent (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9888/codes/5934_6195.py: expected ':' (<unknown>, line 10)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9888/codes/5788_6580.py: invalid syntax (<unknown>, line 9)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9888/codes/5854_6323.py: expected ':' (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9756/codes/5795_5287.py: expected an indented block after 'if' statement on line 6 (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9754/codes/5658_6699.py: '(' was never closed (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9754/codes/5944_1652.py: expected ':' (<unknown>, line 8)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9754/codes/5817_6210.py: expected ':' (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9754/codes/5817_6191.py: invalid syntax. Maybe you meant '==' or ':=' instead of '='? (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9754/codes/5795_6039.py: expected an indented block after 'while' statement on line 3 (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9754/codes/5794_6050.py: invalid syntax (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9754/codes/5795_6228.py: invalid syntax (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9754/codes/5764_6765.py: invalid syntax (<unknown>, line 11)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9754/codes/5899_7040.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/7702/codes/5797_6050.py: invalid syntax. Maybe you meant '==' or ':=' instead of '='? (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/7702/codes/5915_2563.py: '(' was never closed (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/7702/codes/5913_6353.py: invalid syntax (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/7702/codes/5818_6199.py: expected ':' (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9955/codes/5737_6100.py: expected an indented block after 'else' statement on line 9 (<unknown>, line 11)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9954/codes/5764_6758.py: expected an indented block after 'if' statement on line 5 (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9954/codes/5764_6747.py: expected ':' (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9954/codes/5764_6777.py: expected ':' (<unknown>, line 6)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9954/codes/5795_6811.py: expected ':' (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9954/codes/5764_6934.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5729_5259.py: expected ':' (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5935_2845.py: unexpected indent (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5874_3589.py: invalid syntax (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5729_6568.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5730_1949.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5935_1644.py: invalid syntax (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5935_6361.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5848_1599.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5916_2576.py: invalid decimal literal (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5848_6323.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5729_6100.py: invalid syntax (<unknown>, line 7)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5874_6836.py: invalid syntax (<unknown>, line 5)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5764_6936.py: invalid syntax (<unknown>, line 1)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5935_6374.py: invalid syntax (<unknown>, line 2)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5764_6746.py: unexpected indent (<unknown>, line 4)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5795_5287.py: unexpected indent (<unknown>, line 3)
# Erro ao fazer parsing de ../Etapa_3/UsuariosUnicos/9978/codes/5916_2574.py: invalid syntax (<unknown>, line 16)
#   - Usuários analisados: 17/17
#   - Com misconceptions: 17
#   - MC³ mais frequentes: {'A5': 17, 'G4': 17, 'B8': 17}
#
# Salvando resumo em misconceptions_summary_por_questao.csv...
# Salvando detalhes em misconceptions_detailed_por_usuario.csv...
#
# Resumo geral:
# - Total de questões processadas: 164
# - Total de análises de usuários: 3421
# - Arquivos gerados: misconceptions_summary_por_questao.csv, misconceptions_detailed_por_usuario.csv
# - Total usuários analisados: 3421
# - Total com misconceptions: 3417
# - Percentual geral com misconceptions: 99.88%
# - Top 5 MC³ mais frequentes: {'G4': 3417, 'A5': 3394, 'B8': 3380, 'B9': 2338, 'B4': 2230}
