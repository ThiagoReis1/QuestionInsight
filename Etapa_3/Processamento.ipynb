# %% [markdown]
# # Etapa 3 — Processamento das questões e das notas
#
# Este notebook transforma as referências filtradas pela Etapa 2 em métricas de questões, médias de usuários e índices consumidos pelas etapas seguintes. A execução preserva `Extraidos/` como fonte física: os arquivos são lidos diretamente e não são copiados ou movidos.

# %%
# Em uma instalação limpa, execute uma vez no terminal ou remova o comentário abaixo.
# %pip install numpy scipy matplotlib seaborn tqdm

import csv
import json
import math
import os
import re
from concurrent.futures import ThreadPoolExecutor
from datetime import datetime
from dataclasses import dataclass, field
from pathlib import Path
from typing import Iterable, List

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import mode, spearmanr

try:
    from tqdm import tqdm
except ImportError:
    def tqdm(iterable=None, total=None, desc=None, **_kwargs):
        if iterable is None:
            return range(total or 0)
        return iterable

# %% [markdown]
# ## 1. Dependências e paralelismo
#
# São importadas as bibliotecas numéricas, estatísticas e de visualização utilizadas no processamento. A leitura de arquivos pode usar múltiplos workers configurados por `ETAPA3_WORKERS`; o paralelismo acelera a entrada/saída, mas não muda as regras de filtragem.

# %%
from pathlib import Path

# Caminho do índice JSON produzido pela Etapa 2.
CAMINHO_REFERENCIAS = Path('../Etapa_2/output/referencias_processamento.json')

# Diretório reservado para gráficos opcionais gerados pelas células finais.
PASTA_GRAFICOS = Path('output') / 'Graficos'
PASTA_SAIDA = Path('output')
CAMINHO_LOG_ETAPA3 = PASTA_SAIDA / 'etapa3_progresso.log'


def registrar_progresso_etapa3(mensagem: str) -> None:
    linha = f'[{datetime.now().strftime("%Y-%m-%d %H:%M:%S")}] {mensagem}'
    print(linha, flush=True)
    CAMINHO_LOG_ETAPA3.parent.mkdir(parents=True, exist_ok=True)
    with CAMINHO_LOG_ETAPA3.open('a', encoding='utf-8') as arquivo_log:
        arquivo_log.write(linha + '\n')
        arquivo_log.flush()



# Uma questão só é elegível com pelo menos 16 estudantes distintos.
MINIMO_ESTUDANTES_DISTINTOS_POR_QUESTAO = 16

# Estruturas globais preenchidas progressivamente pelas etapas do notebook.
lista_questoes = []
lista_questoes_com_dificuldade = []
lista_questoes_completas = []
dicionario_usuarios_processados = {}


def deduplicar_usuarios_em_memoria(registros: list[dict]) -> tuple[list[dict], int]:
    """Consolida usuários repetidos pelo ID sem alterar o JSON no disco.

    As raízes e os arquivos são unidos por caminho relativo. Assim, cada ID
    vira um único usuário para as métricas da Etapa 3, mas todas as referências
    válidas de seus diferentes escopos permanecem disponíveis.
    """
    por_id: dict[str, dict] = {}
    ocorrencias = 0
    for registro in registros:
        id_usuario = str(registro.get('id'))
        if id_usuario in por_id:
            ocorrencias += 1
            destino = por_id[id_usuario]
        else:
            destino = {
                'id': id_usuario,
                'roots': [],
                'files': {},
            }
            por_id[id_usuario] = destino

        destino['roots'] = sorted(set(destino.get('roots', [])) | set(registro.get('roots', [])))
        for tipo, itens in registro.get('files', {}).items():
            existentes = {
                item.get('path'): item
                for item in destino.setdefault('files', {}).get(tipo, [])
                if item.get('path')
            }
            for item in itens:
                caminho = item.get('path')
                if caminho and caminho not in existentes:
                    existentes[caminho] = item
            destino['files'][tipo] = sorted(existentes.values(), key=lambda item: item.get('path', ''))

    return list(por_id.values()), ocorrencias

def gerar_json_colisoes_usuarios(dados: dict) -> None:
    """Salva colisões de usuários durante a deduplicação, sem alterar o JSON-fonte."""
    raiz_fisica = Path(dados['_source_root'])
    colisoes = []
    for registro in dados.get('users', []):
        ocorrencias = []
        for raiz_relativa in registro.get('roots', []):
            pasta_usuario = (raiz_fisica / raiz_relativa).resolve()
            user_data = pasta_usuario / 'user.data'
            ocorrencias.append({
                'pasta_usuario': str(pasta_usuario),
                'user_data': str(user_data),
                'user_data_existe': user_data.is_file(),
                'user_data_conteudo': (
                    user_data.read_text(encoding='utf-8', errors='replace')
                    if user_data.is_file() else None
                ),
            })
        if len(ocorrencias) > 1:
            colisoes.append({
                'id_usuario': str(registro.get('id')),
                'quantidade_ocorrencias': len(ocorrencias),
                'ocorrencias': ocorrencias,
            })

    relatorio = {
        'quantidade_colisoes': len(colisoes),
        'descricao': (
            'Usuários cujo mesmo ID aparece em mais de uma pasta de turma/escopo. '
            'Cada ocorrência inclui o caminho e o conteúdo de user.data.'
        ),
        'colisoes': sorted(colisoes, key=lambda item: item['id_usuario']),
    }
    caminho_saida = Path('output') / 'colisoes_usuarios_user_data.json'
    caminho_saida.parent.mkdir(parents=True, exist_ok=True)
    caminho_saida.write_text(
        json.dumps(relatorio, ensure_ascii=False, indent=2) + '\n',
        encoding='utf-8',
    )

def gerar_json_grades_exam_anomalas(dados: dict, limite: int = 6) -> None:
    """Registra usuários com mais de ``limite`` grades exam no mesmo escopo."""
    anomalias = []
    for registro in dados.get('users', []):
        por_escopo = {}
        for item in registro.get('files', {}).get('grades', []):
            caminho = item.get('path', '').replace('\\', '/')
            partes = caminho.split('/')
            try:
                indice_users = partes.index('users')
                escopo = '/'.join(partes[:indice_users + 2])
            except ValueError:
                continue
            por_escopo.setdefault(escopo, []).append(item)
        for escopo, grades in sorted(por_escopo.items()):
            if len(grades) > limite:
                anomalias.append({
                    'id_usuario': str(registro.get('id')),
                    'escopo': escopo,
                    'quantidade_grades_exam': len(grades),
                    'grades': sorted(grades, key=lambda item: item.get('path', '')),
                })
    relatorio = {
        'limite_grades_exam_por_escopo': limite,
        'quantidade_anomalias': len(anomalias),
        'descricao': (
            'Usuários com mais de 6 grades de assessments exam no mesmo escopo. '
            'Esses casos devem ser revisados manualmente.'
        ),
        'anomalias': anomalias,
    }
    caminho_saida = Path('output') / 'anomalias_grades_exam_por_usuario_escopo.json'
    caminho_saida.parent.mkdir(parents=True, exist_ok=True)
    caminho_saida.write_text(
        json.dumps(relatorio, ensure_ascii=False, indent=2) + '\n',
        encoding='utf-8',
    )



def _ler_start_assessment(caminho: Path) -> str:
    """Lê o campo ``---- start:`` do assessment para ordenar repetições."""
    try:
        for linha in caminho.read_text(encoding='utf-8', errors='replace').splitlines():
            if linha.strip().lower().startswith('---- start:'):
                return linha.split(':', 1)[1].strip()
    except OSError:
        pass
    return ''


def _metadata_grade_exam(dados: dict, item: dict) -> dict:
    """Resolve metadados e nota da grade a partir da referência do JSON."""
    path_string = item.get('path', '').replace('\\', '/')
    partes = path_string.split('/')
    try:
        indice_users = partes.index('users')
    except ValueError:
        return {}
    escopo = '/'.join(partes[:indice_users])
    assessment_id = str(item.get('assessment') or Path(path_string).stem)
    assessment_path = f'{escopo}/assessments/{assessment_id}.data'
    assessment = next(
        (a for a in dados.get('assessments', []) if a.get('path') == assessment_path),
        {},
    )
    raiz = Path(dados['_source_root'])
    caminho_assessment = raiz / assessment_path
    inicio = _ler_start_assessment(caminho_assessment)
    nota = _ler_nota_grade_usuario(raiz / path_string)
    return {
        'path': path_string,
        'name': item.get('name', Path(path_string).name),
        'assessment': assessment_id,
        'assessment_path': assessment_path,
        'assessment_title': assessment.get('assessment_title', ''),
        'assessment_type': assessment.get('type', 'exam'),
        'group': assessment.get('group'),
        'group_description': assessment.get('group_description'),
        'start': inicio,
        'nota': nota,
        'escopo': escopo,
    }


def tratar_anomalias_grades_por_tp(dados: dict, limite: int = 6) -> None:
    """Classifica e trata excesso de grades e repetição de TPs.

    ``mais_de_6_grades_exam`` identifica 7 ou mais grades no escopo.
    ``tp_repetido_com_menos_de_6_tps`` identifica TP repetido quando há
    menos de 6 TPs distintos. Em qualquer deduplicação, o assessment mais
    antigo por TP é mantido segundo ``---- start:``.
    """
    anomalias = []
    for registro in dados.get('users', []):
        grades_por_escopo = {}
        for item in registro.get('files', {}).get('grades', []):
            meta = _metadata_grade_exam(dados, item)
            if meta.get('group'):
                grades_por_escopo.setdefault(meta['escopo'], []).append(meta)
        grades_mantidas = []
        for escopo, grades in sorted(grades_por_escopo.items()):
            por_tp = {}
            for grade in grades:
                por_tp.setdefault(grade['group'], []).append(grade)
            quantidade_tps = len(por_tp)
            possui_repeticao = any(len(itens) > 1 for itens in por_tp.values())
            labels = []
            if len(grades) > limite:
                labels.append('mais_de_6_grades_exam')
            if quantidade_tps < limite and possui_repeticao:
                labels.append('tp_repetido_com_menos_de_6_tps')
            if not labels:
                grades_mantidas.extend(grade['path'] for grade in grades)
                continue

            usados = []
            descartados = []
            for grupo, repeticoes in sorted(por_tp.items()):
                ordenadas = sorted(
                    repeticoes,
                    key=lambda item: (item.get('start') or '9999-99-99 99:99', item['path']),
                )
                usados.append(ordenadas[0])
                descartados.extend(ordenadas[1:])
            # Como o domínio possui somente TP 01 a TP 06, um escopo com
            # mais de 6 grades necessariamente tem repetição. Mantém-se apenas
            # uma grade por TP: a do assessment mais antigo pelo campo start.
            grades_mantidas.extend(grade['path'] for grade in usados)
            anomalias.append({
                'id_usuario': str(registro.get('id')),
                'escopo': escopo,
                'labels_anomalia': labels,
                'quantidade_grades_exam': len(grades),
                'quantidade_tps': quantidade_tps,
                'quantidade_grades_usadas': len(usados),
                'quantidade_grades_descartadas': len(descartados),
                'grades_usadas_no_calculo': usados,
                'grades_descartadas_por_repeticao': [
                    {
                        **grade,
                        'motivo_descarte': (
                            'Assessment mais novo descartado; assessment mais antigo '
                            'mantido no cálculo'
                        ),
                    }
                    for grade in descartados
                ],
            })
        permitidos = set(grades_mantidas)
        if permitidos:
            registro['files']['grades'] = [
                item for item in registro.get('files', {}).get('grades', [])
                if item.get('path', '').replace('\\', '/') in permitidos
            ]
    relatorio = {
        'limite_tps_por_usuario_escopo': limite,
        'labels_anomalia': {
            'mais_de_6_grades_exam': 'Usuário possui 7 ou mais grades exam; mantém-se somente o assessment mais antigo de cada TP',
            'tp_repetido_com_menos_de_6_tps': 'Usuário possui TP repetido e menos de 6 TPs distintos no escopo',
        },
        'regra': (
            'O assessment mais antigo por TP é mantido pelo campo ---- start:. '
            'O usuário nunca é excluído; somente assessments repetidos mais novos '
            'podem ser retirados das médias.'
        ),
        'quantidade_anomalias': len(anomalias),
        'anomalias': sorted(anomalias, key=lambda item: (item['id_usuario'], item['escopo'])),
    }
    caminho_saida = Path('output') / 'anomalias_grades_exam_por_usuario_escopo.json'
    caminho_saida.parent.mkdir(parents=True, exist_ok=True)
    caminho_saida.write_text(json.dumps(relatorio, ensure_ascii=False, indent=2) + '\n', encoding='utf-8')

def _ler_start_assessment(caminho: Path) -> str:
    """Lê o campo ``---- start:`` do assessment para ordenar repetições."""
    try:
        for linha in caminho.read_text(encoding='utf-8', errors='replace').splitlines():
            if linha.strip().lower().startswith('---- start:'):
                return linha.split(':', 1)[1].strip()
    except OSError:
        pass
    return ''


def _metadata_grade_exam(dados: dict, item: dict) -> dict:
    """Resolve metadados e nota da grade a partir da referência do JSON."""
    path_string = item.get('path', '').replace('\\', '/')
    partes = path_string.split('/')
    try:
        indice_users = partes.index('users')
    except ValueError:
        return {}
    escopo = '/'.join(partes[:indice_users])
    assessment_id = str(item.get('assessment') or Path(path_string).stem)
    assessment_path = f'{escopo}/assessments/{assessment_id}.data'
    assessment = next(
        (a for a in dados.get('assessments', []) if a.get('path') == assessment_path),
        {},
    )
    raiz = Path(dados['_source_root'])
    caminho_assessment = raiz / assessment_path
    inicio = _ler_start_assessment(caminho_assessment)
    nota = _ler_nota_grade_usuario(raiz / path_string)
    return {
        'path': path_string,
        'name': item.get('name', Path(path_string).name),
        'assessment': assessment_id,
        'assessment_path': assessment_path,
        'assessment_title': assessment.get('assessment_title', ''),
        'assessment_type': assessment.get('type', 'exam'),
        'group': assessment.get('group'),
        'group_description': assessment.get('group_description'),
        'start': inicio,
        'nota': nota,
        'escopo': escopo,
    }


def selecionar_primeira_experiencia_usuarios(dados: dict) -> None:
    """Mantém em memória somente o primeiro escopo de cada usuário.

    Os registros do JSON original já foram consolidados por ID. As raízes são
    ordenadas pelo caminho do dataset, que preserva a ordem cronológica dos
    semestres (por exemplo, 2016-1 antes de 2016-2). Nenhum arquivo no disco e
    nenhum JSON da Etapa 2 é alterado.
    """
    for registro in dados.get('users', []):
        raizes = sorted(set(registro.get('roots', [])))
        if not raizes:
            continue
        primeira_raiz = raizes[0]
        prefixo = primeira_raiz.rstrip('/') + '/'
        registro['roots'] = [primeira_raiz]
        arquivos_filtrados = {}
        for tipo, itens in registro.get('files', {}).items():
            arquivos_filtrados[tipo] = [
                item for item in itens
                if item.get('path', '').replace('\\', '/').startswith(prefixo)
            ]
        registro['files'] = arquivos_filtrados
    dados['_first_experience_only'] = True

def _assessment_id_from_item_path(path_string: str, kind: str) -> str | None:
    stem = Path(path_string.replace('\\', '/')).stem
    if kind == 'grades' and stem.isdigit():
        return stem
    if '_' in stem:
        candidate = stem.split('_', 1)[0]
        return candidate if candidate.isdigit() else None
    return None


def _assessment_type_for_item(dados: dict, item: dict, kind: str) -> str:
    """Lê o tipo do assessment pai de uma grade/execution/código."""
    path_string = item.get('path', '').replace('\\', '/')
    partes = path_string.split('/')
    try:
        indice_users = partes.index('users')
        escopo = '/'.join(partes[:indice_users])
    except ValueError:
        return 'desconhecido'
    assessment_id = _assessment_id_from_item_path(path_string, kind)
    if assessment_id is None:
        return 'desconhecido'
    raiz = Path(dados['_source_root'])
    arquivo = raiz / escopo / 'assessments' / f'{assessment_id}.data'
    try:
        for linha in arquivo.read_text(encoding='utf-8', errors='replace').splitlines():
            if linha.strip().lower().startswith('---- type:'):
                return linha.split(':', 1)[1].strip().lower()
    except OSError:
        pass
    return 'desconhecido'


def filtrar_registros_exam_em_memoria(dados: dict) -> None:
    """Remove em memória referências cujo assessment pai não é exam."""
    for registro in dados.get('users', []):
        arquivos_filtrados = {}
        for tipo, itens in registro.get('files', {}).items():
            if tipo in {'grades', 'executions', 'codes', 'codemirror'}:
                itens = [
                    item for item in itens
                    if _assessment_type_for_item(dados, item, tipo) == 'exam'
                ]
            arquivos_filtrados[tipo] = itens
        registro['files'] = arquivos_filtrados
    # A Etapa 3 calcula notas somente a partir de grades/*.log. Portanto,
    # execution de exam sem grades/<assessment>.log não torna o usuário válido.
    # Exigir grades aqui também protege contra um referencias_processamento.json
    # antigo que ainda contenha executions/codes de exam.
    dados['users'] = [
        registro for registro in dados.get('users', [])
        if registro.get('files', {}).get('grades')
    ]

def _assessment_metadata_for_item(dados: dict, item: dict, kind: str) -> dict:
    """Retorna grupo e título do assessment pai de uma referência."""
    path_string = item.get('path', '').replace('\\', '/')
    partes = path_string.split('/')
    try:
        indice_users = partes.index('users')
    except ValueError:
        return {}
    escopo = '/'.join(partes[:indice_users])
    assessment_id = _assessment_id_from_item_path(path_string, kind)
    if assessment_id is None:
        return {}
    alvo = f'{escopo}/assessments/{assessment_id}.data'
    return next((a for a in dados.get('assessments', []) if a.get('path') == alvo), {})

def carregar_referencias(caminho: str | Path) -> dict:
    """Carrega o índice e resolve a raiz física sem copiar arquivos."""
    caminho_json = Path(caminho).resolve()
    dados = json.loads(caminho_json.read_text(encoding='utf-8'))
    raiz_fisica = Path(dados['source_root'])
    if not raiz_fisica.is_absolute():
        raiz_fisica = (caminho_json.parent / raiz_fisica).resolve()
    dados['_source_root'] = str(raiz_fisica)
    dados['_references_path'] = str(caminho_json)
    usuarios_deduplicados, ocorrencias_repetidas = deduplicar_usuarios_em_memoria(dados.get('users', []))
    dados['users'] = usuarios_deduplicados
    dados['_duplicate_user_occurrences'] = ocorrencias_repetidas
    dados['_users_by_id'] = {str(registro.get('id')): registro for registro in usuarios_deduplicados}
    # O relatório conserva todas as ocorrências antes do recorte da primeira experiência.
    gerar_json_colisoes_usuarios(dados)
    gerar_json_grades_exam_anomalas(dados, limite=6)
    selecionar_primeira_experiencia_usuarios(dados)
    filtrar_registros_exam_em_memoria(dados)
    dados['_users_by_id'] = {str(registro.get('id')): registro for registro in dados.get('users', [])}
    return dados


def caminhos_usuario(dados: dict, id_usuario: str, tipo_arquivo: str, sufixo: str | None = None):
    """Produz caminhos dos arquivos de um usuário sem criar cópias."""
    raiz_fisica = Path(dados['_source_root'])
    registro = dados.get('_users_by_id', {}).get(str(id_usuario))
    if registro is None:
        return
    for item in registro.get('files', {}).get(tipo_arquivo, []):
        caminho = raiz_fisica / item['path']
        if caminho.is_file() and (sufixo is None or caminho.name.endswith(sufixo)):
            yield caminho


def caminhos_assessments(dados: dict):
    raiz_fisica = Path(dados['_source_root'])
    for item in dados.get('assessments', []):
        caminho = raiz_fisica / item['path']
        if caminho.is_file():
            yield caminho


CAMINHO_LOG_ETAPA3.parent.mkdir(parents=True, exist_ok=True)
CAMINHO_LOG_ETAPA3.write_text('', encoding='utf-8')
registrar_progresso_etapa3('Etapa 3 iniciada')
registrar_progresso_etapa3(
    f'Configuração: {max(1, min(int(os.environ.get("ETAPA3_WORKERS", os.cpu_count() or 1)), 32))} workers'
)
registrar_progresso_etapa3('Fase 1/5 iniciada — carregando e filtrando referências')
dados_referencias = carregar_referencias(CAMINHO_REFERENCIAS)
registrar_progresso_etapa3(
    f'Fase 1/5 concluída — usuários={len(dados_referencias.get("users", [])):,}; '
    f'assessments={len(dados_referencias.get("assessments", [])):,}'
)
print(f"Referências carregadas: {dados_referencias['_references_path']}")
print(f"Base física: {dados_referencias['_source_root']}")
print(f"Workers da Etapa 3: {max(1, min(int(os.environ.get('ETAPA3_WORKERS', os.cpu_count() or 1)), 32))}")

# %% [markdown]
# ## 2. Configuração e entradas
#
# A Etapa 3 recebe `Etapa_2/output/referencias_processamento.json`. Esse índice define os assessments, usuários, executions e grades que podem ser lidos. As variáveis globais desta seção controlam caminhos, limite mínimo de estudantes e diretórios de saída; elas não criam cópias da base física.

# %%
print(f"Caminho do JSON: {CAMINHO_REFERENCIAS.resolve()}")
print(f"JSON existe? {CAMINHO_REFERENCIAS.exists()}")
print(f"Base física resolvida: {dados_referencias['_source_root']}")

# %% [markdown]
# ## 3. Estruturas de dados
#
# As classes `Questao`, `Exercise`, `Assessment`, `Curso` e `Usuario` representam as entidades usadas no cálculo. Elas mantêm o contrato interno do notebook e os nomes necessários para as exportações CSV e JSON.

# %%
@dataclass
class Questao:
    id: int
    dificuldade: float = 0.0
    discriminacao: float = 0.0
    respostas: int = 0
    usuarios_respondidos: list[str] = field(default_factory=list)
    notas_por_usuario: dict[str, float] = field(default_factory=dict)


@dataclass
class Exercise:
    number: int
    codes: List[int]


@dataclass
class Assessment:
    assessment_title: str
    class_name: str
    class_number: int
    start: str
    end: str
    language: str
    codemirror_mode: str
    type: str
    weight: int
    total_exercises: int
    exercises: List[Exercise] = field(default_factory=list)
    filename: str = ""


@dataclass
class Curso:
    laboratorios: List[Assessment] = field(default_factory=list)


@dataclass
class Usuario:
    id: str
    media: float = 0.0
    notas: List[float] = field(default_factory=list)

    def adicionar_nota(self, nota: float):
        self.notas.append(nota)

    def calcular_media(self):
        # Mantém a regra original: soma das notas dividida por 6.
        self.media = sum(self.notas) / 6 if self.notas else 0

# %% [markdown]
# ## 4. Leitura dos assessments
#
# Os caminhos dos assessments são resolvidos a partir do índice da Etapa 2. Cada arquivo é lido diretamente da raiz física e convertido em objetos `Assessment`. Esta seção apenas carrega e organiza os dados; ainda não aplica o filtro de 16 estudantes.

# %%
def ler_assessment_file(filepath: str | Path) -> Assessment:
    filepath = Path(filepath)
    assessment_data = {}
    exercises = []
    in_exercises_section = False

    with filepath.open('r', encoding='utf-8') as file:
        for raw_line in file:
            line = raw_line.strip()
            if line.startswith('-- ASSESSMENT DATA:'):
                in_exercises_section = False
                continue
            if line.startswith('-- EXERCISES:'):
                in_exercises_section = True
                continue
            if not in_exercises_section:
                match = re.match(r'---- (.+?): (.+)', line)
                if match:
                    key, value = match.groups()
                    if key == 'assessment title': assessment_data['assessment_title'] = value
                    elif key == 'class name': assessment_data['class_name'] = value
                    elif key == 'class number': assessment_data['class_number'] = int(value)
                    elif key == 'start': assessment_data['start'] = value
                    elif key == 'end': assessment_data['end'] = value
                    elif key == 'language': assessment_data['language'] = value
                    elif key == 'codemirror mode': assessment_data['codemirror_mode'] = value
                    elif key == 'type': assessment_data['type'] = value
                    elif key == 'weight': assessment_data['weight'] = int(value)
                    elif key == 'total_exercises': assessment_data['total_exercises'] = int(value)
            else:
                match = re.match(r'---- exercise (\d+): (.+)', line)
                if match:
                    number, codes = match.groups()
                    exercises.append(Exercise(number=int(number), codes=list(map(int, codes.split(' or ')))))

    return Assessment(
        assessment_title=assessment_data['assessment_title'], class_name=assessment_data['class_name'],
        class_number=assessment_data['class_number'], start=assessment_data['start'], end=assessment_data['end'],
        language=assessment_data['language'], codemirror_mode=assessment_data['codemirror_mode'],
        type=assessment_data['type'], weight=assessment_data['weight'],
        total_exercises=assessment_data['total_exercises'], exercises=exercises, filename=filepath.name,
    )


def processar_assessments(assessments_path, todos=0):
    curso = Curso()
    data = carregar_referencias(assessments_path)
    for filepath in caminhos_assessments(data):
        try:
            curso.laboratorios.append(ler_assessment_file(filepath))
        except (KeyError, ValueError) as error:
            print(f'Assessment ignorado: {filepath} ({error})')
    return curso


def imprimir_assessment(assessment: Assessment):
    print(f"Assessment Title: {assessment.assessment_title}")
    print(f"Class Name: {assessment.class_name}")
    print(f"Class Number: {assessment.class_number}")
    print(f"Start: {assessment.start}")
    print(f"End: {assessment.end}")
    print(f"Language: {assessment.language}")
    print(f"Codemirror Mode: {assessment.codemirror_mode}")
    print(f"Type: {assessment.type}")
    print(f"Weight: {assessment.weight}")
    print(f"Total Exercises: {assessment.total_exercises}")
    print(f"Filename: {assessment.filename}")
    print("Exercises:")
    for exercise in assessment.exercises:
        print(f"  Exercise {exercise.number}: {' or '.join(map(str, exercise.codes))}")
    print()


def imprimir_curso(curso: Curso):
    for assessment in curso.laboratorios:
        imprimir_assessment(assessment)

# %% [markdown]
# ## 5. Catalogação das questões
#
# Os exercícios dos assessments são percorridos e as questões são catalogadas por ID. Um conjunto de IDs já vistos impede que a mesma questão seja cadastrada duas vezes quando aparece em mais de um assessment.

# %%
registrar_progresso_etapa3('Fase 2/5 iniciada — leitura dos assessments')
curso = processar_assessments(CAMINHO_REFERENCIAS)
registrar_progresso_etapa3(f'Fase 2/5 concluída — assessments lidos={len(curso.laboratorios):,}')
imprimir_curso(curso)

# %% [markdown]
# ## 6. Consolidação das execuções
#
# As executions válidas são agrupadas por usuário e questão. A Etapa 3 consolida os dados necessários para saber quantos estudantes distintos responderam cada questão e quais respostas podem participar das métricas.

# %%
def catalogar_questoes():
    ids_adicionados = set()
    catalogo = []
    for lab in curso.laboratorios:
        for exercise in lab.exercises:
            for code in exercise.codes:
                if code not in ids_adicionados:
                    catalogo.append(Questao(id=code))
                    ids_adicionados.add(code)
    return catalogo

# %% [markdown]
# ## 7. Filtro de elegibilidade das questões
#
# Uma questão só segue para as métricas quando possui pelo menos `MINIMO_ESTUDANTES_DISTINTOS_POR_QUESTAO = 16` estudantes distintos. Questões abaixo desse limite são excluídas das métricas, do CSV de questões e do índice final de usuários.

# %%
registrar_progresso_etapa3('Fase 3/5 iniciada — catalogação das questões')
lista_questoes = catalogar_questoes()
registrar_progresso_etapa3(f'Fase 3/5 concluída — questões catalogadas={len(lista_questoes):,}')
print(f"Questões catalogadas: {len(lista_questoes):,}")
for questao in lista_questoes:
    print(questao)

# %% [markdown]
# ## 8. Leitura das grades e notas agregadas
#
# Os arquivos `grades/*.log` representam a nota agregada de um assessment e usam principalmente `final score (0-10)`. Essa nota é usada para calcular a média do usuário na Etapa 3. Ela não deve ser confundida com a nota percentual de uma questão encontrada nos executions.

# %%
def obter_nota_arquivo(arquivo_path: str | Path) -> float | None:
    """Retorna a nota da última SUBMITION, inclusive no formato em duas linhas.

    Formatos aceitos:
        -- GRADE: 100%
        -- GRADE:
        100%

    Blocos TEST, OUTPUT e ERROR são ignorados. A última SUBMITION com GRADE
    é a nota final do arquivo.
    """
    separador = '*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*'
    try:
        conteudo = Path(arquivo_path).read_text(encoding='utf-8')
    except (FileNotFoundError, OSError, UnicodeError):
        return 0.0

    def notas_do_bloco(bloco: str) -> list[float]:
        linhas = bloco.splitlines()
        notas = []
        for indice, linha in enumerate(linhas):
            correspondencia = re.match(
                r'^\s*-+\s*GRADE\s*:\s*(.*?)\s*$',
                linha,
                flags=re.IGNORECASE,
            )
            if not correspondencia:
                continue
            valor_texto = correspondencia.group(1).strip()
            if not valor_texto:
                for proxima_linha in linhas[indice + 1:]:
                    candidato = proxima_linha.strip()
                    if not candidato:
                        continue
                    valor_texto = candidato
                    break
            numero = re.search(
                r'-?\d+(?:[.,]\d+)?',
                valor_texto,
            )
            if numero:
                valor = float(numero.group(0).replace(',', '.'))
                notas.append(max(0.0, min(100.0, valor)))
        return notas

    ultima_nota = None
    for bloco in conteudo.split(separador):
        if not re.search(
            r'^\s*==\s*SUBMITION\b',
            bloco,
            flags=re.IGNORECASE | re.MULTILINE,
        ):
            continue
        notas = notas_do_bloco(bloco)
        if notas:
            ultima_nota = notas[-1]

    # Compatibilidade com logs antigos sem o cabeçalho SUBMITION.
    if ultima_nota is None:
        notas = notas_do_bloco(conteudo)
        if notas:
            ultima_nota = notas[-1]

    return ultima_nota


def _ler_execucao(task: tuple[str, str, str]) -> tuple[str, int, float | None] | None:
    """Lê uma execução e retorna usuário, questão e nota da tentativa."""
    id_usuario, caminho, nome_sem_extensao = task
    try:
        id_questao = int(nome_sem_extensao.rsplit('_', 1)[-1])
    except (ValueError, IndexError):
        return None
    return id_usuario, id_questao, obter_nota_arquivo(caminho)


def _tarefas_execucao(data: dict) -> list[tuple[str, str, str]]:
    """Lista logs válidos sem duplicar o mesmo caminho físico."""
    tarefas = []
    caminhos_vistos = set()
    raiz_fisica = Path(data['_source_root'])
    for registro_usuario in data.get('users', []):
        id_usuario = str(registro_usuario['id'])
        for item in registro_usuario.get('files', {}).get('executions', []):
            caminho = raiz_fisica / item['path']
            chave = (id_usuario, str(caminho.resolve()))
            if chave in caminhos_vistos or not caminho.is_file() or caminho.suffix.lower() != '.log':
                continue
            caminhos_vistos.add(chave)
            tarefas.append((id_usuario, str(caminho), caminho.stem))
    return sorted(tarefas, key=lambda tarefa: (tarefa[0], tarefa[2], tarefa[1]))


def calcular_dificuldade(questoes):
    for questao in questoes:
        if questao.respostas > 0:
            questao.dificuldade = 100 - (questao.dificuldade / questao.respostas)
        else:
            questao.dificuldade = 0
    return questoes


def respostas_questao(questoes, data=None):
    """Coleta uma única resposta por usuário e questão.

    Um usuário pode ter várias tentativas da mesma questão. Portanto, não se
    deve incrementar ``respostas`` diretamente para cada log. Primeiro
    consolidamos por ``(id_usuario, id_questao)``; a última ocorrência
    determinística representa a tentativa final. Só depois agregamos as
    questões, evitando usuários repetidos e contagens infladas.
    """
    data = data or dados_referencias
    questoes_por_id = {questao.id: questao for questao in questoes}
    tarefas = _tarefas_execucao(data)
    trabalhadores = max(1, min(int(os.environ.get('ETAPA3_WORKERS', os.cpu_count() or 1)), 32))
    print(f"Iniciando leitura paralela de {len(tarefas):,} execuções com {trabalhadores} workers...")

    respostas_por_usuario_questao = {}
    with ThreadPoolExecutor(max_workers=trabalhadores, thread_name_prefix='Etapa3-IO') as executor:
        resultados = executor.map(_ler_execucao, tarefas)
        for resultado in tqdm(resultados, total=len(tarefas), desc='Fase 4/5 — execuções lidas', unit='arquivo', leave=True):
            if resultado is None:
                continue
            id_usuario, id_questao, nota = resultado
            if nota is None:
                continue
            if id_questao in questoes_por_id:
                # A ordem de tarefas é determinística; uma tentativa posterior
                # substitui a anterior para a mesma questão do mesmo usuário.
                respostas_por_usuario_questao[(str(id_usuario), id_questao)] = nota

    notas_finais_por_questao = {}
    for (id_usuario, id_questao), nota in respostas_por_usuario_questao.items():
        notas_finais_por_questao.setdefault(id_questao, {})[str(id_usuario)] = float(nota)

    for id_questao, notas_por_usuario in notas_finais_por_questao.items():
        questao = questoes_por_id[id_questao]
        questao.notas_por_usuario = dict(sorted(notas_por_usuario.items()))
        questao.usuarios_respondidos = sorted(questao.notas_por_usuario)
        questao.respostas = len(questao.notas_por_usuario)
        questao.dificuldade = float(sum(questao.notas_por_usuario.values()))

    return calcular_dificuldade(questoes)


def formatar_questao(questao):
    return (f"Questao(id={questao.id}, dificuldade={questao.dificuldade:.2f}, "
            f"discriminacao={questao.discriminacao:.2f}, respostas={questao.respostas}, "
            f"usuarios={questao.usuarios_respondidos})")

# %% [markdown]
# ## 9. Cálculo das médias dos usuários
#
# `processar_usuarios` lê as grades em paralelo, mantém somente notas válidas e calcula a média final de cada usuário. Usuários sem nota válida não recebem uma média artificial para fins de discriminação.

# %%
registrar_progresso_etapa3('Fase 4/5 iniciada — leitura paralela e consolidação das execuções')
resultado_questoes_com_dificuldade = respostas_questao(
    lista_questoes,
    dados_referencias,
)

registrar_progresso_etapa3(f'Execuções consolidadas — questões com dados={sum(q.respostas > 0 for q in resultado_questoes_com_dificuldade):,}')
questoes_sem_amostra_suficiente = [
    questao
    for questao in resultado_questoes_com_dificuldade
    if questao.respostas < MINIMO_ESTUDANTES_DISTINTOS_POR_QUESTAO
]

lista_questoes_com_dificuldade = [
    questao
    for questao in resultado_questoes_com_dificuldade
    if questao.respostas >= MINIMO_ESTUDANTES_DISTINTOS_POR_QUESTAO
]
lista_questoes_com_dificuldade.sort(
    key=lambda questao: questao.respostas,
    reverse=True,
)

print(
    f'Questões catalogadas: {len(resultado_questoes_com_dificuldade):,}'
)
print(
    f'Questões excluídas por menos de '
    f'{MINIMO_ESTUDANTES_DISTINTOS_POR_QUESTAO} estudantes distintos: '
    f'{len(questoes_sem_amostra_suficiente):,}'
)
print(
    f'Questões elegíveis para métricas: '
    f'{len(lista_questoes_com_dificuldade):,}'
)
print(
    f'Questões elegíveis com respostas: '
    f'{sum(questao.respostas > 0 for questao in lista_questoes_com_dificuldade):,}'
)
for questao in lista_questoes_com_dificuldade:
    print(formatar_questao(questao))

# %% [markdown]
# ## 10. Nota individual por usuário–questão
#
# Para permitir o reuso pela Etapa 5, a Etapa 3 também extrai a `GRADE` do último `SUBMITION` válido de cada execution, ignorando blocos com `ERROR`. Essa nota é registrada no `indice_usuarios.json` como `notas_finais[questao].nota_final`. O valor `0` é preservado como nota real; ausência de nota não é convertida em zero.

# %%
def _ler_nota_grade_usuario(caminho: str | Path) -> float | None:
    """Lê a nota agregada de um arquivo ``grades/*.log``.

    O dataset CodeBench usa principalmente este formato::

        ---- final score  (0-10): 10

    Algumas versões/arquivos antigos usam ``grade (0-10): 7.5``. O parser
    aceita ambos. Isso não deve ser confundido com ``executions/*.log``, que
    guarda percentuais em blocos ``SUBMITION`` com ``-- GRADE:``.
    """
    padrao = re.compile(
        r'^\s*(?:-{2,}\s*)?(?:final\s+score|grade)\s*'
        r'\(\s*0\s*-\s*10\s*\)\s*:\s*'
        r'(-?\d+(?:[.,]\d+)?)\s*$',
        flags=re.IGNORECASE,
    )
    try:
        with Path(caminho).open('r', encoding='utf-8') as arquivo:
            for linha in arquivo:
                correspondencia = padrao.match(linha)
                if correspondencia:
                    nota = float(correspondencia.group(1).replace(',', '.'))
                    return max(0.0, min(10.0, nota))
    except (FileNotFoundError, OSError, UnicodeError, ValueError):
        return None
    return None



def _diagnostico_arquivo_grade(dados: dict, item: dict, raiz_fisica: Path) -> dict:
    """Retorna evidências físicas e de parsing de uma grade referenciada."""
    caminho_relativo = str(item.get('path', '')).replace('\\', '/')
    caminho = raiz_fisica / caminho_relativo
    registro = {
        'referencia': item,
        'path_relativo': caminho_relativo,
        'path_absoluto': str(caminho),
        'existe': caminho.is_file(),
        'tamanho_bytes': caminho.stat().st_size if caminho.is_file() else None,
        'nota_extraida_pelo_parser': None,
        'motivo': None,
    }
    if not caminho.is_file():
        registro['motivo'] = 'arquivo_referenciado_nao_existe'
        return registro
    try:
        registro['conteudo_bruto'] = caminho.read_text(encoding='utf-8', errors='replace')
    except OSError as exc:
        registro['motivo'] = 'erro_ao_ler_arquivo'
        registro['erro_leitura'] = repr(exc)
        return registro
    nota = _ler_nota_grade_usuario(caminho)
    registro['nota_extraida_pelo_parser'] = nota
    registro['motivo'] = 'nota_valida_extraida' if nota is not None else 'formato_de_nota_nao_reconhecido_ou_vazio'
    return registro


def gerar_json_usuarios_sem_notas_validas(dados_antes_das_anomalias: dict, dados_depois_das_anomalias: dict, usuarios_processados: dict) -> None:
    """Salva evidências completas dos usuários sem nota após a Etapa 3."""
    raiz_fisica = Path(dados_depois_das_anomalias['_source_root'])
    antes = {str(r.get('id')): r for r in dados_antes_das_anomalias.get('users', [])}
    depois = {str(r.get('id')): r for r in dados_depois_das_anomalias.get('users', [])}
    sem_notas = [u for u in usuarios_processados.values() if not u.notas]
    registros = []
    for usuario in sorted(sem_notas, key=lambda u: str(u.id)):
        uid = str(usuario.id)
        original, final = antes.get(uid, {}), depois.get(uid, {})
        grades_originais = original.get('files', {}).get('grades', [])
        grades_finais = final.get('files', {}).get('grades', [])
        caminhos_finais = {str(x.get('path', '')).replace('\\', '/') for x in grades_finais}
        diagnosticos = []
        for item in grades_originais:
            diag = _diagnostico_arquivo_grade(dados_depois_das_anomalias, item, raiz_fisica)
            removida = str(item.get('path', '')).replace('\\', '/') not in caminhos_finais
            diag['removida_antes_da_leitura_final'] = removida
            if removida:
                diag['motivo_pos_processamento'] = 'removida_pela_deduplicacao_de_assessments_ou_tp'
            diagnosticos.append(diag)
        motivos = sorted({d.get('motivo_pos_processamento') or d.get('motivo') or 'sem_grade_referenciada' for d in diagnosticos}) or ['sem_grade_referenciada']
        registros.append({
            'id_usuario': uid,
            'notas_validas_finais': list(usuario.notas),
            'media_final': usuario.media,
            'roots_originais': original.get('roots', []),
            'roots_finais': final.get('roots', []),
            'arquivos_originais_etapa2': original.get('files', {}),
            'arquivos_finais_etapa3': final.get('files', {}),
            'quantidade_grades_originais': len(grades_originais),
            'quantidade_grades_finais': len(grades_finais),
            'motivos_diagnostico': motivos,
            'grades_diagnosticadas': diagnosticos,
        })
    relatorio = {
        'schema_version': 1,
        'descricao': 'Evidências dos usuários processados sem notas válidas ao final da Etapa 3.',
        'criterio': 'usuario.notas vazio após leitura das grades finais; parser aceita final score (0-10) e grade (0-10).',
        'source_root': str(raiz_fisica),
        'quantidade_usuarios_sem_notas_validas': len(registros),
        'usuarios': registros,
    }
    caminho_saida = PASTA_SAIDA / 'usuarios_sem_notas_validas_diagnostico.json'
    caminho_saida.parent.mkdir(parents=True, exist_ok=True)
    caminho_saida.write_text(json.dumps(relatorio, ensure_ascii=False, indent=2) + '\n', encoding='utf-8')
    print(f'Diagnóstico salvo: {caminho_saida.resolve()} ({len(registros):,} usuários)')

def _ler_notas_usuario(task: tuple[str, list[str]]) -> tuple[str, list[float]]:
    """Lê as notas dos arquivos grades usando o formato original."""
    user_id, paths = task
    notas = []
    for path_string in paths:
        nota = _ler_nota_grade_usuario(path_string)
        if nota is not None:
            notas.append(nota)
    return user_id, notas


def calcular_media_final_usuario(dicionario_usuarios_processados):
    for usuario in dicionario_usuarios_processados.values():
        usuario.calcular_media()
    return dicionario_usuarios_processados


def extrair_nota_final_execution(caminho):
    """Retorna a GRADE percentual do último SUBMITION válido do execution."""
    separador = '*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*'
    try:
        conteudo = Path(caminho).read_text(encoding='utf-8', errors='replace')
    except (OSError, UnicodeError):
        return None
    blocos = [bloco for bloco in conteudo.split(separador)
              if re.search(r'^\s*==\s*SUBMITION\b', bloco, flags=re.I | re.M)]
    if not blocos:
        return None
    ultimo = blocos[-1]
    if re.search(r'^\s*-+\s*ERROR\s*:', ultimo, flags=re.I | re.M):
        return None
    match = re.search(
        r'^\s*-+\s*GRADE\s*:\s*([+-]?\d+(?:[.,]\d+)?)\s*%?',
        ultimo, flags=re.I | re.M
    )
    if not match:
        return None
    try:
        return float(match.group(1).replace(',', '.'))
    except ValueError:
        return None


def extrair_notas_finais_por_usuario_questao(data):
    """Indexa a nota do execution por usuário e questão, sem alterar filtros."""
    source_root = Path(data['_source_root'])
    notas = {}
    for registro in data.get('users', []):
        usuario = str(registro.get('id'))
        for item in registro.get('files', {}).get('executions', []):
            question = item.get('question')
            if question is None:
                continue
            caminho = source_root / item['path']
            nota = extrair_nota_final_execution(caminho)
            if nota is None:
                continue
            notas.setdefault(usuario, {})[str(question)] = {
                'nota_final': nota,
                'assessment': str(item.get('assessment') or caminho.stem.split('_', 1)[0]),
                'execution_path': item['path'],
            }
    return notas

def processar_usuarios(data=None):
    data = data or dados_referencias
    source_root = Path(data['_source_root'])
    tasks = []
    for record in data.get('users', []):
        user_id = str(record['id'])
        paths = [str(source_root / item['path']) for item in record.get('files', {}).get('grades', [])
                 if (source_root / item['path']).is_file() and item['path'].endswith('.log')]
        tasks.append((user_id, sorted(paths)))

    workers = max(1, min(int(os.environ.get('ETAPA3_WORKERS', os.cpu_count() or 1)), 32))
    usuarios_dict = {}
    print(f"Iniciando leitura paralela de notas de {len(tasks):,} usuários com {workers} workers...")
    with ThreadPoolExecutor(max_workers=workers, thread_name_prefix='Etapa3-Grades') as executor:
        for user_id, notas in tqdm(executor.map(_ler_notas_usuario, tasks), total=len(tasks), desc='Fase 5/5 — notas lidas', unit='usuário', leave=True):
            usuario = Usuario(user_id)
            for nota in notas:
                usuario.adicionar_nota(nota)
            usuarios_dict[user_id] = usuario
    usuarios_dict = calcular_media_final_usuario(usuarios_dict)
    usuarios_com_nota = sum(bool(usuario.notas) for usuario in usuarios_dict.values())
    print(f"Notas de grades válidas (assessment-level): {sum(len(usuario.notas) for usuario in usuarios_dict.values()):,}")
    print(f"Usuários com pelo menos uma nota de grade válida: {usuarios_com_nota:,}/{len(usuarios_dict):,}")
    return usuarios_dict

# %% [markdown]
# ## 11. Dificuldade das questões
#
# A dificuldade da questão é calculada a partir das respostas válidas consolidadas. O cálculo usa apenas questões elegíveis e estudantes com dados compatíveis, evitando que questões com pouca participação produzam métricas instáveis.

# %%
registrar_progresso_etapa3('Fase 5/5 iniciada — deduplicação de TPs e leitura paralela das grades')
dados_referencias_antes_das_anomalias = json.loads(json.dumps(dados_referencias, ensure_ascii=False))
tratar_anomalias_grades_por_tp(dados_referencias, limite=6)
dicionario_usuarios_processados = processar_usuarios(dados_referencias)
registrar_progresso_etapa3(
    f'Fase 5/5 concluída — usuários com grades processadas={len(dicionario_usuarios_processados):,}'
)
registrar_progresso_etapa3(f'Log completo salvo: {CAMINHO_LOG_ETAPA3.resolve()}')
print(f"Usuários processados: {len(dicionario_usuarios_processados):,}")

gerar_json_usuarios_sem_notas_validas(dados_referencias_antes_das_anomalias, dados_referencias, dicionario_usuarios_processados)

# %%
# Diagnóstico dos usuários: notas e endereço físico para validação.
# Esta célula mostra somente os arquivos que a Etapa 2 registrou no JSON.
raiz_fisica = Path(dados_referencias['_source_root'])
usuarios_por_id = dados_referencias.get('_users_by_id', {})

for id_usuario, usuario in list(dicionario_usuarios_processados.items())[:20]:
    id_usuario = str(id_usuario)
    registro = usuarios_por_id.get(id_usuario)

    print(f'ID: {usuario.id}')

    grades_do_usuario = registro.get('files', {}).get('grades', []) if registro else []
    notas_detalhadas = []
    for item_grade in grades_do_usuario:
        caminho_grade_diagnostico = raiz_fisica / item_grade['path']
        nota_grade_diagnostico = _ler_nota_grade_usuario(caminho_grade_diagnostico)
        assessment_grade_diagnostico = _assessment_id_from_item_path(
            item_grade['path'], 'grades'
        )
        tipo_grade_diagnostico = _assessment_type_for_item(
            dados_referencias, item_grade, 'grades'
        )
        metadata_grade_diagnostico = _assessment_metadata_for_item(
            dados_referencias, item_grade, 'grades'
        )
        grupo_grade_diagnostico = metadata_grade_diagnostico.get('group', 'não informado')
        if nota_grade_diagnostico is not None:
            notas_detalhadas.append(
                f'{nota_grade_diagnostico:g} '
                f'(assessment={assessment_grade_diagnostico}, tipo={tipo_grade_diagnostico}, '
                f'grupo={grupo_grade_diagnostico})'
            )
    if notas_detalhadas:
        print(f'Notas: [{", ".join(notas_detalhadas)}]')
    else:
        print('Notas: []')

    if usuario.notas:
        parcelas_media = ' + '.join(f'{nota:g}' for nota in usuario.notas)
        print(
            f'Média (N/6): ({parcelas_media}) / 6 = {usuario.media:g}'
        )
    else:
        print('Média (N/6): 0 / 6 = 0')

    if registro is None:
        print('Pasta do usuário: não registrada no JSON')
        print('-' * 80)
        continue

    raizes_usuario = registro.get('roots', [])
    if not raizes_usuario:
        print('Pasta do usuário: não registrada no JSON')
    else:
        for raiz_relativa in raizes_usuario:
            pasta_usuario = raiz_fisica / raiz_relativa
            print(f'Pasta do usuário: {pasta_usuario}')
            print(f'  Existe: {pasta_usuario.is_dir()}')

    for tipo_arquivo, titulo in (('grades', 'Grades filtradas pelo JSON'), ('executions', 'Executions filtradas pelo JSON')):
        arquivos_registrados = registro.get('files', {}).get(tipo_arquivo, [])
        if not arquivos_registrados:
            print(f'{titulo}: nenhuma')
            continue

        print(f'{titulo}:')
        for item in arquivos_registrados:
            caminho = raiz_fisica / item['path']
            assessment_id = _assessment_id_from_item_path(item['path'], tipo_arquivo)
            tipo_assessment = _assessment_type_for_item(
                dados_referencias, item, tipo_arquivo
            )
            metadata_item = _assessment_metadata_for_item(
                dados_referencias, item, tipo_arquivo
            )
            grupo_item = metadata_item.get('group', 'não informado')
            linha = (
                f'  {caminho} | assessment={assessment_id} | '
                f'tipo={tipo_assessment} | grupo={grupo_item}'
            )
            if tipo_arquivo != 'grades':
                questao = item.get('question')
                if questao is None and '_' in caminho.stem:
                    questao = caminho.stem.rsplit('_', 1)[-1]
                desempenho = obter_nota_arquivo(caminho)
                linha += f' | questão={questao} | desempenho(GRADE)={desempenho:g}%'
            print(linha)

    print('-' * 80)

if len(dicionario_usuarios_processados) > 20:
    print(f'... {len(dicionario_usuarios_processados) - 20:,} usuários adicionais não exibidos.')

# %% [markdown]
# ## 12. Discriminação psicométrica
#
# A discriminação é calculada pela correlação de Spearman entre a nota da questão e a média final do estudante. O resultado varia de -1 a 1: valores positivos indicam associação direta, valores próximos de zero indicam pouca relação e valores negativos indicam comportamento invertido.

# %%
usuarios_com_notas_validas = [
    usuario
    for usuario in dicionario_usuarios_processados.values()
    if usuario.notas
]
notas_finais = np.asarray(
    [usuario.media for usuario in usuarios_com_notas_validas],
    dtype=float,
)
media_final = float(np.mean(notas_finais)) if notas_finais.size else 0.0
desvio_padrao = float(np.std(notas_finais)) if notas_finais.size else 0.0
print(
    f'Usuários processados: '
    f'{len(dicionario_usuarios_processados):,}'
)
print(
    f'Usuários com notas válidas: '
    f'{len(usuarios_com_notas_validas):,}'
)
print(
    f'Usuários sem notas válidas: '
    f'{len(dicionario_usuarios_processados) - len(usuarios_com_notas_validas):,}'
)
print(f'Total de notas válidas: {sum(len(usuario.notas) for usuario in usuarios_com_notas_validas):,}')
print(f'Média Final (MT): {media_final}')
print(f'Desvio Padrão (DPT): {desvio_padrao}')

# %% [markdown]
# ## 13. Estatísticas globais
#
# As estatísticas globais usam somente usuários com pelo menos uma nota válida em `grades/*.log`. Todas as operações verificam se existem dados suficientes antes de calcular percentis, moda, amplitude ou distribuições.

# %%
def calcular_discriminacao(questoes, usuarios):
    """Calcula a discriminação como correlação de Spearman item-total.

    O item é a nota final da questão (0--100) e o total é a média final do
    estudante (0--10). O cálculo usa somente estudantes com média válida e
    com nota final válida para a questão. A correlação de Spearman mede se
    estudantes de maior desempenho tendem a obter notas maiores no item, sem
    depender de uma escala linear perfeita.
    """
    media_por_id = {
        str(usuario.id): float(usuario.media)
        for usuario in usuarios.values()
        if usuario.notas and np.isfinite(usuario.media)
    }

    for questao in questoes:
        pares = [
            (float(nota), media_por_id[str(usuario_id)])
            for usuario_id, nota in questao.notas_por_usuario.items()
            if str(usuario_id) in media_por_id and np.isfinite(nota)
        ]
        if len(pares) < 3:
            questao.discriminacao = 0.0
            continue

        notas_item = np.asarray([par[0] for par in pares], dtype=float)
        medias_totais = np.asarray([par[1] for par in pares], dtype=float)
        if np.ptp(notas_item) == 0 or np.ptp(medias_totais) == 0:
            questao.discriminacao = 0.0
            continue

        correlacao, _pvalor = spearmanr(notas_item, medias_totais)
        questao.discriminacao = (
            float(correlacao) if np.isfinite(correlacao) else 0.0
        )

    return questoes

# %% [markdown]
# ## 14. Exportação das questões
#
# A Etapa 3 grava `questoes_ordenadas.csv` com as questões elegíveis e suas métricas. Esse arquivo é a saída tabular principal para as etapas posteriores.

# %%
lista_questoes_completas = calcular_discriminacao(
    lista_questoes_com_dificuldade,
    dicionario_usuarios_processados,
)
questoes_ordenadas = sorted(
    lista_questoes_completas,
    key=lambda questao: questao.discriminacao,
    reverse=True,
)
print(
    f'Questões elegíveis com discriminação calculada: '
    f'{len(questoes_ordenadas):,}'
)
for questao in questoes_ordenadas:
    questao.dificuldade = float(questao.dificuldade)
    questao.discriminacao = float(questao.discriminacao)
    print(
        f'Questao(id={questao.id}, '
        f'dificuldade={questao.dificuldade:.2f}, '
        f'discriminacao={questao.discriminacao:.4f}, '
        f'respostas={questao.respostas}, '
        f'usuarios_respondidos={questao.usuarios_respondidos})'
    )

# %% [markdown]
# ## 15. Exportação do índice de usuários
#
# A Etapa 3 grava `indice_usuarios.json` versão 3. O índice contém as questões elegíveis de cada usuário e as notas individuais por usuário–questão, além das referências necessárias para localizar os arquivos físicos. Ele contém referências e metadados, não cópias dos códigos.

# %%
DIRETORIO_SAIDA = Path('output')
DIRETORIO_SAIDA.mkdir(parents=True, exist_ok=True)
ARQUIVO_QUESTOES_SAIDA = DIRETORIO_SAIDA / 'questoes_ordenadas.csv'
questoes_ordenadas = sorted(questoes_ordenadas, key=lambda questao: questao.id)

with ARQUIVO_QUESTOES_SAIDA.open(mode='w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['id', 'dificuldade', 'discriminacao', 'respostas', 'usuarios_respondidos']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for questao in questoes_ordenadas:
        if questao.respostas >= MINIMO_ESTUDANTES_DISTINTOS_POR_QUESTAO:
            writer.writerow({
                'id': questao.id,
                'dificuldade': f'{questao.dificuldade:.2f}',
                'discriminacao': f'{questao.discriminacao:.2f}',
                'respostas': questao.respostas,
                'usuarios_respondidos': ','.join(map(str, sorted(questao.usuarios_respondidos))),
            })

print("Arquivo 'questoes_ordenadas.csv' criado com sucesso.")

notas_finais_indice = extrair_notas_finais_por_usuario_questao(dados_referencias)
indice_usuarios_elegiveis = {}
for questao in questoes_ordenadas:
    if questao.respostas < MINIMO_ESTUDANTES_DISTINTOS_POR_QUESTAO:
        continue
    for usuario_id in questao.usuarios_respondidos:
        usuario_id = str(usuario_id)
        registro = indice_usuarios_elegiveis.setdefault(usuario_id, {'diretorio': usuario_id, 'questoes_elegiveis': set()})
        registro['questoes_elegiveis'].add(int(questao.id))

por_id = dados_referencias.get('_users_by_id', {})
for registro in indice_usuarios_elegiveis.values():
    registro['questoes_elegiveis'] = sorted(registro['questoes_elegiveis'])
    registro['notas_finais'] = {
        str(question): notas_finais_indice.get(str(registro['diretorio']), {}).get(str(question))
        for question in registro['questoes_elegiveis']
        if str(question) in notas_finais_indice.get(str(registro['diretorio']), {})
    }
    referencia_usuario = por_id.get(str(registro['diretorio']), {})
    registro['subdiretorios'] = sorted(referencia_usuario.get('files', {}).keys())
    registro['tem_user_data'] = bool(referencia_usuario.get('files', {}).get('user_data'))

pares_com_nota_individual = sum(len(item.get('notas_finais', {})) for item in indice_usuarios_elegiveis.values())
registrar_progresso_etapa3(f'Notas individuais indexadas por usuário–questão={pares_com_nota_individual:,}')

dados_indice_saida = {
    'versao': 3,
    'notas_finais_fonte': 'execution logs; último SUBMITION válido com GRADE e sem ERROR',
    'base_relativa': '../Etapa_2/output/referencias_processamento.json',
    'usuarios': indice_usuarios_elegiveis,
    'estatisticas': {
        'usuarios_elegiveis': len(indice_usuarios_elegiveis),
        'pares_usuario_questao': sum(len(item['questoes_elegiveis']) for item in indice_usuarios_elegiveis.values()),
    },
}
(DIRETORIO_SAIDA / 'indice_usuarios.json').write_text(json.dumps(dados_indice_saida, ensure_ascii=False, indent=2), encoding='utf-8')
print('Índice de usuários salvo em:', DIRETORIO_SAIDA / 'indice_usuarios.json')
registrar_progresso_etapa3(
    f'Etapa 3 concluída — usuários_elegíveis={len(indice_usuarios_elegiveis):,}; '
    f'questões_elegíveis={sum(1 for questao in questoes_ordenadas if questao.respostas >= MINIMO_ESTUDANTES_DISTINTOS_POR_QUESTAO):,}; '
    f'pares_usuario_questao={sum(len(item["questoes_elegiveis"]) for item in indice_usuarios_elegiveis.values()):,}'
)

# %% [markdown]
# ## 16. Validação das saídas
#
# Antes de concluir, o notebook confirma a quantidade de usuários elegíveis, questões elegíveis e pares usuário–questão. A contagem de grades agregadas, executions e pares finais é mantida separada porque são unidades diferentes.

# %%
contador_usuarios = sum(len(usuario.notas) > 6 for usuario in dicionario_usuarios_processados.values())
quantidade_total_usuarios = len(dicionario_usuarios_processados)
print(f'Quantidade total de usuários: {quantidade_total_usuarios:,}')
print(f'Quantidade de usuários com mais de 6 notas: {contador_usuarios:,}')

# %% [markdown]
# ## 17. Estatísticas descritivas
#
# As células finais calculam estatísticas descritivas usando os objetos já processados. Quando não há usuários, notas ou questões suficientes, o notebook informa a situação e evita operações que exigem uma amostra não vazia.

# %%
notas_dos_usuarios = [
    nota
    for usuario in dicionario_usuarios_processados.values()
    for nota in usuario.notas
]

if not notas_dos_usuarios:
    print('Não há notas disponíveis para calcular variância, amplitude ou quartis.')
else:
    notas_array = np.asarray(notas_dos_usuarios, dtype=float)
    variancia_notas = float(np.var(notas_array))
    desvio_padrao_notas = float(np.std(notas_array))
    amplitude_notas = float(np.ptp(notas_array))
    primeiro_quartil = float(np.percentile(notas_array, 25))
    terceiro_quartil = float(np.percentile(notas_array, 75))
    intervalo_interquartil = terceiro_quartil - primeiro_quartil

    print(
        f"Variância: {variancia_notas:.2f}, "
        f"Desvio Padrão: {desvio_padrao_notas:.2f}, "
        f"Amplitude: {amplitude_notas:.2f}"
    )
    print(
        f"Quartil 1: {primeiro_quartil:.2f}, "
        f"Quartil 3: {terceiro_quartil:.2f}, "
        f"IQR: {intervalo_interquartil:.2f}"
    )

# %% [markdown]
# ## 18. Gráficos
#
# Os gráficos são gerados a partir dos resultados já calculados. Nenhuma célula desta seção relê ou altera a base `Extraidos`; os gráficos servem apenas para inspeção e interpretação.

# %%
notas_medias_usuarios = np.asarray(
    [usuario.media for usuario in dicionario_usuarios_processados.values()],
    dtype=float,
)

if notas_medias_usuarios.size == 0:
    print('Não há médias de usuários para gerar o histograma de notas.')
else:
    media_notas = float(np.mean(notas_medias_usuarios))
    mediana_notas = float(np.median(notas_medias_usuarios))
    resultado_moda = mode(notas_medias_usuarios, keepdims=True)
    moda_notas = float(resultado_moda.mode[0]) if resultado_moda.count[0] > 0 else None

    bins_notas = np.arange(0, 12, 1)
    centros_bins = (bins_notas[:-1] + bins_notas[1:]) / 2
    largura_bin = bins_notas[1] - bins_notas[0]

    plt.figure(figsize=(10, 5))
    contagens_notas, _ = np.histogram(notas_medias_usuarios, bins=bins_notas)
    plt.bar(centros_bins, contagens_notas, width=largura_bin, color='skyblue', edgecolor='black')
    plt.axvline(media_notas, color='red', linestyle='dashed', linewidth=2, label=f'Média: {media_notas:.1f}')
    plt.axvline(mediana_notas, color='green', linestyle='dashed', linewidth=2, label=f'Mediana: {mediana_notas:.1f}')
    if moda_notas is not None:
        plt.axvline(moda_notas, color='purple', linestyle='dashed', linewidth=2, label=f'Moda: {moda_notas:.1f}')
    for indice_bin, quantidade in enumerate(contagens_notas):
        plt.text(centros_bins[indice_bin], quantidade + 0.5, str(quantidade), ha='center', va='bottom')
    plt.xticks(ticks=centros_bins, labels=[str(int(valor)) for valor in centros_bins])
    plt.xlabel('Notas')
    plt.ylabel('Frequência')
    plt.title('Distribuição das Notas')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 19. Conclusão e arquivos produzidos
#
# Ao final, o notebook deixa disponíveis `questoes_ordenadas.csv`, `indice_usuarios.json`, as estatísticas e as figuras para as etapas seguintes. A Etapa 5 pode reutilizar as notas individuais do índice sem reler os executions.

# %%
notas_medias_usuarios = np.asarray(
    [usuario.media for usuario in dicionario_usuarios_processados.values()],
    dtype=float,
)

if notas_medias_usuarios.size < 2:
    print('São necessários pelo menos dois valores para gerar a densidade das notas.')
else:
    media_notas = float(np.mean(notas_medias_usuarios))
    mediana_notas = float(np.median(notas_medias_usuarios))
    resultado_moda = mode(notas_medias_usuarios, keepdims=True)
    moda_notas = float(resultado_moda.mode[0]) if resultado_moda.count[0] > 0 else None

    plt.figure(figsize=(10, 5))
    sns.kdeplot(notas_medias_usuarios, fill=True, color='skyblue')
    plt.axvline(media_notas, color='red', linestyle='dashed', linewidth=2, label=f'Média: {media_notas:.1f}')
    plt.axvline(mediana_notas, color='green', linestyle='dashed', linewidth=2, label=f'Mediana: {mediana_notas:.1f}')
    if moda_notas is not None:
        plt.axvline(moda_notas, color='purple', linestyle='dashed', linewidth=2, label=f'Moda: {moda_notas:.1f}')
    plt.xlabel('Notas')
    plt.title('Distribuição das Notas dos Usuários')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

# %%
questoes_com_respostas = [questao for questao in questoes_ordenadas if questao.respostas >= MINIMO_ESTUDANTES_DISTINTOS_POR_QUESTAO]
dificuldades_questoes = np.asarray(
    [questao.dificuldade for questao in questoes_com_respostas],
    dtype=float,
)

if dificuldades_questoes.size == 0:
    print('Não há questões com pelo menos 15 respostas para gerar o gráfico de dificuldade.')
else:
    media_dificuldade = float(np.mean(dificuldades_questoes))
    mediana_dificuldade = float(np.median(dificuldades_questoes))
    resultado_moda = mode(dificuldades_questoes, keepdims=True)
    moda_dificuldade = float(resultado_moda.mode[0]) if resultado_moda.count[0] > 0 else None

    intervalos_dificuldade = np.arange(0, 110, 10)
    histograma, limites_bins = np.histogram(dificuldades_questoes, bins=intervalos_dificuldade)
    centros_bins = (limites_bins[:-1] + limites_bins[1:]) / 2

    plt.figure(figsize=(10, 5))
    plt.bar(centros_bins, histograma, width=np.diff(limites_bins), color='skyblue', edgecolor='black')
    plt.axvline(media_dificuldade, color='red', linestyle='dashed', linewidth=2, label=f'Média: {media_dificuldade:.2f}')
    plt.axvline(mediana_dificuldade, color='green', linestyle='dashed', linewidth=2, label=f'Mediana: {mediana_dificuldade:.2f}')
    if moda_dificuldade is not None:
        plt.axvline(moda_dificuldade, color='purple', linestyle='dashed', linewidth=2, label=f'Moda: {moda_dificuldade:.2f}')
    for indice_bin, quantidade in enumerate(histograma):
        plt.text(centros_bins[indice_bin], quantidade + 0.5, str(quantidade), ha='center', va='bottom')
    plt.xticks(ticks=centros_bins, labels=[str(int(valor)) for valor in intervalos_dificuldade[:-1]])
    plt.xlabel('Dificuldade')
    plt.ylabel('Frequência')
    plt.title('Distribuição das Dificuldades das Questões')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
questoes_com_respostas = [questao for questao in questoes_ordenadas if questao.respostas >= MINIMO_ESTUDANTES_DISTINTOS_POR_QUESTAO]
discriminacoes_questoes = np.asarray(
    [questao.discriminacao for questao in questoes_com_respostas],
    dtype=float,
)

if discriminacoes_questoes.size < 2:
    print('São necessárias pelo menos duas questões elegíveis para gerar a densidade da discriminação.')
else:
    media_discriminacao = float(np.mean(discriminacoes_questoes))
    mediana_discriminacao = float(np.median(discriminacoes_questoes))
    resultado_moda = mode(discriminacoes_questoes, keepdims=True)
    moda_discriminacao = float(resultado_moda.mode[0]) if resultado_moda.count[0] > 0 else None

    plt.figure(figsize=(10, 5))
    sns.kdeplot(discriminacoes_questoes, fill=True, color='skyblue')
    plt.axvline(media_discriminacao, color='red', linestyle='dashed', linewidth=2, label=f'Média: {media_discriminacao:.2f}')
    plt.axvline(mediana_discriminacao, color='green', linestyle='dashed', linewidth=2, label=f'Mediana: {mediana_discriminacao:.2f}')
    if moda_discriminacao is not None:
        plt.axvline(moda_discriminacao, color='purple', linestyle='dashed', linewidth=2, label=f'Moda: {moda_discriminacao:.2f}')
    plt.xlabel('Discriminação')
    plt.title('Distribuição da Discriminação das Questões')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

# %%
respostas_por_questao = np.asarray(
    [questao.respostas for questao in questoes_ordenadas],
    dtype=float,
)

if respostas_por_questao.size == 0:
    print('Não há questões para gerar a distribuição de respostas.')
else:
    media_respostas = float(np.mean(respostas_por_questao))
    mediana_respostas = float(np.median(respostas_por_questao))
    resultado_moda = mode(respostas_por_questao, keepdims=True)
    moda_respostas = float(resultado_moda.mode[0]) if resultado_moda.count[0] > 0 else None

    plt.figure(figsize=(10, 5))
    plt.hist(respostas_por_questao, bins=20, color='skyblue', edgecolor='black')
    plt.axvline(media_respostas, color='red', linestyle='dashed', linewidth=2, label=f'Média: {media_respostas:.2f}')
    plt.axvline(mediana_respostas, color='green', linestyle='dashed', linewidth=2, label=f'Mediana: {mediana_respostas:.2f}')
    if moda_respostas is not None:
        plt.axvline(moda_respostas, color='purple', linestyle='dashed', linewidth=2, label=f'Moda: {moda_respostas:.2f}')
    plt.xlabel('Quantidade de Respostas')
    plt.ylabel('Frequência')
    plt.title('Distribuição da Quantidade de Respostas das Questões')
    plt.legend()
    plt.tight_layout()
    plt.show()
